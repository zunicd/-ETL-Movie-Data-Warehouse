# %% [markdown]
# # ETL Project

# %%
# Import libraries
import pandas as pd
import pymongo

# Set max number of columns to be displayed
pd.set_option('display.max_columns', 60)
pd.set_option('display.max_colwidth', 70)

# %% [markdown]
# ## Finding Data - Extract

# %% [markdown]
# ### Load .csv Files to Dataframe

# %%
# Movie metadata file from Kaggle
file1 = './Resources/movies_metadata.csv'

# Movie metadata file from Data.World; mostly used for Facebook likes
file_fb = './Resources/movie_metadata_dw.csv'

# %% [markdown]
# We need to use converters to convert 'genres' string back to the list of dictionaries.

# %%
# Using converters to convert 'genres' string back to list of dictionaries
df_init = pd.read_csv(file1, low_memory=False, converters={'genres': eval})
print(df_init.shape)
df_init.head(2)
# Out:
# (45466, 24)
#    adult  \
# 0  False
# 1  False
#
#                                                    belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9...
# 1                                                                    NaN
#
#      budget  \
# 0  30000000
# 1  65000000
#
#                                                                   genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title  \
# 0      Toy Story
# 1        Jumanji
#
#                                                                 overview  \
# 0  Led by Woody, Andy's toys live happily in his room until Andy's bi...
# 1  When siblings Judy and Peter discover an enchanted board game that...
#
#   popularity                       poster_path  \
# 0  21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1  17.015539  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
#
#                                                     production_companies  \
# 0                         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'name': 'Teitler Film',...
#
#                                          production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States of America'}]   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States of America'}]   1995-12-15
#
#        revenue  runtime  \
# 0  373554033.0     81.0
# 1  262797249.0    104.0
#
#                                                         spoken_languages  \
# 0                               [{'iso_639_1': 'en', 'name': 'English'}]
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name...
#
#      status                                    tagline      title  video  \
# 0  Released                                        NaN  Toy Story  False
# 1  Released  Roll the dice and unleash the excitement!    Jumanji  False
#
#    vote_average  vote_count
# 0           7.7      5415.0
# 1           6.9      2413.0

# %%
dffb_init = pd.read_csv(file_fb, low_memory=False)
print(dffb_init.shape)
dffb_init.head(2)
# Out:
# (5043, 28)
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
#
#   actor_1_name                                movie_title  num_voted_users  \
# 0  CCH Pounder                                    Avatar            886204
# 1  Johnny Depp  Pirates of the Caribbean: At World's End            471220
#
#    cast_total_facebook_likes    actor_3_name  facenumber_in_poster  \
# 0                       4834       Wes Studi                   0.0
# 1                      48350  Jack Davenport                   0.0
#
#                                                   plot_keywords  \
# 0                        avatar|future|marine|native|paraplegic
# 1  goddess|marriage ceremony|marriage proposal|pirate|singapore
#
#                                         movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_tt_tt_1                3054.0
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_tt_tt_1                1238.0
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0      2009.0
# 1  English     USA          PG-13  300000000.0      2007.0
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes
# 0                   936.0         7.9          1.78                 33000
# 1                  5000.0         7.1          2.35                     0

# %% [markdown]
# ### Select the Columns

# %%
df_init.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
dffb_init.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
# Work dataframe copies
df = df_init.copy()
dffb = dffb_init.copy()

# %% [markdown]
# **Select the features for df in desired order**

# %%
# Choose features in desired order
df = df.iloc[:,[6,20,3,2,15,10,22,23 ]]
df.head(2)
# Out:
#      imdb_id      title  \
# 0  tt0114709  Toy Story
# 1  tt0113497    Jumanji
#
#                                                                   genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {...
#
#      budget      revenue popularity  vote_average  vote_count
# 0  30000000  373554033.0  21.946943           7.7      5415.0
# 1  65000000  262797249.0  17.015539           6.9      2413.0

# %% [markdown]
# **Create 'imdb_id' feature for dffb**

# %% [markdown]
# dffb dataframe does not have 'imdb_id' column, but we can create it from 'movie_imdb_link'.
#
# Let's do that now.

# %%
# Create new dataframe from split parts of link
iid = dffb['movie_imdb_link'].str.split('/',expand=True)
iid.head(2)
# Out:
#        0 1             2      3          4                 5
# 0  http:    www.imdb.com  title  tt0499549  ?ref_=fn_tt_tt_1
# 1  http:    www.imdb.com  title  tt0449088  ?ref_=fn_tt_tt_1

# %%
# Column '4' is what we need
iid[4].head(2)
# Out:
# 0    tt0499549
# 1    tt0449088
# Name: 4, dtype: object

# %%
# Add this column into dffb dataframe
dffb['imdb_id'] = iid[4]
dffb.head(2)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
#
#   actor_1_name                                movie_title  num_voted_users  \
# 0  CCH Pounder                                    Avatar            886204
# 1  Johnny Depp  Pirates of the Caribbean: At World's End            471220
#
#    cast_total_facebook_likes    actor_3_name  facenumber_in_poster  \
# 0                       4834       Wes Studi                   0.0
# 1                      48350  Jack Davenport                   0.0
#
#                                                   plot_keywords  \
# 0                        avatar|future|marine|native|paraplegic
# 1  goddess|marriage ceremony|marriage proposal|pirate|singapore
#
#                                         movie_imdb_link  num_user_for_reviews  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_tt_tt_1                3054.0
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_tt_tt_1                1238.0
#
#   language country content_rating       budget  title_year  \
# 0  English     USA          PG-13  237000000.0      2009.0
# 1  English     USA          PG-13  300000000.0      2007.0
#
#    actor_2_facebook_likes  imdb_score  aspect_ratio  movie_facebook_likes  \
# 0                   936.0         7.9          1.78                 33000
# 1                  5000.0         7.1          2.35                     0
#
#      imdb_id
# 0  tt0499549
# 1  tt0449088

# %% [markdown]
# **Select the features for dffb in desired order**

# %%
dffb.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'imdb_id'],
#       dtype='object')

# %%
# Choose features in desired order
dffb = dffb.iloc[:,[28, 11, 21, 9, 25, 27, 1, 4, 10, 7, 6, 24, 14, 5]]
dffb.head(2)
# Out:
#      imdb_id                                movie_title content_rating  \
# 0  tt0499549                                    Avatar           PG-13
# 1  tt0449088  Pirates of the Caribbean: At World's End           PG-13
#
#                             genres  imdb_score  movie_facebook_likes  \
# 0  Action|Adventure|Fantasy|Sci-Fi         7.9                 33000
# 1         Action|Adventure|Fantasy         7.1                     0
#
#     director_name  director_facebook_likes actor_1_name  \
# 0   James Cameron                      0.0  CCH Pounder
# 1  Gore Verbinski                    563.0  Johnny Depp
#
#    actor_1_facebook_likes      actor_2_name  actor_2_facebook_likes  \
# 0                  1000.0  Joel David Moore                   936.0
# 1                 40000.0     Orlando Bloom                  5000.0
#
#      actor_3_name  actor_3_facebook_likes
# 0       Wes Studi                   855.0
# 1  Jack Davenport                  1000.0

# %%
# Check dimensions of dataframes
print(df.shape)
print(dffb.shape)
# Out:
# (45466, 8)
# (5043, 14)

# %% [markdown]
# ## Data Cleanup & Analysis - Transform

# %% [markdown]
# ### Renaming columns

# %%
df.columns
# Out:
# Index(['imdb_id', 'title', 'genres', 'budget', 'revenue', 'popularity',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# No need to rename columns in df.
#
# But we will need to do some renaming of columns in dffb.

# %%
dffb.columns
# Out:
# Index(['imdb_id', 'movie_title', 'content_rating', 'genres', 'imdb_score',
#        'movie_facebook_likes', 'director_name', 'director_facebook_likes',
#        'actor_1_name', 'actor_1_facebook_likes', 'actor_2_name',
#        'actor_2_facebook_likes', 'actor_3_name', 'actor_3_facebook_likes'],
#       dtype='object')

# %%
dffb = dffb.rename(columns={'content_rating': 'rating', 'movie_facebook_likes': 'movie_likes', 'director_name': 'director', 
                     'director_facebook_likes': 'director_likes', 'actor_1_name': 'actor_1', 
                     'actor_1_facebook_likes': 'actor_1_likes', 'actor_2_name': 'actor_2', 'actor_2_facebook_likes':
                     'actor_2_likes', 'actor_3_name': 'actor_3', 'actor_3_facebook_likes': 'actor_3_likes',
                     'movie_title': 'title'})
dffb.head(2)
# Out:
#      imdb_id                                      title rating  \
# 0  tt0499549                                    Avatar   PG-13
# 1  tt0449088  Pirates of the Caribbean: At World's End   PG-13
#
#                             genres  imdb_score  movie_likes        director  \
# 0  Action|Adventure|Fantasy|Sci-Fi         7.9        33000   James Cameron
# 1         Action|Adventure|Fantasy         7.1            0  Gore Verbinski
#
#    director_likes      actor_1  actor_1_likes           actor_2  \
# 0             0.0  CCH Pounder         1000.0  Joel David Moore
# 1           563.0  Johnny Depp        40000.0     Orlando Bloom
#
#    actor_2_likes         actor_3  actor_3_likes
# 0          936.0       Wes Studi          855.0
# 1         5000.0  Jack Davenport         1000.0

# %% [markdown]
# ### Checking for NaNs

# %%
df.isna().sum()
# Out:
# imdb_id         17
# title            6
# genres           0
# budget           0
# revenue          6
# popularity       5
# vote_average     6
# vote_count       6
# dtype: int64

# %% [markdown]
# We do not want to keep records without 'imdb_id'. We are going to remove them.

# %%
# Drop records 
df = df.dropna(subset=['imdb_id'])
df.isna().sum()
# Out:
# imdb_id         0
# title           6
# genres          0
# budget          0
# revenue         6
# popularity      5
# vote_average    6
# vote_count      6
# dtype: int64

# %% [markdown]
# Let's check records with 'title' equal NaN

# %%
df[df['title'].isna()]
# Out:
#          imdb_id title  \
# 19729  tt0113002   NaN
# 19730          0   NaN
# 29502  tt2423504   NaN
# 29503          0   NaN
# 35586  tt2622826   NaN
# 35587          0   NaN
#
#                                                                       genres  \
# 19729  [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'i...
# 19730  [{'name': 'Carousel Productions', 'id': 11176}, {'name': 'Vision V...
# 29502  [{'id': 16, 'name': 'Animation'}, {'id': 878, 'name': 'Science Fic...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'GoHands', 'id': 7759},...
# 35586  [{'id': 10770, 'name': 'TV Movie'}, {'id': 28, 'name': 'Action'}, ...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'name': 'Pulser Producti...
#
#                                  budget  revenue             popularity  \
# 19729                                 0      NaN                    NaN
# 19730  /ff9qCepilowshEtG2GYWwzt2bs4.jpg      NaN                    NaN
# 29502                                 0      NaN                    NaN
# 29503  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg      NaN                    NaN
# 35586                                 0      NaN                    NaN
# 35587  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg      NaN  Beware Of Frost Bites
#
#        vote_average  vote_count
# 19729           NaN         NaN
# 19730           NaN         NaN
# 29502           NaN         NaN
# 29503           NaN         NaN
# 35586           NaN         NaN
# 35587           NaN         NaN

# %% [markdown]
# We can remove these records as well.

# %%
# Drop records
df = df.dropna()
df.isna().sum()
# Out:
# imdb_id         0
# title           0
# genres          0
# budget          0
# revenue         0
# popularity      0
# vote_average    0
# vote_count      0
# dtype: int64

# %% [markdown]
# Checking dffb for NaNs

# %%
# Checking nulls
dffb.isna().sum()
# Out:
# imdb_id             0
# title               0
# rating            303
# genres              0
# imdb_score          0
# movie_likes         0
# director          104
# director_likes    104
# actor_1             7
# actor_1_likes       7
# actor_2            13
# actor_2_likes      13
# actor_3            23
# actor_3_likes      23
# dtype: int64

# %% [markdown]
# We can keep all these records.

# %% [markdown]
# ### Checking duplicates

# %%
# Count records with duplicate 'imdb_id'
df.duplicated(subset=['imdb_id']).sum()
# Out:
# 30

# %% [markdown]
# List all duplicate records to help us decide which to keep.

# %%
# List all duplicate records (keep=False)
df[df.duplicated(subset=['imdb_id'], keep=False)].sort_values('imdb_id')
# Out:
#          imdb_id                                        title  \
# 38871  tt0022537                                   The Viking
# 16167  tt0022537                                   The Viking
# 949    tt0022879                           A Farewell to Arms
# 15074  tt0022879                           A Farewell to Arms
# 838    tt0046468                                         Wife
# 30001  tt0046468                                         Wife
# 7345   tt0062229                                  Le Samouraï
# 9165   tt0062229                                  Le Samouraï
# 29374  tt0067306                                    King Lear
# 15702  tt0067306                                    King Lear
# 19890  tt0080000                                  The Tempest
# 21165  tt0080000                                  The Tempest
# 5710   tt0082992                              Rich and Famous
# 20899  tt0082992                              Rich and Famous
# 13603  tt0084387               Nana, the True Key of Pleasure
# 28860  tt0084387               Nana, the True Key of Pleasure
# 26625  tt0100361                     The Phantom of the Opera
# 9576   tt0100361                     The Phantom of the Opera
# 1465   tt0111613                                  The Promise
# 676    tt0111613                                  The Promise
# 13946  tt0127834                         Seven Years Bad Luck
# 40276  tt0127834                         Seven Years Bad Luck
# 33743  tt0157472                                Clockstoppers
# 5130   tt0157472                                Clockstoppers
# 13220  tt0173769             Why We Fight: Divide and Conquer
# 35798  tt0173769             Why We Fight: Divide and Conquer
# 4114   tt0235679                Pokémon: Spell of the Unknown
# 44821  tt0235679                Pokémon: Spell of the Unknown
# 33826  tt0270288              Confessions of a Dangerous Mind
# 5865   tt0270288              Confessions of a Dangerous Mind
# 5535   tt0287635  Pokémon 4Ever: Celebi - Voice of the Forest
# 44826  tt0287635  Pokémon 4Ever: Celebi - Voice of the Forest
# 8068   tt0295682                                  The Warrior
# 9327   tt0295682                                  The Warrior
# 24844  tt0446676                                         Deal
# 14012  tt0446676                                         Deal
# 12066  tt0454792                                       Bubble
# 10419  tt0454792                                       Bubble
# 14000  tt0499456                             Days of Darkness
# 22151  tt0499456                             Days of Darkness
# 15765  tt0499537                                      Offside
# 11342  tt0499537                                      Offside
# 16764  tt1180333                                     Blackout
# 13375  tt1180333                                     Blackout
# 13261  tt1180333                                     Blackout
# 23044  tt1327820                                  Brotherhood
# 17229  tt1327820                                  Brotherhood
# 20843  tt1701210                                   Black Gold
# 11155  tt1701210                                   Black Gold
# 2564   tt1736049                         A Place at the Table
# 21116  tt1736049                         A Place at the Table
# 19925  tt1821641                                 The Congress
# 21854  tt1821641                                 The Congress
# 23534  tt2018086                         Camille Claudel 1915
# 4356   tt2018086                         Camille Claudel 1915
# 45265  tt2121382                                Force Majeure
# 24164  tt2121382                                Force Majeure
# 40040  tt2818654                        Cemetery of Splendour
# 33184  tt2818654                        Cemetery of Splendour
#
#                                                                       genres  \
# 38871  [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id':...
# 16167  [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id':...
# 949    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, {'...
# 15074  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, {'...
# 838                                            [{'id': 18, 'name': 'Drama'}]
# 30001                                          [{'id': 18, 'name': 'Drama'}]
# 7345   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': ...
# 9165   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': ...
# 29374        [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'name': 'Foreign'}]
# 15702        [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'name': 'Foreign'}]
# 19890  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'name': 'Drama'}, {'id'...
# 21165  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'name': 'Drama'}, {'id'...
# 5710                                           [{'id': 18, 'name': 'Drama'}]
# 20899                                          [{'id': 18, 'name': 'Drama'}]
# 13603            [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]
# 28860            [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]
# 26625  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name': 'Horror'}, {'id':...
# 9576   [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name': 'Horror'}, {'id':...
# 1465         [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]
# 676          [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]
# 13946                                         [{'id': 35, 'name': 'Comedy'}]
# 40276                                         [{'id': 35, 'name': 'Comedy'}]
# 33743  [{'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'},...
# 5130   [{'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'},...
# 13220                                    [{'id': 99, 'name': 'Documentary'}]
# 35798                                    [{'id': 99, 'name': 'Documentary'}]
# 4114   [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {...
# 44821  [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {...
# 33826  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}, {'id':...
# 5865   [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}, {'id':...
# 5535   [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {...
# 44826  [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {...
# 8068   [{'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'},...
# 9327   [{'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'},...
# 24844            [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]
# 14012            [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]
# 12066  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}, {'id': ...
# 10419  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}, {'id': ...
# 14000  [{'id': 28, 'name': 'Action'}, {'id': 27, 'name': 'Horror'}, {'id'...
# 22151  [{'id': 28, 'name': 'Action'}, {'id': 27, 'name': 'Horror'}, {'id'...
# 15765  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}, {'id':...
# 11342  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}, {'id':...
# 16764      [{'id': 53, 'name': 'Thriller'}, {'id': 9648, 'name': 'Mystery'}]
# 13375      [{'id': 53, 'name': 'Thriller'}, {'id': 9648, 'name': 'Mystery'}]
# 13261      [{'id': 53, 'name': 'Thriller'}, {'id': 9648, 'name': 'Mystery'}]
# 23044                                          [{'id': 18, 'name': 'Drama'}]
# 17229                                          [{'id': 18, 'name': 'Drama'}]
# 20843         [{'id': 12, 'name': 'Adventure'}, {'id': 18, 'name': 'Drama'}]
# 11155         [{'id': 12, 'name': 'Adventure'}, {'id': 18, 'name': 'Drama'}]
# 2564                                     [{'id': 99, 'name': 'Documentary'}]
# 21116                                    [{'id': 99, 'name': 'Documentary'}]
# 19925  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'name': 'Science Fiction...
# 21854  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'name': 'Science Fiction...
# 23534                                          [{'id': 18, 'name': 'Drama'}]
# 4356                                           [{'id': 18, 'name': 'Drama'}]
# 45265            [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]
# 24164            [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]
# 40040           [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name': 'Fantasy'}]
# 33184           [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name': 'Fantasy'}]
#
#          budget     revenue popularity  vote_average  vote_count
# 38871         0         0.0   0.002362           0.0         0.0
# 16167         0         0.0   0.002362           0.0         0.0
# 949           4        25.0   1.914697           6.2        29.0
# 15074         4        25.0   2.411191           6.2        29.0
# 838           0         0.0   0.096079           0.0         0.0
# 30001         0         0.0   0.619388           0.0         0.0
# 7345          0     39481.0   9.091288           7.9       187.0
# 9165          0     39481.0   9.091288           7.9       187.0
# 29374         0         0.0   0.187901           8.0         3.0
# 15702         0         0.0   0.187901           8.0         3.0
# 19890         0         0.0    1.8e-05           0.0         0.0
# 21165         0         0.0    1.8e-05           0.0         0.0
# 5710          0         0.0  12.180836           4.9         7.0
# 20899         0         0.0  10.396878           4.9         7.0
# 13603         0         0.0   1.276602           4.7         3.0
# 28860         0         0.0   1.276602           4.7         3.0
# 26625  10000000         0.0    0.43849           5.0         3.0
# 9576   10000000         0.0   0.441872           5.0         3.0
# 1465          0         0.0   0.122178           5.0         1.0
# 676           0         0.0   0.122178           5.0         1.0
# 13946         0         0.0   0.141558           5.6         4.0
# 40276         0         0.0   0.141558           5.6         4.0
# 33743  26000000  38793283.0   4.920175           4.9        90.0
# 5130   26000000  38793283.0   5.373623           4.9        89.0
# 13220         0         0.0   0.473322           5.0         1.0
# 35798         0         0.0   0.473322           5.0         1.0
# 4114   16000000  68411275.0  10.264597           6.0       143.0
# 44821  16000000  68411275.0   6.480376           6.0       144.0
# 33826  30000000  33013805.0   7.645827           6.6       281.0
# 5865   30000000  33013805.0  11.331072           6.6       281.0
# 5535          0  28023563.0   7.072301           5.7        82.0
# 44826         0  28023563.0   6.080108           5.7        82.0
# 8068          0         0.0   1.967992           6.3        15.0
# 9327          0         0.0   1.967992           6.3        15.0
# 24844         0         0.0   6.880365           5.2        22.0
# 14012         0         0.0   6.880365           5.2        22.0
# 12066   1600000         0.0   3.008299           6.4        36.0
# 10419   1600000         0.0   3.185256           6.4        36.0
# 14000         0         0.0   1.436085           5.0         5.0
# 22151         0         0.0   1.436085           5.0         5.0
# 15765      2500         0.0   1.529879           6.7        27.0
# 11342      2500         0.0    1.52896           6.7        27.0
# 16764         0         0.0   0.411949           6.7         3.0
# 13375         0         0.0   0.411949           6.7         3.0
# 13261         0         0.0   0.411949           6.7         3.0
# 23044         0         0.0   2.587911           7.1        21.0
# 17229         0         0.0   2.587911           7.1        21.0
# 20843  40000000   5446000.0   6.475665           5.9        77.0
# 11155  40000000   5446000.0   6.652197           5.9        77.0
# 2564          0         0.0   0.501046           6.9         7.0
# 21116         0         0.0   1.673307           6.9         7.0
# 19925         0    455815.0   8.534039           6.4       165.0
# 21854         0    455815.0   8.534039           6.4       165.0
# 23534   3512454    115860.0   0.110065           7.0        20.0
# 4356    3512454    115860.0   0.134014           7.0        20.0
# 45265         0   1359497.0  12.165685           6.8       255.0
# 24164         0   1359497.0  12.165685           6.8       255.0
# 40040    980000         0.0   2.535419           4.4        50.0
# 33184    980000         0.0   2.535419           4.4        50.0

# %% [markdown]
# We are going to drop duplicates except for the first occurrence.

# %%
# Drop duplicates
df = df.drop_duplicates(subset=['imdb_id'])
df.head(2)
# Out:
#      imdb_id      title  \
# 0  tt0114709  Toy Story
# 1  tt0113497    Jumanji
#
#                                                                   genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {...
#
#      budget      revenue popularity  vote_average  vote_count
# 0  30000000  373554033.0  21.946943           7.7      5415.0
# 1  65000000  262797249.0  17.015539           6.9      2413.0

# %%
# Check again for confirmation
df.duplicated(subset=['imdb_id']).sum()
# Out:
# 0

# %% [markdown]
# Duplicates for dffb.

# %%
# Count records with duplicate 'imdb_id'
dffb.duplicated(subset=['imdb_id']).sum()
# Out:
# 124

# %%
# List all duplicate records (keep=False)
dffb[dffb.duplicated(subset=['imdb_id'], keep=False)].sort_values('imdb_id')
# Out:
#         imdb_id                          title     rating  \
# 3711  tt0046672  20,000 Leagues Under the Sea    Approved
# 4894  tt0046672  20,000 Leagues Under the Sea    Approved
# 890   tt0056193                        Lolita   Not Rated
# 4256  tt0056193                        Lolita   Not Rated
# 4951  tt0063350      Night of the Living Dead     Unrated
# ...         ...                            ...        ...
# 3158  tt4178092                      The Gift           R
# 98    tt4262980           Godzilla Resurgence         NaN
# 204   tt4262980           Godzilla Resurgence         NaN
# 2562  tt4651520                      Bad Moms           R
# 2181  tt4651520                      Bad Moms           R
#
#                                      genres  imdb_score  movie_likes  \
# 3711  Adventure|Drama|Family|Fantasy|Sci-Fi         7.2            0
# 4894  Adventure|Drama|Family|Fantasy|Sci-Fi         7.2            0
# 890                     Crime|Drama|Romance         7.7            0
# 4256                    Crime|Drama|Romance         7.7            0
# 4951                   Drama|Horror|Mystery         8.0            0
# ...                                     ...         ...          ...
# 3158                       Mystery|Thriller         7.1        15000
# 98     Action|Adventure|Drama|Horror|Sci-Fi         8.2            0
# 204    Action|Adventure|Drama|Horror|Sci-Fi         8.2            0
# 2562                                 Comedy         6.7        18000
# 2181                                 Comedy         6.7        18000
#
#                director  director_likes        actor_1  actor_1_likes  \
# 3711  Richard Fleischer           130.0    James Mason          617.0
# 4894  Richard Fleischer           130.0    James Mason          618.0
# 890     Stanley Kubrick             0.0    James Mason          617.0
# 4256    Stanley Kubrick             0.0    James Mason          618.0
# 4951   George A. Romero             0.0   Judith O'Dea          125.0
# ...                 ...             ...            ...            ...
# 3158      Joel Edgerton             0.0  Busy Philipps         1000.0
# 98         Hideaki Anno            28.0  Mark Chinnery          544.0
# 204        Hideaki Anno            28.0  Mark Chinnery          544.0
# 2562          Jon Lucas            24.0     Mila Kunis        15000.0
# 2181          Jon Lucas            24.0     Mila Kunis        15000.0
#
#                 actor_2  actor_2_likes             actor_3  actor_3_likes
# 3711    Robert J. Wilke           53.0          Paul Lukas           51.0
# 4894    Robert J. Wilke           53.0          Paul Lukas           51.0
# 890     Shelley Winters          367.0        Lois Maxwell          177.0
# 4256    Shelley Winters          367.0        Lois Maxwell          177.0
# 4951        Duane Jones          108.0  S. William Hinzman           56.0
# ...                 ...            ...                 ...            ...
# 3158     Allison Tolman          562.0      Wendell Pierce          458.0
# 98    Shin'ya Tsukamoto          106.0        Atsuko Maeda           12.0
# 204   Shin'ya Tsukamoto          106.0        Atsuko Maeda           12.0
# 2562      Jay Hernandez         1000.0  Jada Pinkett Smith          851.0
# 2181      Jay Hernandez         1000.0  Jada Pinkett Smith          851.0
#
# [241 rows x 14 columns]

# %% [markdown]
# We are going to drop duplicates except for the first occurrence.

# %%
# Drop duplicates
dffb = dffb.drop_duplicates(subset=['imdb_id'])
dffb.head(2)
# Out:
#      imdb_id                                      title rating  \
# 0  tt0499549                                    Avatar   PG-13
# 1  tt0449088  Pirates of the Caribbean: At World's End   PG-13
#
#                             genres  imdb_score  movie_likes        director  \
# 0  Action|Adventure|Fantasy|Sci-Fi         7.9        33000   James Cameron
# 1         Action|Adventure|Fantasy         7.1            0  Gore Verbinski
#
#    director_likes      actor_1  actor_1_likes           actor_2  \
# 0             0.0  CCH Pounder         1000.0  Joel David Moore
# 1           563.0  Johnny Depp        40000.0     Orlando Bloom
#
#    actor_2_likes         actor_3  actor_3_likes
# 0          936.0       Wes Studi          855.0
# 1         5000.0  Jack Davenport         1000.0

# %%
# Check again for confirmation
dffb.duplicated(subset=['imdb_id']).sum()
# Out:
# 0

# %%
# Check dimensions of both dataframes
print(df.shape)
print(dffb.shape)
# Out:
# (45413, 8)
# (4919, 14)

# %% [markdown]
# ### Correcting Column 'title' in dffb

# %% [markdown]
# We have noticed that same movie titles are not exactly the same in both dataframes. It looks like a space at the end of the title.

# %%
dffb.loc[0, :]
# Out:
# imdb_id                                 tt0499549
# title                                     Avatar
# rating                                      PG-13
# genres            Action|Adventure|Fantasy|Sci-Fi
# imdb_score                                    7.9
# movie_likes                                 33000
# director                            James Cameron
# director_likes                                  0
# actor_1                               CCH Pounder
# actor_1_likes                                1000
# actor_2                          Joel David Moore
# actor_2_likes                                 936
# actor_3                                 Wes Studi
# actor_3_likes                                 855
# Name: 0, dtype: object

# %% [markdown]
# If we check only that records we can see \xa0 at the end. \xa0 is actually non-breaking space in Latin1 (ISO 8859-1), also chr(160). It should be replaced with a space.

# %%
dffb.loc[0, 'title']
# Out:
# 'Avatar\xa0'

# %%
df.loc[df['title'] == 'Avatar']
# Out:
#          imdb_id   title  \
# 14551  tt0499549  Avatar
#
#                                                                       genres  \
# 14551  [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'...
#
#           budget       revenue  popularity  vote_average  vote_count
# 14551  237000000  2.787965e+09  185.070892           7.2     12114.0

# %%
df.loc[14551, 'title']
# Out:
# 'Avatar'

# %% [markdown]
# So, to make titles in the same format in both dataframes, we will replace \xa0 with a space.

# %%
dffb['title'] = dffb['title'].str.split().str.join(' ')
dffb.loc[0, 'title']
# Out:
# 'Avatar'

# %% [markdown]
# It looks we are OK now.

# %% [markdown]
# ### Reformating Columns 'genres' in Both Dataframes

# %% [markdown]
# **dataframe df**

# %%
df.head(2)
# Out:
#      imdb_id      title  \
# 0  tt0114709  Toy Story
# 1  tt0113497    Jumanji
#
#                                                                   genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {...
#
#      budget      revenue popularity  vote_average  vote_count
# 0  30000000  373554033.0  21.946943           7.7      5415.0
# 1  65000000  262797249.0  17.015539           6.9      2413.0

# %% [markdown]
# The field in 'genres' is a list of dictionaries. We want to create the string of genre names separated with comma.

# %%
df.loc[0, 'genres']
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
# Function to reformat 'genres'
def genres(gl):
    o = ""
    for d in gl:
        o += f"{d['name']} "
    return ', '.join(o.split(' ')[:-1])

# %%
# Apply function to dataframe
df['genres'] = df['genres'].apply(genres)
df.head(2)
# Out:
#      imdb_id      title                      genres    budget      revenue  \
# 0  tt0114709  Toy Story   Animation, Comedy, Family  30000000  373554033.0
# 1  tt0113497    Jumanji  Adventure, Fantasy, Family  65000000  262797249.0
#
#   popularity  vote_average  vote_count
# 0  21.946943           7.7      5415.0
# 1  17.015539           6.9      2413.0

# %% [markdown]
# **dataframe dffb**

# %% [markdown]
# We need to replace character '|' with ', '

# %%
dffb.loc[0, 'genres']
# Out:
# 'Action|Adventure|Fantasy|Sci-Fi'

# %%
dffb['genres'] = dffb['genres'].apply(lambda x: ', '.join(x.split('|')))
dffb.head(2)
# Out:
#      imdb_id                                     title rating  \
# 0  tt0499549                                    Avatar  PG-13
# 1  tt0449088  Pirates of the Caribbean: At World's End  PG-13
#
#                                genres  imdb_score  movie_likes  \
# 0  Action, Adventure, Fantasy, Sci-Fi         7.9        33000
# 1          Action, Adventure, Fantasy         7.1            0
#
#          director  director_likes      actor_1  actor_1_likes  \
# 0   James Cameron             0.0  CCH Pounder         1000.0
# 1  Gore Verbinski           563.0  Johnny Depp        40000.0
#
#             actor_2  actor_2_likes         actor_3  actor_3_likes
# 0  Joel David Moore          936.0       Wes Studi          855.0
# 1     Orlando Bloom         5000.0  Jack Davenport         1000.0

# %% [markdown]
# ## Store Data - Load

# %% [markdown]
# We are going to store our data to MongoDB. These are the steps:
#
# * Connect to database and declare collection
#
# * Create dictionary from dataframe df
#
# * Insert this dictionary to database collection
#
# * Prepare special dictionaries from dataframe dffb
#
# * Update previously created collection with these dictionaries
#
# * Confirm data has been added by querying the collection

# %% [markdown]
# **Connect to database and declare collection**

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Declare the database
db = client.movies_db

# Declare the collection
coll = db.movies

# %% [markdown]
# **Create dictionary from dataframe df**

# %%
df = df.reset_index(drop=True)
df.head(2)
# Out:
#      imdb_id      title                      genres    budget      revenue  \
# 0  tt0114709  Toy Story   Animation, Comedy, Family  30000000  373554033.0
# 1  tt0113497    Jumanji  Adventure, Fantasy, Family  65000000  262797249.0
#
#   popularity  vote_average  vote_count
# 0  21.946943           7.7      5415.0
# 1  17.015539           6.9      2413.0

# %% [markdown]
# Use 'to_dict' to convert the dataframe to a dictionary.

# %%
# Convert dataframe to dictionary
df_dict = df.to_dict('records')

# %%
df_dict
# Out:
# [{'imdb_id': 'tt0114709',
#   'title': 'Toy Story',
#   'genres': 'Animation, Comedy, Family',
#   'budget': '30000000',
#   'revenue': 373554033.0,
#   'popularity': '21.946943',
#   'vote_average': 7.7,
#   'vote_count': 5415.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75614f')},
#  {'imdb_id': 'tt0113497',
#   'title': 'Jumanji',
#   'genres': 'Adventure, Fantasy, Family',
#   'budget': '65000000',
#   'revenue': 262797249.0,
#   'popularity': '17.015539',
#   'vote_average': 6.9,
#   'vote_count': 2413.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756150')},
#  {'imdb_id': 'tt0113228',
#   'title': 'Grumpier Old Men',
#   'genres': 'Romance, Comedy',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '11.7129',
#   'vote_average': 6.5,
#   'vote_count': 92.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756151')},
#  {'imdb_id': 'tt0114885',
#   'title': 'Waiting to Exhale',
#   'genres': 'Comedy, Drama, Romance',
#   'budget': '16000000',
#   'revenue': 81452156.0,
#   'popularity': '3.859495',
#   'vote_average': 6.1,
#   'vote_count': 34.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756152')},
#  {'imdb_id': 'tt0113041',
#   'title': 'Father of the Bride Part II',
#   'genres': 'Comedy',
#   'budget': '0',
#   'revenue': 76578911.0,
#   'popularity': '8.387519',
#   'vote_average': 5.7,
#   'vote_count': 173.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756153')},
#  {'imdb_id': 'tt0113277',
#   'title': 'Heat',
#   'genres': 'Action, Crime, Drama, Thriller',
#   'budget': '60000000',
#   'revenue': 187436818.0,
#   'popularity': '17.924927',
#   'vote_average': 7.7,
#   'vote_count': 1886.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756154')},
#  {'imdb_id': 'tt0114319',
#   'title': 'Sabrina',
#   'genres': 'Comedy, Romance',
#   'budget': '58000000',
#   'revenue': 0.0,
#   'popularity': '6.677277',
#   'vote_average': 6.2,
#   'vote_count': 141.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756155')},
#  {'imdb_id': 'tt0112302',
#   'title': 'Tom and Huck',
#   'genres': 'Action, Adventure, Drama, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '2.561161',
#   'vote_average': 5.4,
#   'vote_count': 45.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756156')},
#  {'imdb_id': 'tt0114576',
#   'title': 'Sudden Death',
#   'genres': 'Action, Adventure, Thriller',
#   'budget': '35000000',
#   'revenue': 64350171.0,
#   'popularity': '5.23158',
#   'vote_average': 5.5,
#   'vote_count': 174.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756157')},
#  {'imdb_id': 'tt0113189',
#   'title': 'GoldenEye',
#   'genres': 'Adventure, Action, Thriller',
#   'budget': '58000000',
#   'revenue': 352194034.0,
#   'popularity': '14.686036',
#   'vote_average': 6.6,
#   'vote_count': 1194.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756158')},
#  {'imdb_id': 'tt0112346',
#   'title': 'The American President',
#   'genres': 'Comedy, Drama, Romance',
#   'budget': '62000000',
#   'revenue': 107879496.0,
#   'popularity': '6.318445',
#   'vote_average': 6.5,
#   'vote_count': 199.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756159')},
#  {'imdb_id': 'tt0112896',
#   'title': 'Dracula: Dead and Loving It',
#   'genres': 'Comedy, Horror',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '5.430331',
#   'vote_average': 5.7,
#   'vote_count': 210.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75615a')},
#  {'imdb_id': 'tt0112453',
#   'title': 'Balto',
#   'genres': 'Family, Animation, Adventure',
#   'budget': '0',
#   'revenue': 11348324.0,
#   'popularity': '12.140733',
#   'vote_average': 7.1,
#   'vote_count': 423.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75615b')},
#  {'imdb_id': 'tt0113987',
#   'title': 'Nixon',
#   'genres': 'History, Drama',
#   'budget': '44000000',
#   'revenue': 13681765.0,
#   'popularity': '5.092',
#   'vote_average': 7.1,
#   'vote_count': 72.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75615c')},
#  {'imdb_id': 'tt0112760',
#   'title': 'Cutthroat Island',
#   'genres': 'Action, Adventure',
#   'budget': '98000000',
#   'revenue': 10017322.0,
#   'popularity': '7.284477',
#   'vote_average': 5.7,
#   'vote_count': 137.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75615d')},
#  {'imdb_id': 'tt0112641',
#   'title': 'Casino',
#   'genres': 'Drama, Crime',
#   'budget': '52000000',
#   'revenue': 116112375.0,
#   'popularity': '10.137389',
#   'vote_average': 7.8,
#   'vote_count': 1343.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75615e')},
#  {'imdb_id': 'tt0114388',
#   'title': 'Sense and Sensibility',
#   'genres': 'Drama, Romance',
#   'budget': '16500000',
#   'revenue': 135000000.0,
#   'popularity': '10.673167',
#   'vote_average': 7.2,
#   'vote_count': 364.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75615f')},
#  {'imdb_id': 'tt0113101',
#   'title': 'Four Rooms',
#   'genres': 'Crime, Comedy',
#   'budget': '4000000',
#   'revenue': 4300000.0,
#   'popularity': '9.026586',
#   'vote_average': 6.5,
#   'vote_count': 539.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756160')},
#  {'imdb_id': 'tt0112281',
#   'title': 'Ace Ventura: When Nature Calls',
#   'genres': 'Crime, Comedy, Adventure',
#   'budget': '30000000',
#   'revenue': 212385533.0,
#   'popularity': '8.205448',
#   'vote_average': 6.1,
#   'vote_count': 1128.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756161')},
#  {'imdb_id': 'tt0113845',
#   'title': 'Money Train',
#   'genres': 'Action, Comedy, Crime',
#   'budget': '60000000',
#   'revenue': 35431113.0,
#   'popularity': '7.337906',
#   'vote_average': 5.4,
#   'vote_count': 224.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756162')},
#  {'imdb_id': 'tt0113161',
#   'title': 'Get Shorty',
#   'genres': 'Comedy, Thriller, Crime',
#   'budget': '30250000',
#   'revenue': 115101622.0,
#   'popularity': '12.669608',
#   'vote_average': 6.4,
#   'vote_count': 305.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756163')},
#  {'imdb_id': 'tt0112722',
#   'title': 'Copycat',
#   'genres': 'Drama, Thriller',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '10.701801',
#   'vote_average': 6.5,
#   'vote_count': 199.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756164')},
#  {'imdb_id': 'tt0112401',
#   'title': 'Assassins',
#   'genres': 'Action, Adventure, Crime, Thriller',
#   'budget': '50000000',
#   'revenue': 30303072.0,
#   'popularity': '11.065939',
#   'vote_average': 6.0,
#   'vote_count': 394.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756165')},
#  {'imdb_id': 'tt0114168',
#   'title': 'Powder',
#   'genres': 'Drama, Fantasy, Science, Fiction, Thriller',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '12.133094',
#   'vote_average': 6.3,
#   'vote_count': 143.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756166')},
#  {'imdb_id': 'tt0113627',
#   'title': 'Leaving Las Vegas',
#   'genres': 'Drama, Romance',
#   'budget': '3600000',
#   'revenue': 49800000.0,
#   'popularity': '10.332025',
#   'vote_average': 7.1,
#   'vote_count': 365.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756167')},
#  {'imdb_id': 'tt0114057',
#   'title': 'Othello',
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.845899',
#   'vote_average': 7.0,
#   'vote_count': 33.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756168')},
#  {'imdb_id': 'tt0114011',
#   'title': 'Now and Then',
#   'genres': 'Comedy, Drama, Family',
#   'budget': '12000000',
#   'revenue': 27400000.0,
#   'popularity': '8.681325',
#   'vote_average': 6.6,
#   'vote_count': 91.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756169')},
#  {'imdb_id': 'tt0114117',
#   'title': 'Persuasion',
#   'genres': 'Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '2.228434',
#   'vote_average': 7.4,
#   'vote_count': 36.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75616a')},
#  {'imdb_id': 'tt0112682',
#   'title': 'The City of Lost Children',
#   'genres': 'Fantasy, Science, Fiction, Adventure',
#   'budget': '18000000',
#   'revenue': 1738611.0,
#   'popularity': '9.822423',
#   'vote_average': 7.6,
#   'vote_count': 308.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75616b')},
#  {'imdb_id': 'tt0115012',
#   'title': 'Shanghai Triad',
#   'genres': 'Drama, Crime',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.100915',
#   'vote_average': 6.5,
#   'vote_count': 17.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75616c')},
#  {'imdb_id': 'tt0112792',
#   'title': 'Dangerous Minds',
#   'genres': 'Drama, Crime',
#   'budget': '0',
#   'revenue': 180000000.0,
#   'popularity': '9.481338',
#   'vote_average': 6.4,
#   'vote_count': 249.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75616d')},
#  {'imdb_id': 'tt0114746',
#   'title': 'Twelve Monkeys',
#   'genres': 'Science, Fiction, Thriller, Mystery',
#   'budget': '29500000',
#   'revenue': 168840000.0,
#   'popularity': '12.297305',
#   'vote_average': 7.4,
#   'vote_count': 2470.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75616e')},
#  {'imdb_id': 'tt0114952',
#   'title': 'Wings of Courage',
#   'genres': 'Romance, Adventure',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.745542',
#   'vote_average': 6.8,
#   'vote_count': 4.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75616f')},
#  {'imdb_id': 'tt0112431',
#   'title': 'Babe',
#   'genres': 'Fantasy, Drama, Comedy, Family',
#   'budget': '30000000',
#   'revenue': 254134910.0,
#   'popularity': '14.404764',
#   'vote_average': 6.0,
#   'vote_count': 756.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756170')},
#  {'imdb_id': 'tt0112637',
#   'title': 'Carrington',
#   'genres': 'History, Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.493361',
#   'vote_average': 6.4,
#   'vote_count': 16.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756171')},
#  {'imdb_id': 'tt0112818',
#   'title': 'Dead Man Walking',
#   'genres': 'Drama',
#   'budget': '11000000',
#   'revenue': 39363635.0,
#   'popularity': '6.891317',
#   'vote_average': 7.3,
#   'vote_count': 350.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756172')},
#  {'imdb_id': 'tt0112286',
#   'title': 'Across the Sea of Time',
#   'genres': 'Adventure, History, Drama, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.114469',
#   'vote_average': 3.5,
#   'vote_count': 2.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756173')},
#  {'imdb_id': 'tt0113442',
#   'title': 'It Takes Two',
#   'genres': 'Comedy, Family, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '7.777735',
#   'vote_average': 6.1,
#   'vote_count': 149.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756174')},
#  {'imdb_id': 'tt0112697',
#   'title': 'Clueless',
#   'genres': 'Comedy, Drama, Romance',
#   'budget': '12000000',
#   'revenue': 0.0,
#   'popularity': '9.882383',
#   'vote_average': 6.9,
#   'vote_count': 828.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756175')},
#  {'imdb_id': 'tt0112749',
#   'title': 'Cry, the Beloved Country',
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 676525.0,
#   'popularity': '0.894647',
#   'vote_average': 6.7,
#   'vote_count': 13.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756176')},
#  {'imdb_id': 'tt0114279',
#   'title': 'Richard III',
#   'genres': 'Drama, War',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '4.561387',
#   'vote_average': 6.9,
#   'vote_count': 50.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756177')},
#  {'imdb_id': 'tt0112819',
#   'title': 'Dead Presidents',
#   'genres': 'Action, Crime, Drama, History',
#   'budget': '10000000',
#   'revenue': 0.0,
#   'popularity': '9.87957',
#   'vote_average': 6.6,
#   'vote_count': 80.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756178')},
#  {'imdb_id': 'tt0114272',
#   'title': 'Restoration',
#   'genres': 'Drama, Romance',
#   'budget': '19000000',
#   'revenue': 0.0,
#   'popularity': '10.979269',
#   'vote_average': 6.3,
#   'vote_count': 30.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d756179')},
#  {'imdb_id': 'tt0113855',
#   'title': 'Mortal Kombat',
#   'genres': 'Action, Fantasy',
#   'budget': '18000000',
#   'revenue': 122195920.0,
#   'popularity': '10.870138',
#   'vote_average': 5.4,
#   'vote_count': 452.0,
#   '_id': ObjectId('5ecd7a289bbb609a3d75617a')},
#  {'imdb_id': 'tt0114681',
#   'title': 'To Die For',
#   'genres': 'Fantasy, Drama, Comedy, Thriller',
#   'budget': '20000000',
#   'revenue': 21284514.0,
#   'popularity': '10.448481',
#   'vote_average': 6.7,
#   'vote_count': 177.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75617b')},
#  {'imdb_id': 'tt0113347',
#   'title': 'How To Make An American Quilt',
#   'genres': 'Drama, Romance',
#   'budget': '10000000',
#   'revenue': 23574130.0,
#   'popularity': '4.485958',
#   'vote_average': 6.5,
#   'vote_count': 38.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75617c')},
#  {'imdb_id': 'tt0114369',
#   'title': 'Se7en',
#   'genres': 'Crime, Mystery, Thriller',
#   'budget': '33000000',
#   'revenue': 327311859.0,
#   'popularity': '18.45743',
#   'vote_average': 8.1,
#   'vote_count': 5915.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75617d')},
#  {'imdb_id': 'tt0114148',
#   'title': 'Pocahontas',
#   'genres': 'Adventure, Animation, Drama, Family',
#   'budget': '55000000',
#   'revenue': 346079773.0,
#   'popularity': '13.280069',
#   'vote_average': 6.7,
#   'vote_count': 1509.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75617e')},
#  {'imdb_id': 'tt0114916',
#   'title': 'When Night Is Falling',
#   'genres': 'Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '3.302524',
#   'vote_average': 5.9,
#   'vote_count': 10.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75617f')},
#  {'imdb_id': 'tt0114814',
#   'title': 'The Usual Suspects',
#   'genres': 'Drama, Crime, Thriller',
#   'budget': '6000000',
#   'revenue': 23341568.0,
#   'popularity': '16.302466',
#   'vote_average': 8.1,
#   'vote_count': 3334.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756180')},
#  {'imdb_id': 'tt0109950',
#   'title': 'Guardian Angel',
#   'genres': 'Action, Thriller, Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.595949',
#   'vote_average': 6.3,
#   'vote_count': 3.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756181')},
#  {'imdb_id': 'tt0113819',
#   'title': 'Mighty Aphrodite',
#   'genres': 'Comedy, Romance',
#   'budget': '15000000',
#   'revenue': 6700000.0,
#   'popularity': '15.899134',
#   'vote_average': 6.7,
#   'vote_count': 145.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756182')},
#  {'imdb_id': 'tt0110299',
#   'title': 'Lamerica',
#   'genres': 'Drama, Foreign',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.361286',
#   'vote_average': 7.7,
#   'vote_count': 11.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756183')},
#  {'imdb_id': 'tt0112499',
#   'title': 'The Big Green',
#   'genres': 'Action, Adventure, Comedy, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '5.982764',
#   'vote_average': 5.2,
#   'vote_count': 41.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756184')},
#  {'imdb_id': 'tt0113158',
#   'title': 'Georgia',
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '4.093443',
#   'vote_average': 6.1,
#   'vote_count': 15.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756185')},
#  {'imdb_id': 'tt0113541',
#   'title': 'Kids of the Round Table',
#   'genres': '',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.307075',
#   'vote_average': 3.0,
#   'vote_count': 1.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756186')},
#  {'imdb_id': 'tt0113321',
#   'title': 'Home for the Holidays',
#   'genres': 'Comedy, Drama, Romance',
#   'budget': '0',
#   'revenue': 17519169.0,
#   'popularity': '8.416802',
#   'vote_average': 6.3,
#   'vote_count': 39.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756187')},
#  {'imdb_id': 'tt0110877',
#   'title': 'The Postman',
#   'genres': 'Comedy, Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '10.168437',
#   'vote_average': 7.6,
#   'vote_count': 181.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756188')},
#  {'imdb_id': 'tt0112714',
#   'title': 'The Confessional',
#   'genres': 'Thriller, Drama, Mystery',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.120789',
#   'vote_average': 6.5,
#   'vote_count': 2.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756189')},
#  {'imdb_id': 'tt0113419',
#   'title': 'The Indian in the Cupboard',
#   'genres': 'Adventure, Family, Fantasy',
#   'budget': '45000000',
#   'revenue': 0.0,
#   'popularity': '10.673296',
#   'vote_average': 5.9,
#   'vote_count': 136.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75618a')},
#  {'imdb_id': 'tt0116260',
#   'title': 'Eye for an Eye',
#   'genres': 'Drama, Thriller',
#   'budget': '20000000',
#   'revenue': 0.0,
#   'popularity': '4.733526',
#   'vote_average': 5.8,
#   'vote_count': 65.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75618b')},
#  {'imdb_id': 'tt0113862',
#   'title': "Mr. Holland's Opus",
#   'genres': 'Music, Drama, Family',
#   'budget': '0',
#   'revenue': 106269971.0,
#   'popularity': '7.137117',
#   'vote_average': 6.9,
#   'vote_count': 115.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75618c')},
#  {'imdb_id': 'tt0116126',
#   'title': "Don't Be a Menace to South Central While Drinking Your Juice in the Hood",
#   'genres': 'Comedy',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '11.700115',
#   'vote_average': 6.2,
#   'vote_count': 192.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75618d')},
#  {'imdb_id': 'tt0118002',
#   'title': 'Two If by Sea',
#   'genres': 'Comedy, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '2.174487',
#   'vote_average': 4.5,
#   'vote_count': 14.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75618e')},
#  {'imdb_id': 'tt0115683',
#   'title': 'Bio-Dome',
#   'genres': 'Comedy',
#   'budget': '15000000',
#   'revenue': 0.0,
#   'popularity': '6.387469',
#   'vote_average': 4.4,
#   'vote_count': 110.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75618f')},
#  {'imdb_id': 'tt0116839',
#   'title': 'Lawnmower Man 2: Beyond Cyberspace',
#   'genres': 'Action, Science, Fiction',
#   'budget': '0',
#   'revenue': 2409225.0,
#   'popularity': '2.49535',
#   'vote_average': 2.8,
#   'vote_count': 32.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756190')},
#  {'imdb_id': 'tt0114753',
#   'title': 'Two Bits',
#   'genres': 'Drama, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '4.046208',
#   'vote_average': 5.4,
#   'vote_count': 11.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756191')},
#  {'imdb_id': 'tt0113149',
#   'title': 'French Twist',
#   'genres': 'Comedy, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '2.518051',
#   'vote_average': 6.0,
#   'vote_count': 43.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756192')},
#  {'imdb_id': 'tt0113118',
#   'title': 'Friday',
#   'genres': 'Comedy',
#   'budget': '3500000',
#   'revenue': 28215918.0,
#   'popularity': '14.56965',
#   'vote_average': 7.0,
#   'vote_count': 513.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756193')},
#  {'imdb_id': 'tt0116367',
#   'title': 'From Dusk Till Dawn',
#   'genres': 'Horror, Action, Thriller, Crime',
#   'budget': '19000000',
#   'revenue': 25836616.0,
#   'popularity': '15.339153',
#   'vote_average': 6.9,
#   'vote_count': 1644.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756194')},
#  {'imdb_id': 'tt0113010',
#   'title': 'Fair Game',
#   'genres': 'Action, Thriller, Romance',
#   'budget': '50000000',
#   'revenue': 11534477.0,
#   'popularity': '5.912223',
#   'vote_average': 4.1,
#   'vote_count': 54.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756195')},
#  {'imdb_id': 'tt0113537',
#   'title': 'Kicking and Screaming',
#   'genres': 'Comedy, Drama, Romance',
#   'budget': '0',
#   'revenue': 718490.0,
#   'popularity': '3.367276',
#   'vote_average': 7.0,
#   'vote_count': 36.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756196')},
#  {'imdb_id': 'tt0113828',
#   'title': 'Les Miserables',
#   'genres': 'Drama, History',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.479446',
#   'vote_average': 6.6,
#   'vote_count': 8.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756197')},
#  {'imdb_id': 'tt0115644',
#   'title': 'Bed of Roses',
#   'genres': 'Drama, Romance',
#   'budget': '0',
#   'revenue': 19030691.0,
#   'popularity': '10.412194',
#   'vote_average': 5.1,
#   'vote_count': 27.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756198')},
#  {'imdb_id': 'tt0115676',
#   'title': 'Big Bully',
#   'genres': 'Comedy, Family',
#   'budget': '15000000',
#   'revenue': 2042530.0,
#   'popularity': '2.936443',
#   'vote_average': 3.9,
#   'vote_count': 16.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756199')},
#  {'imdb_id': 'tt0114367',
#   'title': 'Screamers',
#   'genres': 'Horror, Science, Fiction',
#   'budget': '20000000',
#   'revenue': 5781885.0,
#   'popularity': '12.758848',
#   'vote_average': 6.1,
#   'vote_count': 154.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75619a')},
#  {'imdb_id': 'tt0113973',
#   'title': 'Nico Icon',
#   'genres': 'Documentary',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.133893',
#   'vote_average': 7.3,
#   'vote_count': 3.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75619b')},
#  {'imdb_id': 'tt0112744',
#   'title': 'The Crossing Guard',
#   'genres': 'Drama, Thriller',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '5.756462',
#   'vote_average': 6.1,
#   'vote_count': 74.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75619c')},
#  {'imdb_id': 'tt0116731',
#   'title': 'The Juror',
#   'genres': 'Drama, Thriller',
#   'budget': '44000000',
#   'revenue': 0.0,
#   'popularity': '6.010579',
#   'vote_average': 5.5,
#   'vote_count': 91.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75619d')},
#  {'imdb_id': 'tt0112445',
#   'title': 'The White Balloon',
#   'genres': 'Family, Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.196256',
#   'vote_average': 7.5,
#   'vote_count': 20.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75619e')},
#  {'imdb_id': 'tt0114660',
#   'title': "Things to Do in Denver When You're Dead",
#   'genres': 'Drama, Crime',
#   'budget': '8000000',
#   'revenue': 529766.0,
#   'popularity': '4.486179',
#   'vote_average': 6.7,
#   'vote_count': 87.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75619f')},
#  {'imdb_id': 'tt0112379',
#   'title': "Antonia's Line",
#   'genres': 'Drama, Comedy',
#   'budget': '900000',
#   'revenue': 0.0,
#   'popularity': '2.030174',
#   'vote_average': 7.2,
#   'vote_count': 26.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561a0')},
#  {'imdb_id': 'tt0114039',
#   'title': 'Once Upon a Time... When We Were Colored',
#   'genres': 'Romance, Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.252287',
#   'vote_average': 4.5,
#   'vote_count': 2.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561a1')},
#  {'imdb_id': 'tt0113612',
#   'title': 'Last Summer in the Hamptons',
#   'genres': '',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.531159',
#   'vote_average': 0.0,
#   'vote_count': 0.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561a2')},
#  {'imdb_id': 'tt0112365',
#   'title': 'Angels and Insects',
#   'genres': 'Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '2.15166',
#   'vote_average': 6.3,
#   'vote_count': 17.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561a3')},
#  {'imdb_id': 'tt0118158',
#   'title': 'White Squall',
#   'genres': 'Action, Drama',
#   'budget': '38000000',
#   'revenue': 10300000.0,
#   'popularity': '9.568604',
#   'vote_average': 6.3,
#   'vote_count': 86.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561a4')},
#  {'imdb_id': 'tt0116151',
#   'title': 'Dunston Checks In',
#   'genres': 'Adventure, Comedy, Family',
#   'budget': '16000000',
#   'revenue': 0.0,
#   'popularity': '4.814825',
#   'vote_average': 5.1,
#   'vote_count': 59.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561a5')},
#  {'imdb_id': 'tt0115697',
#   'title': 'Black Sheep',
#   'genres': 'Comedy',
#   'budget': '0',
#   'revenue': 32.0,
#   'popularity': '8.963037',
#   'vote_average': 6.0,
#   'vote_count': 124.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561a6')},
#  {'imdb_id': 'tt0113972',
#   'title': 'Nick of Time',
#   'genres': 'Crime, Drama, Thriller',
#   'budget': '8169363',
#   'revenue': 8175346.0,
#   'popularity': '6.848591',
#   'vote_average': 6.1,
#   'vote_count': 190.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561a7')},
#  {'imdb_id': 'tt0113490',
#   'title': 'The Journey of August King',
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.411424',
#   'vote_average': 6.7,
#   'vote_count': 3.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561a8')},
#  {'imdb_id': 'tt0117002',
#   'title': 'Mary Reilly',
#   'genres': 'Drama, Horror, Thriller, Romance',
#   'budget': '47000000',
#   'revenue': 12379402.0,
#   'popularity': '12.866139',
#   'vote_average': 5.7,
#   'vote_count': 77.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561a9')},
#  {'imdb_id': 'tt0114825',
#   'title': 'Vampire in Brooklyn',
#   'genres': 'Comedy, Horror, Romance',
#   'budget': '14000000',
#   'revenue': 19800000.0,
#   'popularity': '9.071127',
#   'vote_average': 4.5,
#   'vote_count': 113.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561aa')},
#  {'imdb_id': 'tt0115639',
#   'title': 'Beautiful Girls',
#   'genres': 'Comedy, Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '4.670562',
#   'vote_average': 6.6,
#   'vote_count': 103.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561ab')},
#  {'imdb_id': 'tt0115759',
#   'title': 'Broken Arrow',
#   'genres': 'Action, Adventure, Drama, Thriller',
#   'budget': '50000000',
#   'revenue': 150270147.0,
#   'popularity': '14.957626',
#   'vote_average': 5.7,
#   'vote_count': 459.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561ac')},
#  {'imdb_id': 'tt0113403',
#   'title': "A Midwinter's Tale",
#   'genres': 'Comedy',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.513391',
#   'vote_average': 7.5,
#   'vote_count': 6.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561ad')},
#  {'imdb_id': 'tt0113247',
#   'title': 'La Haine',
#   'genres': 'Drama',
#   'budget': '3000000',
#   'revenue': 0.0,
#   'popularity': '12.108196',
#   'vote_average': 7.9,
#   'vote_count': 695.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561ae')},
#  {'imdb_id': 'tt0111173',
#   'title': 'Shopping',
#   'genres': 'Action, Adventure, Drama, Science, Fiction, Thriller',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '2.657647',
#   'vote_average': 5.6,
#   'vote_count': 13.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561af')},
#  {'imdb_id': 'tt0113283',
#   'title': 'Heidi Fleiss: Hollywood Madam',
#   'genres': 'Documentary',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.638211',
#   'vote_average': 6.8,
#   'vote_count': 4.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561b0')},
#  {'imdb_id': 'tt0115907',
#   'title': 'City Hall',
#   'genres': 'Drama, Thriller',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '4.807223',
#   'vote_average': 6.0,
#   'vote_count': 67.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561b1')},
#  {'imdb_id': 'tt0115734',
#   'title': 'Bottle Rocket',
#   'genres': 'Comedy, Crime, Drama',
#   'budget': '7000000',
#   'revenue': 560069.0,
#   'popularity': '6.904831',
#   'vote_average': 6.8,
#   'vote_count': 285.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561b2')},
#  {'imdb_id': 'tt0117102',
#   'title': 'Mr. Wrong',
#   'genres': 'Comedy, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '3.329264',
#   'vote_average': 3.3,
#   'vote_count': 16.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561b3')},
#  {'imdb_id': 'tt0118040',
#   'title': 'Unforgettable',
#   'genres': 'Drama, Mystery, Science, Fiction, Thriller',
#   'budget': '18000000',
#   'revenue': 0.0,
#   'popularity': '2.464425',
#   'vote_average': 5.3,
#   'vote_count': 22.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561b4')},
#  {'imdb_id': 'tt0116483',
#   'title': 'Happy Gilmore',
#   'genres': 'Comedy',
#   'budget': '12000000',
#   'revenue': 41205099.0,
#   'popularity': '9.592265',
#   'vote_average': 6.5,
#   'vote_count': 767.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561b5')},
#  {'imdb_id': 'tt0112579',
#   'title': 'The Bridges of Madison County',
#   'genres': 'Drama, Romance',
#   'budget': '24000000',
#   'revenue': 182016617.0,
#   'popularity': '5.951077',
#   'vote_average': 7.3,
#   'vote_count': 397.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561b6')},
#  {'imdb_id': 'tt0110251',
#   'title': 'Nobody Loves Me',
#   'genres': 'Drama, Comedy, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.015068',
#   'vote_average': 5.1,
#   'vote_count': 5.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561b7')},
#  {'imdb_id': 'tt0117110',
#   'title': 'Muppet Treasure Island',
#   'genres': 'Action, Comedy, Music, Family, Adventure',
#   'budget': '0',
#   'revenue': 34327391.0,
#   'popularity': '6.902423',
#   'vote_average': 6.5,
#   'vote_count': 93.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561b8')},
#  {'imdb_id': 'tt0112646',
#   'title': 'Catwalk',
#   'genres': 'Documentary',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.976707',
#   'vote_average': 7.0,
#   'vote_count': 2.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561b9')},
#  {'imdb_id': 'tt0113276',
#   'title': 'Headless Body in Topless Bar',
#   'genres': 'Crime',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.001346',
#   'vote_average': 0.0,
#   'vote_count': 0.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561ba')},
#  {'imdb_id': 'tt0112573',
#   'title': 'Braveheart',
#   'genres': 'Action, Drama, History, War',
#   'budget': '72000000',
#   'revenue': 210000000.0,
#   'popularity': '20.755149',
#   'vote_average': 7.7,
#   'vote_count': 3404.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561bb')},
#  {'imdb_id': 'tt0075314',
#   'title': 'Taxi Driver',
#   'genres': 'Crime, Drama',
#   'budget': '1300000',
#   'revenue': 28262574.0,
#   'popularity': '14.092713',
#   'vote_average': 8.1,
#   'vote_count': 2632.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561bc')},
#  {'imdb_id': 'tt0113326',
#   'title': 'Rumble in the Bronx',
#   'genres': 'Crime, Action, Comedy, Thriller',
#   'budget': '7500000',
#   'revenue': 32392047.0,
#   'popularity': '12.314278',
#   'vote_average': 6.5,
#   'vote_count': 245.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561bd')},
#  {'imdb_id': 'tt0115645',
#   'title': 'Before and After',
#   'genres': 'Drama, Thriller',
#   'budget': '35000000',
#   'revenue': 0.0,
#   'popularity': '2.938293',
#   'vote_average': 5.8,
#   'vote_count': 37.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561be')},
#  {'imdb_id': 'tt0113774',
#   'title': "Margaret's Museum",
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.372697',
#   'vote_average': 7.5,
#   'vote_count': 2.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561bf')},
#  {'imdb_id': 'tt0112556',
#   'title': 'Happiness Is in the Field',
#   'genres': 'Comedy',
#   'budget': '13365000',
#   'revenue': 0.0,
#   'popularity': '1.254885',
#   'vote_average': 7.0,
#   'vote_count': 23.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561c0')},
#  {'imdb_id': 'tt0112373',
#   'title': 'Anne Frank Remembered',
#   'genres': 'Documentary, Drama, Foreign',
#   'budget': '0',
#   'revenue': 1.0,
#   'popularity': '0.243986',
#   'vote_average': 7.3,
#   'vote_count': 4.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561c1')},
#  {'imdb_id': 'tt0115033',
#   'title': "The Young Poisoner's Handbook",
#   'genres': 'Comedy, Crime, Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '6.178497',
#   'vote_average': 6.9,
#   'vote_count': 19.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561c2')},
#  {'imdb_id': 'tt0116606',
#   'title': 'If Lucy Fell',
#   'genres': 'Comedy, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '2.891918',
#   'vote_average': 5.4,
#   'vote_count': 11.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561c3')},
#  {'imdb_id': 'tt0114536',
#   'title': 'Steal Big Steal Little',
#   'genres': 'Comedy, Drama',
#   'budget': '25000000',
#   'revenue': 6278139.0,
#   'popularity': '1.522412',
#   'vote_average': 5.1,
#   'vote_count': 7.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561c4')},
#  {'imdb_id': 'tt0117427',
#   'title': 'Race the Sun',
#   'genres': 'Action, Adventure, Comedy, Drama, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.317878',
#   'vote_average': 5.2,
#   'vote_count': 21.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561c5')},
#  {'imdb_id': 'tt0106473',
#   'title': 'The Boys of St. Vincent',
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.86539',
#   'vote_average': 7.0,
#   'vote_count': 7.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561c6')},
#  {'imdb_id': 'tt0103859',
#   'title': 'Boomerang',
#   'genres': 'Comedy, Romance',
#   'budget': '40000000',
#   'revenue': 70100000.0,
#   'popularity': '6.506983',
#   'vote_average': 5.4,
#   'vote_count': 139.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561c7')},
#  {'imdb_id': 'tt0109424',
#   'title': 'Chungking Express',
#   'genres': 'Drama, Comedy, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '6.778979',
#   'vote_average': 7.9,
#   'vote_count': 249.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561c8')},
#  {'imdb_id': 'tt0114808',
#   'title': 'The Star Maker',
#   'genres': 'Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.702639',
#   'vote_average': 6.8,
#   'vote_count': 29.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561c9')},
#  {'imdb_id': 'tt0116324',
#   'title': 'Flirting with Disaster',
#   'genres': 'Comedy, Romance',
#   'budget': '7000000',
#   'revenue': 14702438.0,
#   'popularity': '5.579088',
#   'vote_average': 6.3,
#   'vote_count': 66.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561ca')},
#  {'imdb_id': 'tt0110647',
#   'title': 'The Neverending Story III: Escape from Fantasia',
#   'genres': 'Fantasy',
#   'budget': '17000000',
#   'revenue': 0.0,
#   'popularity': '6.252377',
#   'vote_average': 4.4,
#   'vote_count': 105.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561cb')},
#  {'imdb_id': 'tt0111055',
#   'title': 'The Silences of the Palace',
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.406754',
#   'vote_average': 4.3,
#   'vote_count': 3.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561cc')},
#  {'imdb_id': 'tt0110217',
#   'title': "Jupiter's Wife",
#   'genres': '',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.001178',
#   'vote_average': 0.0,
#   'vote_count': 0.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561cd')},
#  {'imdb_id': 'tt0114131',
#   'title': 'Pie in the Sky',
#   'genres': 'Comedy, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.699066',
#   'vote_average': 7.0,
#   'vote_count': 2.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561ce')},
#  {'imdb_id': 'tt0112364',
#   'title': 'Angela',
#   'genres': 'Comedy, Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '2.197439',
#   'vote_average': 5.6,
#   'vote_count': 9.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561cf')},
#  {'imdb_id': 'tt0113107',
#   'title': 'Frankie Starlight',
#   'genres': 'Drama, Romance, War',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.637554',
#   'vote_average': 5.4,
#   'vote_count': 4.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561d0')},
#  {'imdb_id': 'tt0113451',
#   'title': 'Jade',
#   'genres': 'Action, Thriller, Mystery, Romance',
#   'budget': '50000000',
#   'revenue': 9851610.0,
#   'popularity': '11.418917',
#   'vote_average': 5.1,
#   'vote_count': 45.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561d1')},
#  {'imdb_id': 'tt0114015',
#   'title': 'Nueba Yol',
#   'genres': 'Comedy, Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.291021',
#   'vote_average': 5.5,
#   'vote_count': 1.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561d2')},
#  {'imdb_id': 'tt0114500',
#   'title': 'Sonic Outlaws',
#   'genres': 'Music, Documentary',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.001838',
#   'vote_average': 0.0,
#   'vote_count': 0.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561d3')},
#  {'imdb_id': 'tt0116130',
#   'title': 'Down Periscope',
#   'genres': 'Comedy',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '5.184977',
#   'vote_average': 5.6,
#   'vote_count': 110.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561d4')},
#  {'imdb_id': 'tt0113125',
#   'title': 'From the Journals of Jean Seberg',
#   'genres': 'Documentary',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.276401',
#   'vote_average': 6.5,
#   'vote_count': 2.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561d5')},
#  {'imdb_id': 'tt0113756',
#   'title': 'Man of the Year',
#   'genres': 'Comedy',
#   'budget': '0',
#   'revenue': 209935.0,
#   'popularity': '0.540436',
#   'vote_average': 3.8,
#   'vote_count': 2.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561d6')},
#  {'imdb_id': 'tt0113952',
#   'title': 'The Neon Bible',
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.370342',
#   'vote_average': 7.2,
#   'vote_count': 5.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561d7')},
#  {'imdb_id': 'tt0114618',
#   'title': 'Target',
#   'genres': '',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.001205',
#   'vote_average': 0.0,
#   'vote_count': 0.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561d8')},
#  {'imdb_id': 'tt0118055',
#   'title': 'Up Close & Personal',
#   'genres': 'Drama, Romance',
#   'budget': '60000000',
#   'revenue': 0.0,
#   'popularity': '3.402749',
#   'vote_average': 5.9,
#   'vote_count': 51.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561d9')},
#  {'imdb_id': 'tt0115685',
#   'title': 'The Birdcage',
#   'genres': 'Comedy',
#   'budget': '31000000',
#   'revenue': 185260553.0,
#   'popularity': '6.49968',
#   'vote_average': 6.7,
#   'vote_count': 303.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561da')},
#  {'imdb_id': 'tt0113200',
#   'title': 'Virgin Mary',
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.918504',
#   'vote_average': 7.0,
#   'vote_count': 2.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561db')},
#  {'imdb_id': 'tt0112585',
#   'title': 'The Brothers McMullen',
#   'genres': 'Comedy, Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '2.039196',
#   'vote_average': 6.3,
#   'vote_count': 23.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561dc')},
#  {'imdb_id': 'tt0112442',
#   'title': 'Bad Boys',
#   'genres': 'Action, Comedy, Crime, Thriller',
#   'budget': '19000000',
#   'revenue': 141407024.0,
#   'popularity': '9.262184',
#   'vote_average': 6.5,
#   'vote_count': 1729.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561dd')},
#  {'imdb_id': 'tt0112342',
#   'title': 'The Amazing Panda Adventure',
#   'genres': 'Action, Adventure, Drama, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '2.375865',
#   'vote_average': 5.0,
#   'vote_count': 31.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561de')},
#  {'imdb_id': 'tt0112461',
#   'title': 'The Basketball Diaries',
#   'genres': 'Drama, Crime',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '7.415144',
#   'vote_average': 7.2,
#   'vote_count': 472.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561df')},
#  {'imdb_id': 'tt0112427',
#   'title': 'An Awfully Big Adventure',
#   'genres': 'Romance, Drama, Comedy',
#   'budget': '4000000',
#   'revenue': 851545.0,
#   'popularity': '0.922958',
#   'vote_average': 6.0,
#   'vote_count': 11.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561e0')},
#  {'imdb_id': 'tt0109093',
#   'title': 'Amateur',
#   'genres': 'Crime, Comedy, Drama, Thriller',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.759012',
#   'vote_average': 6.5,
#   'vote_count': 21.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561e1')},
#  {'imdb_id': 'tt0112384',
#   'title': 'Apollo 13',
#   'genres': 'Drama',
#   'budget': '52000000',
#   'revenue': 355237933.0,
#   'popularity': '18.761467',
#   'vote_average': 7.3,
#   'vote_count': 1637.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561e2')},
#  {'imdb_id': 'tt0114287',
#   'title': 'Rob Roy',
#   'genres': 'Adventure',
#   'budget': '28000000',
#   'revenue': 31596911.0,
#   'popularity': '10.193549',
#   'vote_average': 6.5,
#   'vote_count': 151.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561e3')},
#  {'imdb_id': 'tt0112288',
#   'title': 'The Addiction',
#   'genres': 'Drama, Horror',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '3.137285',
#   'vote_average': 6.4,
#   'vote_count': 46.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561e4')},
#  {'imdb_id': 'tt0112462',
#   'title': 'Batman Forever',
#   'genres': 'Action, Crime, Fantasy',
#   'budget': '100000000',
#   'revenue': 336529144.0,
#   'popularity': '13.321354',
#   'vote_average': 5.2,
#   'vote_count': 1529.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561e5')},
#  {'imdb_id': 'tt0061395',
#   'title': 'Belle de Jour',
#   'genres': 'Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '10.142662',
#   'vote_average': 7.3,
#   'vote_count': 163.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561e6')},
#  {'imdb_id': 'tt0112495',
#   'title': 'Beyond Rangoon',
#   'genres': 'Drama, Thriller',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '2.04189',
#   'vote_average': 6.4,
#   'vote_count': 21.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561e7')},
#  {'imdb_id': 'tt0112541',
#   'title': 'Blue in the Face',
#   'genres': 'Comedy',
#   'budget': '2000000',
#   'revenue': 1275000.0,
#   'popularity': '11.528147',
#   'vote_average': 6.8,
#   'vote_count': 28.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561e8')},
#  {'imdb_id': 'tt0109370',
#   'title': 'Canadian Bacon',
#   'genres': 'Action, Comedy',
#   'budget': '11000000',
#   'revenue': 178104.0,
#   'popularity': '5.391556',
#   'vote_average': 5.9,
#   'vote_count': 57.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561e9')},
#  {'imdb_id': 'tt0112642',
#   'title': 'Casper',
#   'genres': 'Fantasy, Comedy, Family',
#   'budget': '50000000',
#   'revenue': 287928194.0,
#   'popularity': '12.812539',
#   'vote_average': 6.0,
#   'vote_count': 1045.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561ea')},
#  {'imdb_id': 'tt0112688',
#   'title': 'Clockers',
#   'genres': 'Mystery, Crime, Drama',
#   'budget': '25000000',
#   'revenue': 13071518.0,
#   'popularity': '4.558992',
#   'vote_average': 6.8,
#   'vote_count': 69.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561eb')},
#  {'imdb_id': 'tt0112715',
#   'title': 'Congo',
#   'genres': 'Action, Adventure, Drama, Mystery, Science, Fiction, Thriller',
#   'budget': '50000000',
#   'revenue': 152022101.0,
#   'popularity': '7.260574',
#   'vote_average': 5.0,
#   'vote_count': 214.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561ec')},
#  {'imdb_id': 'tt0112740',
#   'title': 'Crimson Tide',
#   'genres': 'Action, Thriller, Drama',
#   'budget': '53000000',
#   'revenue': 157387195.0,
#   'popularity': '8.657365',
#   'vote_average': 7.0,
#   'vote_count': 508.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561ed')},
#  {'imdb_id': 'tt0109508',
#   'title': 'Crumb',
#   'genres': 'Documentary',
#   'budget': '0',
#   'revenue': 3174695.0,
#   'popularity': '3.620388',
#   'vote_average': 7.6,
#   'vote_count': 71.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561ee')},
#  {'imdb_id': 'tt0112851',
#   'title': 'Desperado',
#   'genres': 'Thriller, Action, Crime',
#   'budget': '7000000',
#   'revenue': 25405445.0,
#   'popularity': '6.950458',
#   'vote_average': 6.8,
#   'vote_count': 898.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561ef')},
#  {'imdb_id': 'tt0112857',
#   'title': 'Devil in a Blue Dress',
#   'genres': 'Drama, Mystery, Thriller',
#   'budget': '27000000',
#   'revenue': 16140822.0,
#   'popularity': '4.646132',
#   'vote_average': 6.3,
#   'vote_count': 88.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561f0')},
#  {'imdb_id': 'tt0112864',
#   'title': 'Die Hard: With a Vengeance',
#   'genres': 'Action, Thriller',
#   'budget': '90000000',
#   'revenue': 366101666.0,
#   'popularity': '15.138855',
#   'vote_average': 6.9,
#   'vote_count': 2094.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561f1')},
#  {'imdb_id': 'tt0112887',
#   'title': 'The Doom Generation',
#   'genres': 'Action, Comedy, Crime, Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '7.120806',
#   'vote_average': 5.6,
#   'vote_count': 57.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561f2')},
#  {'imdb_id': 'tt0113044',
#   'title': 'Feast of July',
#   'genres': 'Drama, Crime',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.523575',
#   'vote_average': 0.0,
#   'vote_count': 0.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561f3')},
#  {'imdb_id': 'tt0113071',
#   'title': 'First Knight',
#   'genres': 'Action, Adventure, Drama, Romance',
#   'budget': '55000000',
#   'revenue': 127600435.0,
#   'popularity': '15.178338',
#   'vote_average': 5.9,
#   'vote_count': 319.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561f4')},
#  {'imdb_id': 'tt0113114',
#   'title': 'Free Willy 2 - The Adventure Home',
#   'genres': 'Adventure',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '7.575098',
#   'vote_average': 5.5,
#   'vote_count': 130.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561f5')},
#  {'imdb_id': 'tt0113243',
#   'title': 'Hackers',
#   'genres': 'Action, Crime, Thriller, Drama',
#   'budget': '20000000',
#   'revenue': 7563728.0,
#   'popularity': '14.810519',
#   'vote_average': 6.2,
#   'vote_count': 406.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561f6')},
#  {'imdb_id': 'tt0113464',
#   'title': 'Jeffrey',
#   'genres': 'Comedy, Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '3.196456',
#   'vote_average': 6.5,
#   'vote_count': 19.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561f7')},
#  {'imdb_id': 'tt0113481',
#   'title': 'Johnny Mnemonic',
#   'genres': 'Adventure, Action, Drama, Science, Fiction, Thriller',
#   'budget': '25000000',
#   'revenue': 19075720.0,
#   'popularity': '11.715868',
#   'vote_average': 5.5,
#   'vote_count': 380.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561f8')},
#  {'imdb_id': 'tt0113492',
#   'title': 'Judge Dredd',
#   'genres': 'Science, Fiction',
#   'budget': '90000000',
#   'revenue': 113493481.0,
#   'popularity': '8.184815',
#   'vote_average': 5.4,
#   'vote_count': 643.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561f9')},
#  {'imdb_id': 'tt0113500',
#   'title': 'Jury Duty',
#   'genres': 'Comedy, Drama',
#   'budget': '0',
#   'revenue': 17014653.0,
#   'popularity': '3.676921',
#   'vote_average': 4.0,
#   'vote_count': 34.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561fa')},
#  {'imdb_id': 'tt0113540',
#   'title': 'Kids',
#   'genres': 'Drama, Crime',
#   'budget': '1500000',
#   'revenue': 7412216.0,
#   'popularity': '4.877872',
#   'vote_average': 6.8,
#   'vote_count': 280.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561fb')},
#  {'imdb_id': 'tt0113677',
#   'title': 'Living in Oblivion',
#   'genres': 'Drama, Comedy',
#   'budget': '500000',
#   'revenue': 1148752.0,
#   'popularity': '10.058329',
#   'vote_average': 7.2,
#   'vote_count': 64.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561fc')},
#  {'imdb_id': 'tt0113690',
#   'title': 'Lord of Illusions',
#   'genres': 'Mystery, Horror, Thriller',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '4.102409',
#   'vote_average': 5.9,
#   'vote_count': 87.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561fd')},
#  {'imdb_id': 'tt0107447',
#   'title': 'Love & Human Remains',
#   'genres': 'Comedy, Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.354014',
#   'vote_average': 7.0,
#   'vote_count': 7.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561fe')},
#  {'imdb_id': 'tt0113729',
#   'title': 'Mad Love',
#   'genres': 'Drama, Family, Romance',
#   'budget': '0',
#   'revenue': 15453274.0,
#   'popularity': '2.624771',
#   'vote_average': 5.5,
#   'vote_count': 27.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7561ff')},
#  {'imdb_id': 'tt0113749',
#   'title': 'Mallrats',
#   'genres': 'Romance, Comedy',
#   'budget': '6000000',
#   'revenue': 2122561.0,
#   'popularity': '8.25547',
#   'vote_average': 6.8,
#   'vote_count': 400.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756200')},
#  {'imdb_id': 'tt0113820',
#   'title': 'Mighty Morphin Power Rangers: The Movie',
#   'genres': 'Action, Adventure, Science, Fiction, Family, Fantasy',
#   'budget': '15000000',
#   'revenue': 66000000.0,
#   'popularity': '7.024227',
#   'vote_average': 5.2,
#   'vote_count': 153.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756201')},
#  {'imdb_id': 'tt0113851',
#   'title': 'Moonlight and Valentino',
#   'genres': 'Comedy, Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.01115',
#   'vote_average': 5.6,
#   'vote_count': 10.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756202')},
#  {'imdb_id': 'tt0110604',
#   'title': 'Mute Witness',
#   'genres': 'Thriller, Foreign',
#   'budget': '2',
#   'revenue': 1.0,
#   'popularity': '2.466066',
#   'vote_average': 6.4,
#   'vote_count': 36.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756203')},
#  {'imdb_id': 'tt0110620',
#   'title': 'Nadja',
#   'genres': 'Horror, Thriller',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '7.720056',
#   'vote_average': 5.9,
#   'vote_count': 12.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756204')},
#  {'imdb_id': 'tt0113957',
#   'title': 'The Net',
#   'genres': 'Crime, Drama, Mystery, Thriller, Action',
#   'budget': '22000000',
#   'revenue': 110627965.0,
#   'popularity': '13.304342',
#   'vote_average': 5.6,
#   'vote_count': 359.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756205')},
#  {'imdb_id': 'tt0113986',
#   'title': 'Nine Months',
#   'genres': 'Comedy',
#   'budget': '0',
#   'revenue': 69660733.0,
#   'popularity': '8.482834',
#   'vote_average': 5.5,
#   'vote_count': 171.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756206')},
#  {'imdb_id': 'tt0114095',
#   'title': 'Party Girl',
#   'genres': 'Comedy',
#   'budget': '150000',
#   'revenue': 472370.0,
#   'popularity': '1.165039',
#   'vote_average': 5.8,
#   'vote_count': 14.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756207')},
#  {'imdb_id': 'tt0114194',
#   'title': 'The Prophecy',
#   'genres': 'Fantasy, Horror, Thriller',
#   'budget': '8',
#   'revenue': 16.0,
#   'popularity': '10.187623',
#   'vote_average': 6.4,
#   'vote_count': 139.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756208')},
#  {'imdb_id': 'tt0114241',
#   'title': 'Reckless',
#   'genres': 'Fantasy, Comedy, Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.119713',
#   'vote_average': 10.0,
#   'vote_count': 1.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756209')},
#  {'imdb_id': 'tt0114323',
#   'title': 'Safe',
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '8.180047',
#   'vote_average': 7.2,
#   'vote_count': 62.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75620a')},
#  {'imdb_id': 'tt0114345',
#   'title': 'The Scarlet Letter',
#   'genres': 'Drama, History, Romance',
#   'budget': '50000000',
#   'revenue': 10382407.0,
#   'popularity': '6.752119',
#   'vote_average': 5.5,
#   'vote_count': 111.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75620b')},
# ...
#  {'imdb_id': 'tt0039152',
#   'title': 'Angel and the Badman',
#   'genres': 'Romance, Western',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '8.08426',
#   'vote_average': 6.6,
#   'vote_count': 27.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7564f8')},
#  {'imdb_id': 'tt0026029',
#   'title': 'The 39 Steps',
#   'genres': 'Action, Thriller, Mystery',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '5.865697',
#   'vote_average': 7.4,
#   'vote_count': 217.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7564f9')},
#  {'imdb_id': 'tt0038235',
#   'title': 'A Walk in the Sun',
#   'genres': 'War, Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '8.85591',
#   'vote_average': 5.2,
#   'vote_count': 14.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7564fa')},
#  {'imdb_id': 'tt0036241',
#   'title': 'The Outlaw',
#   'genres': 'Action, Adventure, Western',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.450989',
#   'vote_average': 4.9,
#   'vote_count': 16.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7564fb')},
#  {'imdb_id': 'tt0063350',
#   'title': 'Night of the Living Dead',
#   'genres': 'Horror',
#   'budget': '114000',
#   'revenue': 30000000.0,
#   'popularity': '14.384198',
#   'vote_average': 7.5,
#   'vote_count': 591.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7564fc')},
#  {'imdb_id': 'tt0043265',
#   'title': 'The African Queen',
#   'genres': 'Adventure, War, Romance',
#   'budget': '1300000',
#   'revenue': 10750000.0,
#   'popularity': '6.636872',
#   'vote_average': 7.4,
#   'vote_count': 232.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7564fd')},
#  {'imdb_id': 'tt0046414',
#   'title': 'Beat the Devil',
#   'genres': 'Action, Adventure, Comedy, Crime, Drama, Romance',
#   'budget': '1000000',
#   'revenue': 0.0,
#   'popularity': '2.001733',
#   'vote_average': 6.2,
#   'vote_count': 31.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7564fe')},
#  {'imdb_id': 'tt0051459',
#   'title': 'Cat on a Hot Tin Roof',
#   'genres': 'Drama, Romance',
#   'budget': '3000000',
#   'revenue': 17570324.0,
#   'popularity': '11.794846',
#   'vote_average': 7.6,
#   'vote_count': 168.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d7564ff')},
#  {'imdb_id': 'tt0047162',
#   'title': 'The Last Time I Saw Paris',
#   'genres': 'Romance, Drama',
#   'budget': '0',
#   'revenue': 105.0,
#   'popularity': '0.912955',
#   'vote_average': 5.1,
#   'vote_count': 9.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756500')},
#  {'imdb_id': 'tt0033891',
#   'title': 'Meet John Doe',
#   'genres': 'Drama, Comedy, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '10.750619',
#   'vote_average': 7.3,
#   'vote_count': 52.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756501')},
#  {'imdb_id': 'tt0029855',
#   'title': 'Algiers',
#   'genres': 'Drama, Action, Mystery, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.348765',
#   'vote_average': 5.8,
#   'vote_count': 6.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756502')},
#  {'imdb_id': 'tt0029588',
#   'title': 'Something to Sing About',
#   'genres': 'Comedy',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.367546',
#   'vote_average': 3.8,
#   'vote_count': 2.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756503')},
#  {'imdb_id': 'tt0022879',
#   'title': 'A Farewell to Arms',
#   'genres': 'Drama, Romance, War',
#   'budget': '4',
#   'revenue': 25.0,
#   'popularity': '1.914697',
#   'vote_average': 6.2,
#   'vote_count': 29.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756504')},
#  {'imdb_id': 'tt0027980',
#   'title': 'Moonlight Murder',
#   'genres': 'Music, Mystery',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.283269',
#   'vote_average': 6.0,
#   'vote_count': 1.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756505')},
#  {'imdb_id': 'tt0114007',
#   'title': 'Nothing Personal',
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.064512',
#   'vote_average': 4.0,
#   'vote_count': 1.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756506')},
#  {'imdb_id': 'tt0093229',
#   'title': 'Yes, Madam',
#   'genres': 'Action, Foreign',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.060097',
#   'vote_average': 7.4,
#   'vote_count': 11.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756507')},
#  {'imdb_id': 'tt0118927',
#   'title': 'Dangerous Ground',
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 3028094.0,
#   'popularity': '1.463219',
#   'vote_average': 5.0,
#   'vote_count': 8.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756508')},
#  {'imdb_id': 'tt0048491',
#   'title': 'Picnic',
#   'genres': 'Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '8.500509',
#   'vote_average': 6.7,
#   'vote_count': 19.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756509')},
#  {'imdb_id': 'tt0113730',
#   'title': 'Madagascar Skin',
#   'genres': '',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.580724',
#   'vote_average': 0.0,
#   'vote_count': 0.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75650a')},
#  {'imdb_id': 'tt0117357',
#   'title': 'The Pompatus of Love',
#   'genres': 'Comedy, Romance, Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.537795',
#   'vote_average': 5.3,
#   'vote_count': 2.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75650b')},
#  {'imdb_id': 'tt0117669',
#   'title': 'Small Wonders',
#   'genres': 'Documentary, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.00264',
#   'vote_average': 0.0,
#   'vote_count': 0.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75650c')},
#  {'imdb_id': 'tt0116329',
#   'title': 'Fly Away Home',
#   'genres': 'Action, Adventure, Drama, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '5.511155',
#   'vote_average': 6.6,
#   'vote_count': 114.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75650d')},
#  {'imdb_id': 'tt0118742',
#   'title': 'Bliss',
#   'genres': 'Drama, Romance',
#   'budget': '0',
#   'revenue': 294064.0,
#   'popularity': '1.262649',
#   'vote_average': 4.8,
#   'vote_count': 6.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75650e')},
#  {'imdb_id': 'tt0116442',
#   'title': 'Grace of My Heart',
#   'genres': 'Drama, Comedy, Music',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '9.364418',
#   'vote_average': 6.5,
#   'vote_count': 15.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75650f')},
#  {'imdb_id': 'tt0114354',
#   'title': 'Brother of Sleep',
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.751733',
#   'vote_average': 6.8,
#   'vote_count': 6.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756510')},
#  {'imdb_id': 'tt0117011',
#   'title': 'Maximum Risk',
#   'genres': 'Action, Adventure, Thriller',
#   'budget': '25000000',
#   'revenue': 51702483.0,
#   'popularity': '7.370163',
#   'vote_average': 5.3,
#   'vote_count': 104.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756511')},
#  {'imdb_id': 'tt0117039',
#   'title': 'Michael Collins',
#   'genres': 'Drama, Thriller',
#   'budget': '28000000',
#   'revenue': 16900000.0,
#   'popularity': '6.728199',
#   'vote_average': 6.8,
#   'vote_count': 98.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756512')},
#  {'imdb_id': 'tt0117473',
#   'title': "The Rich Man's Wife",
#   'genres': 'Drama, Thriller',
#   'budget': '0',
#   'revenue': 8538318.0,
#   'popularity': '6.746475',
#   'vote_average': 4.9,
#   'vote_count': 11.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756513')},
#  {'imdb_id': 'tt0116635',
#   'title': 'Infinity',
#   'genres': 'Drama, Romance',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.226688',
#   'vote_average': 0.0,
#   'vote_count': 0.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756514')},
#  {'imdb_id': 'tt0115678',
#   'title': 'Big Night',
#   'genres': 'Drama',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '2.702973',
#   'vote_average': 6.8,
#   'vote_count': 45.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756515')},
#  {'imdb_id': 'tt0116830',
#   'title': 'Last Man Standing',
#   'genres': 'Action, Crime, Drama, Thriller',
#   'budget': '67000000',
#   'revenue': 47267001.0,
#   'popularity': '11.845918',
#   'vote_average': 6.2,
#   'vote_count': 263.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756516')},
#  {'imdb_id': 'tt0115847',
#   'title': 'Caught',
#   'genres': 'Action, Drama, Thriller',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.625873',
#   'vote_average': 6.5,
#   'vote_count': 5.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756517')},
#  {'imdb_id': 'tt0117603',
#   'title': 'Set It Off',
#   'genres': 'Drama, Action, Crime',
#   'budget': '9000000',
#   'revenue': 41590886.0,
#   'popularity': '6.85606',
#   'vote_average': 6.9,
#   'vote_count': 66.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756518')},
#  {'imdb_id': 'tt0115438',
#   'title': '2 Days in the Valley',
#   'genres': 'Comedy, Crime',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '4.989276',
#   'vote_average': 5.9,
#   'vote_count': 73.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756519')},
#  {'imdb_id': 'tt0115994',
#   'title': 'Curdled',
#   'genres': 'Comedy, Crime, Thriller',
#   'budget': '2300000',
#   'revenue': 49620.0,
#   'popularity': '2.781581',
#   'vote_average': 6.2,
#   'vote_count': 29.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75651a')},
#  {'imdb_id': 'tt0083587',
#   'title': "L'associé",
#   'genres': 'Comedy',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.000308',
#   'vote_average': 6.0,
#   'vote_count': 3.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75651b')},
#  {'imdb_id': 'tt0116167',
#   'title': "Ed's Next Move",
#   'genres': '',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.550278',
#   'vote_average': 3.0,
#   'vote_count': 1.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75651c')},
#  {'imdb_id': 'tt0116259',
#   'title': 'Extreme Measures',
#   'genres': 'Drama, Thriller',
#   'budget': '38000000',
#   'revenue': 17380126.0,
#   'popularity': '4.990506',
#   'vote_average': 5.7,
#   'vote_count': 80.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75651d')},
#  {'imdb_id': 'tt0116421',
#   'title': 'The Glimmer Man',
#   'genres': 'Action, Adventure, Crime, Drama, Thriller',
#   'budget': '45000000',
#   'revenue': 0.0,
#   'popularity': '5.918737',
#   'vote_average': 4.7,
#   'vote_count': 102.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75651e')},
#  {'imdb_id': 'tt0116000',
#   'title': 'D3: The Mighty Ducks',
#   'genres': 'Action, Comedy, Drama, Family',
#   'budget': '0',
#   'revenue': 22955097.0,
#   'popularity': '5.511475',
#   'vote_average': 5.3,
#   'vote_count': 99.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75651f')},
#  {'imdb_id': 'tt0115862',
#   'title': 'The Chamber',
#   'genres': 'Crime, Drama',
#   'budget': '50000000',
#   'revenue': 22540359.0,
#   'popularity': '3.998494',
#   'vote_average': 5.9,
#   'vote_count': 62.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756520')},
#  {'imdb_id': 'tt0072653',
#   'title': 'The Apple Dumpling Gang',
#   'genres': 'Comedy, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '4.040945',
#   'vote_average': 6.6,
#   'vote_count': 34.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756521')},
#  {'imdb_id': 'tt0047977',
#   'title': 'Davy Crockett, King of the Wild Frontier',
#   'genres': 'Action, Adventure, Family, Western',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '5.497359',
#   'vote_average': 5.9,
#   'vote_count': 14.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756522')},
#  {'imdb_id': 'tt0072951',
#   'title': 'Escape to Witch Mountain',
#   'genres': 'Adventure, Fantasy, Science, Fiction, Family',
#   'budget': '0',
#   'revenue': 20000000.0,
#   'popularity': '7.151691',
#   'vote_average': 6.5,
#   'vote_count': 60.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756523')},
#  {'imdb_id': 'tt0064603',
#   'title': 'The Love Bug',
#   'genres': 'Comedy, Family, Fantasy',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '10.091707',
#   'vote_average': 6.0,
#   'vote_count': 126.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756524')},
#  {'imdb_id': 'tt0071607',
#   'title': 'Herbie Rides Again',
#   'genres': 'Romance, Comedy, Family, Fantasy',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '4.914603',
#   'vote_average': 5.9,
#   'vote_count': 77.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756525')},
#  {'imdb_id': 'tt0050798',
#   'title': 'Old Yeller',
#   'genres': 'Adventure, Drama, Western',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '12.887829',
#   'vote_average': 7.0,
#   'vote_count': 68.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756526')},
#  {'imdb_id': 'tt0055277',
#   'title': 'The Parent Trap',
#   'genres': 'Comedy, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '5.807074',
#   'vote_average': 6.8,
#   'vote_count': 92.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756527')},
#  {'imdb_id': 'tt0054195',
#   'title': 'Pollyanna',
#   'genres': 'Adventure',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '3.254308',
#   'vote_average': 6.9,
#   'vote_count': 50.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756528')},
#  {'imdb_id': 'tt0107131',
#   'title': 'Homeward Bound: The Incredible Journey',
#   'genres': 'Adventure, Comedy, Drama, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '7.186506',
#   'vote_average': 6.6,
#   'vote_count': 218.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756529')},
#  {'imdb_id': 'tt0053271',
#   'title': 'The Shaggy Dog',
#   'genres': 'Comedy, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '3.404213',
#   'vote_average': 6.2,
#   'vote_count': 22.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75652a')},
#  {'imdb_id': 'tt0054357',
#   'title': 'Swiss Family Robinson',
#   'genres': 'Adventure, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '4.623089',
#   'vote_average': 7.0,
#   'vote_count': 88.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75652b')},
#  {'imdb_id': 'tt0059793',
#   'title': 'That Darn Cat!',
#   'genres': 'Drama, Family, Comedy',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '2.803679',
#   'vote_average': 6.4,
#   'vote_count': 28.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75652c')},
#  {'imdb_id': 'tt0046672',
#   'title': '20,000 Leagues Under the Sea',
#   'genres': 'Adventure, Drama, Science, Fiction',
#   'budget': '5000000',
#   'revenue': 28200000.0,
#   'popularity': '8.722406',
#   'vote_average': 6.9,
#   'vote_count': 160.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75652d')},
#  {'imdb_id': 'tt0106611',
#   'title': 'Cool Runnings',
#   'genres': 'Comedy',
#   'budget': '14000000',
#   'revenue': 154864401.0,
#   'popularity': '8.30721',
#   'vote_average': 6.8,
#   'vote_count': 510.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75652e')},
#  {'imdb_id': 'tt0109127',
#   'title': 'Angels in the Outfield',
#   'genres': 'Fantasy, Drama, Comedy, Family',
#   'budget': '0',
#   'revenue': 50236831.0,
#   'popularity': '10.892812',
#   'vote_average': 5.7,
#   'vote_count': 124.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d75652f')},
#  {'imdb_id': 'tt0042332',
#   'title': 'Cinderella',
#   'genres': 'Family, Fantasy, Animation, Romance',
#   'budget': '2900000',
#   'revenue': 263591415.0,
#   'popularity': '14.436858',
#   'vote_average': 6.8,
#   'vote_count': 1760.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756530')},
#  {'imdb_id': 'tt0063819',
#   'title': 'Winnie the Pooh and the Blustery Day',
#   'genres': 'Animation, Family, Music',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '1.054814',
#   'vote_average': 7.8,
#   'vote_count': 20.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756531')},
#  {'imdb_id': 'tt0038166',
#   'title': 'The Three Caballeros',
#   'genres': 'Animation, Family, Music',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '8.702472',
#   'vote_average': 6.2,
#   'vote_count': 108.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756532')},
#  {'imdb_id': 'tt0057546',
#   'title': 'The Sword in the Stone',
#   'genres': 'Animation, Family',
#   'budget': '3000000',
#   'revenue': 22182353.0,
#   'popularity': '10.636458',
#   'vote_average': 6.9,
#   'vote_count': 935.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756533')},
#  {'imdb_id': 'tt0041890',
#   'title': 'So Dear to My Heart',
#   'genres': 'Animation, Drama, Family',
#   'budget': '0',
#   'revenue': 0.0,
#   'popularity': '0.901443',
#   'vote_average': 6.3,
#   'vote_count': 5.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756534')},
#  {'imdb_id': 'tt0102798',
#   'title': 'Robin Hood: Prince of Thieves',
#   'genres': 'Adventure',
#   'budget': '48000000',
#   'revenue': 390493908.0,
#   'popularity': '10.639244',
#   'vote_average': 6.6,
#   'vote_count': 937.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756535')},
#  {'imdb_id': 'tt0058331',
#   'title': 'Mary Poppins',
#   'genres': 'Comedy, Family, Fantasy',
#   'budget': '6000000',
#   'revenue': 102272727.0,
#   'popularity': '15.11549',
#   'vote_average': 7.4,
#   'vote_count': 1217.0,
#   '_id': ObjectId('5ecd7a299bbb609a3d756536')},
#  ...]

# %% [markdown]
# **Insert this dictionary to database collection**

# %%
coll.insert_many(df_dict)

# %%
# Count number of documents
coll.count_documents({})
# Out:
# 45413

# %% [markdown]
# **Create index from 'imdb_id'**

# %%
# Create index
coll.create_index('imdb_id', unique=True)
# Out:
# 'imdb_id_1'

# %%
# Check index info
coll.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)], 'ns': 'movies_db.movies'},
#  'imdb_id_1': {'v': 2,
#   'unique': True,
#   'key': [('imdb_id', 1)],
#   'ns': 'movies_db.movies'}}

# %% [markdown]
# **Prepare special dictionaries from dataframe dffb**

# %% [markdown]
# The dataframe will be converted to the list of dictionaries. We will reformat these dictionaries and add them one by one to the collection.

# %%
dffb_d = dffb.to_dict('records')
dffb_d
# Out:
# [{'imdb_id': 'tt0499549',
#   'title': 'Avatar',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi',
#   'imdb_score': 7.9,
#   'movie_likes': 33000,
#   'director': 'James Cameron',
#   'director_likes': 0.0,
#   'actor_1': 'CCH Pounder',
#   'actor_1_likes': 1000.0,
#   'actor_2': 'Joel David Moore',
#   'actor_2_likes': 936.0,
#   'actor_3': 'Wes Studi',
#   'actor_3_likes': 855.0},
#  {'imdb_id': 'tt0449088',
#   'title': "Pirates of the Caribbean: At World's End",
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy',
#   'imdb_score': 7.1,
#   'movie_likes': 0,
#   'director': 'Gore Verbinski',
#   'director_likes': 563.0,
#   'actor_1': 'Johnny Depp',
#   'actor_1_likes': 40000.0,
#   'actor_2': 'Orlando Bloom',
#   'actor_2_likes': 5000.0,
#   'actor_3': 'Jack Davenport',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt2379713',
#   'title': 'Spectre',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Thriller',
#   'imdb_score': 6.8,
#   'movie_likes': 85000,
#   'director': 'Sam Mendes',
#   'director_likes': 0.0,
#   'actor_1': 'Christoph Waltz',
#   'actor_1_likes': 11000.0,
#   'actor_2': 'Rory Kinnear',
#   'actor_2_likes': 393.0,
#   'actor_3': 'Stephanie Sigman',
#   'actor_3_likes': 161.0},
#  {'imdb_id': 'tt1345836',
#   'title': 'The Dark Knight Rises',
#   'rating': 'PG-13',
#   'genres': 'Action, Thriller',
#   'imdb_score': 8.5,
#   'movie_likes': 164000,
#   'director': 'Christopher Nolan',
#   'director_likes': 22000.0,
#   'actor_1': 'Tom Hardy',
#   'actor_1_likes': 27000.0,
#   'actor_2': 'Christian Bale',
#   'actor_2_likes': 23000.0,
#   'actor_3': 'Joseph Gordon-Levitt',
#   'actor_3_likes': 23000.0},
#  {'imdb_id': 'tt5289954',
#   'title': 'Star Wars: Episode VII - The Force Awakens',
#   'rating': nan,
#   'genres': 'Documentary',
#   'imdb_score': 7.1,
#   'movie_likes': 0,
#   'director': 'Doug Walker',
#   'director_likes': 131.0,
#   'actor_1': 'Doug Walker',
#   'actor_1_likes': 131.0,
#   'actor_2': 'Rob Walker',
#   'actor_2_likes': 12.0,
#   'actor_3': nan,
#   'actor_3_likes': nan},
#  {'imdb_id': 'tt0401729',
#   'title': 'John Carter',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 6.6,
#   'movie_likes': 24000,
#   'director': 'Andrew Stanton',
#   'director_likes': 475.0,
#   'actor_1': 'Daryl Sabara',
#   'actor_1_likes': 640.0,
#   'actor_2': 'Samantha Morton',
#   'actor_2_likes': 632.0,
#   'actor_3': 'Polly Walker',
#   'actor_3_likes': 530.0},
#  {'imdb_id': 'tt0413300',
#   'title': 'Spider-Man 3',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Romance',
#   'imdb_score': 6.2,
#   'movie_likes': 0,
#   'director': 'Sam Raimi',
#   'director_likes': 0.0,
#   'actor_1': 'J.K. Simmons',
#   'actor_1_likes': 24000.0,
#   'actor_2': 'James Franco',
#   'actor_2_likes': 11000.0,
#   'actor_3': 'Kirsten Dunst',
#   'actor_3_likes': 4000.0},
#  {'imdb_id': 'tt0398286',
#   'title': 'Tangled',
#   'rating': 'PG',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy, Musical, Romance',
#   'imdb_score': 7.8,
#   'movie_likes': 29000,
#   'director': 'Nathan Greno',
#   'director_likes': 15.0,
#   'actor_1': 'Brad Garrett',
#   'actor_1_likes': 799.0,
#   'actor_2': 'Donna Murphy',
#   'actor_2_likes': 553.0,
#   'actor_3': 'M.C. Gainey',
#   'actor_3_likes': 284.0},
#  {'imdb_id': 'tt2395427',
#   'title': 'Avengers: Age of Ultron',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 7.5,
#   'movie_likes': 118000,
#   'director': 'Joss Whedon',
#   'director_likes': 0.0,
#   'actor_1': 'Chris Hemsworth',
#   'actor_1_likes': 26000.0,
#   'actor_2': 'Robert Downey Jr.',
#   'actor_2_likes': 21000.0,
#   'actor_3': 'Scarlett Johansson',
#   'actor_3_likes': 19000.0},
#  {'imdb_id': 'tt0417741',
#   'title': 'Harry Potter and the Half-Blood Prince',
#   'rating': 'PG',
#   'genres': 'Adventure, Family, Fantasy, Mystery',
#   'imdb_score': 7.5,
#   'movie_likes': 10000,
#   'director': 'David Yates',
#   'director_likes': 282.0,
#   'actor_1': 'Alan Rickman',
#   'actor_1_likes': 25000.0,
#   'actor_2': 'Daniel Radcliffe',
#   'actor_2_likes': 11000.0,
#   'actor_3': 'Rupert Grint',
#   'actor_3_likes': 10000.0},
#  {'imdb_id': 'tt2975590',
#   'title': 'Batman v Superman: Dawn of Justice',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 6.9,
#   'movie_likes': 197000,
#   'director': 'Zack Snyder',
#   'director_likes': 0.0,
#   'actor_1': 'Henry Cavill',
#   'actor_1_likes': 15000.0,
#   'actor_2': 'Lauren Cohan',
#   'actor_2_likes': 4000.0,
#   'actor_3': 'Alan D. Purwin',
#   'actor_3_likes': 2000.0},
#  {'imdb_id': 'tt0348150',
#   'title': 'Superman Returns',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 6.1,
#   'movie_likes': 0,
#   'director': 'Bryan Singer',
#   'director_likes': 0.0,
#   'actor_1': 'Kevin Spacey',
#   'actor_1_likes': 18000.0,
#   'actor_2': 'Marlon Brando',
#   'actor_2_likes': 10000.0,
#   'actor_3': 'Frank Langella',
#   'actor_3_likes': 903.0},
#  {'imdb_id': 'tt0830515',
#   'title': 'Quantum of Solace',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure',
#   'imdb_score': 6.7,
#   'movie_likes': 0,
#   'director': 'Marc Forster',
#   'director_likes': 395.0,
#   'actor_1': 'Giancarlo Giannini',
#   'actor_1_likes': 451.0,
#   'actor_2': 'Mathieu Amalric',
#   'actor_2_likes': 412.0,
#   'actor_3': 'Rory Kinnear',
#   'actor_3_likes': 393.0},
#  {'imdb_id': 'tt0383574',
#   'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy',
#   'imdb_score': 7.3,
#   'movie_likes': 5000,
#   'director': 'Gore Verbinski',
#   'director_likes': 563.0,
#   'actor_1': 'Johnny Depp',
#   'actor_1_likes': 40000.0,
#   'actor_2': 'Orlando Bloom',
#   'actor_2_likes': 5000.0,
#   'actor_3': 'Jack Davenport',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt1210819',
#   'title': 'The Lone Ranger',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Western',
#   'imdb_score': 6.5,
#   'movie_likes': 48000,
#   'director': 'Gore Verbinski',
#   'director_likes': 563.0,
#   'actor_1': 'Johnny Depp',
#   'actor_1_likes': 40000.0,
#   'actor_2': 'Ruth Wilson',
#   'actor_2_likes': 2000.0,
#   'actor_3': 'Tom Wilkinson',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt0770828',
#   'title': 'Man of Steel',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi',
#   'imdb_score': 7.2,
#   'movie_likes': 118000,
#   'director': 'Zack Snyder',
#   'director_likes': 0.0,
#   'actor_1': 'Henry Cavill',
#   'actor_1_likes': 15000.0,
#   'actor_2': 'Christopher Meloni',
#   'actor_2_likes': 3000.0,
#   'actor_3': 'Harry Lennix',
#   'actor_3_likes': 748.0},
#  {'imdb_id': 'tt0499448',
#   'title': 'The Chronicles of Narnia: Prince Caspian',
#   'rating': 'PG',
#   'genres': 'Action, Adventure, Family, Fantasy',
#   'imdb_score': 6.6,
#   'movie_likes': 0,
#   'director': 'Andrew Adamson',
#   'director_likes': 80.0,
#   'actor_1': 'Peter Dinklage',
#   'actor_1_likes': 22000.0,
#   'actor_2': 'Pierfrancesco Favino',
#   'actor_2_likes': 216.0,
#   'actor_3': 'Damián Alcázar',
#   'actor_3_likes': 201.0},
#  {'imdb_id': 'tt0848228',
#   'title': 'The Avengers',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 8.1,
#   'movie_likes': 123000,
#   'director': 'Joss Whedon',
#   'director_likes': 0.0,
#   'actor_1': 'Chris Hemsworth',
#   'actor_1_likes': 26000.0,
#   'actor_2': 'Robert Downey Jr.',
#   'actor_2_likes': 21000.0,
#   'actor_3': 'Scarlett Johansson',
#   'actor_3_likes': 19000.0},
#  {'imdb_id': 'tt1298650',
#   'title': 'Pirates of the Caribbean: On Stranger Tides',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy',
#   'imdb_score': 6.7,
#   'movie_likes': 58000,
#   'director': 'Rob Marshall',
#   'director_likes': 252.0,
#   'actor_1': 'Johnny Depp',
#   'actor_1_likes': 40000.0,
#   'actor_2': 'Sam Claflin',
#   'actor_2_likes': 11000.0,
#   'actor_3': 'Stephen Graham',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt1409024',
#   'title': 'Men in Black 3',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Comedy, Family, Fantasy, Sci-Fi',
#   'imdb_score': 6.8,
#   'movie_likes': 40000,
#   'director': 'Barry Sonnenfeld',
#   'director_likes': 188.0,
#   'actor_1': 'Will Smith',
#   'actor_1_likes': 10000.0,
#   'actor_2': 'Michael Stuhlbarg',
#   'actor_2_likes': 816.0,
#   'actor_3': 'Nicole Scherzinger',
#   'actor_3_likes': 718.0},
#  {'imdb_id': 'tt2310332',
#   'title': 'The Hobbit: The Battle of the Five Armies',
#   'rating': 'PG-13',
#   'genres': 'Adventure, Fantasy',
#   'imdb_score': 7.5,
#   'movie_likes': 65000,
#   'director': 'Peter Jackson',
#   'director_likes': 0.0,
#   'actor_1': 'Aidan Turner',
#   'actor_1_likes': 5000.0,
#   'actor_2': 'Adam Brown',
#   'actor_2_likes': 972.0,
#   'actor_3': 'James Nesbitt',
#   'actor_3_likes': 773.0},
#  {'imdb_id': 'tt0948470',
#   'title': 'The Amazing Spider-Man',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy',
#   'imdb_score': 7.0,
#   'movie_likes': 56000,
#   'director': 'Marc Webb',
#   'director_likes': 464.0,
#   'actor_1': 'Emma Stone',
#   'actor_1_likes': 15000.0,
#   'actor_2': 'Andrew Garfield',
#   'actor_2_likes': 10000.0,
#   'actor_3': 'Chris Zylka',
#   'actor_3_likes': 963.0},
#  {'imdb_id': 'tt0955308',
#   'title': 'Robin Hood',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Drama, History',
#   'imdb_score': 6.7,
#   'movie_likes': 17000,
#   'director': 'Ridley Scott',
#   'director_likes': 0.0,
#   'actor_1': 'Mark Addy',
#   'actor_1_likes': 891.0,
#   'actor_2': 'William Hurt',
#   'actor_2_likes': 882.0,
#   'actor_3': 'Scott Grimes',
#   'actor_3_likes': 738.0},
#  {'imdb_id': 'tt1170358',
#   'title': 'The Hobbit: The Desolation of Smaug',
#   'rating': 'PG-13',
#   'genres': 'Adventure, Fantasy',
#   'imdb_score': 7.9,
#   'movie_likes': 83000,
#   'director': 'Peter Jackson',
#   'director_likes': 0.0,
#   'actor_1': 'Aidan Turner',
#   'actor_1_likes': 5000.0,
#   'actor_2': 'Adam Brown',
#   'actor_2_likes': 972.0,
#   'actor_3': 'James Nesbitt',
#   'actor_3_likes': 773.0},
#  {'imdb_id': 'tt0385752',
#   'title': 'The Golden Compass',
#   'rating': 'PG-13',
#   'genres': 'Adventure, Family, Fantasy',
#   'imdb_score': 6.1,
#   'movie_likes': 0,
#   'director': 'Chris Weitz',
#   'director_likes': 129.0,
#   'actor_1': 'Christopher Lee',
#   'actor_1_likes': 16000.0,
#   'actor_2': 'Eva Green',
#   'actor_2_likes': 6000.0,
#   'actor_3': 'Kristin Scott Thomas',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt0360717',
#   'title': 'King Kong',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Drama, Romance',
#   'imdb_score': 7.2,
#   'movie_likes': 0,
#   'director': 'Peter Jackson',
#   'director_likes': 0.0,
#   'actor_1': 'Naomi Watts',
#   'actor_1_likes': 6000.0,
#   'actor_2': 'Thomas Kretschmann',
#   'actor_2_likes': 919.0,
#   'actor_3': 'Evan Parke',
#   'actor_3_likes': 84.0},
#  {'imdb_id': 'tt0120338',
#   'title': 'Titanic',
#   'rating': 'PG-13',
#   'genres': 'Drama, Romance',
#   'imdb_score': 7.7,
#   'movie_likes': 26000,
#   'director': 'James Cameron',
#   'director_likes': 0.0,
#   'actor_1': 'Leonardo DiCaprio',
#   'actor_1_likes': 29000.0,
#   'actor_2': 'Kate Winslet',
#   'actor_2_likes': 14000.0,
#   'actor_3': 'Gloria Stuart',
#   'actor_3_likes': 794.0},
#  {'imdb_id': 'tt3498820',
#   'title': 'Captain America: Civil War',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 8.2,
#   'movie_likes': 72000,
#   'director': 'Anthony Russo',
#   'director_likes': 94.0,
#   'actor_1': 'Robert Downey Jr.',
#   'actor_1_likes': 21000.0,
#   'actor_2': 'Scarlett Johansson',
#   'actor_2_likes': 19000.0,
#   'actor_3': 'Chris Evans',
#   'actor_3_likes': 11000.0},
#  {'imdb_id': 'tt1440129',
#   'title': 'Battleship',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi, Thriller',
#   'imdb_score': 5.9,
#   'movie_likes': 44000,
#   'director': 'Peter Berg',
#   'director_likes': 532.0,
#   'actor_1': 'Liam Neeson',
#   'actor_1_likes': 14000.0,
#   'actor_2': 'Alexander Skarsgård',
#   'actor_2_likes': 10000.0,
#   'actor_3': 'Tadanobu Asano',
#   'actor_3_likes': 627.0},
#  {'imdb_id': 'tt0369610',
#   'title': 'Jurassic World',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi, Thriller',
#   'imdb_score': 7.0,
#   'movie_likes': 150000,
#   'director': 'Colin Trevorrow',
#   'director_likes': 365.0,
#   'actor_1': 'Bryce Dallas Howard',
#   'actor_1_likes': 3000.0,
#   'actor_2': 'Judy Greer',
#   'actor_2_likes': 2000.0,
#   'actor_3': 'Omar Sy',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt1074638',
#   'title': 'Skyfall',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Thriller',
#   'imdb_score': 7.8,
#   'movie_likes': 80000,
#   'director': 'Sam Mendes',
#   'director_likes': 0.0,
#   'actor_1': 'Albert Finney',
#   'actor_1_likes': 883.0,
#   'actor_2': 'Helen McCrory',
#   'actor_2_likes': 563.0,
#   'actor_3': 'Rory Kinnear',
#   'actor_3_likes': 393.0},
#  {'imdb_id': 'tt0316654',
#   'title': 'Spider-Man 2',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy, Romance',
#   'imdb_score': 7.3,
#   'movie_likes': 0,
#   'director': 'Sam Raimi',
#   'director_likes': 0.0,
#   'actor_1': 'J.K. Simmons',
#   'actor_1_likes': 24000.0,
#   'actor_2': 'James Franco',
#   'actor_2_likes': 11000.0,
#   'actor_3': 'Kirsten Dunst',
#   'actor_3_likes': 4000.0},
#  {'imdb_id': 'tt1300854',
#   'title': 'Iron Man 3',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 7.2,
#   'movie_likes': 95000,
#   'director': 'Shane Black',
#   'director_likes': 1000.0,
#   'actor_1': 'Robert Downey Jr.',
#   'actor_1_likes': 21000.0,
#   'actor_2': 'Jon Favreau',
#   'actor_2_likes': 4000.0,
#   'actor_3': 'Don Cheadle',
#   'actor_3_likes': 3000.0},
#  {'imdb_id': 'tt1014759',
#   'title': 'Alice in Wonderland',
#   'rating': 'PG',
#   'genres': 'Adventure, Family, Fantasy',
#   'imdb_score': 6.5,
#   'movie_likes': 24000,
#   'director': 'Tim Burton',
#   'director_likes': 13000.0,
#   'actor_1': 'Johnny Depp',
#   'actor_1_likes': 40000.0,
#   'actor_2': 'Alan Rickman',
#   'actor_2_likes': 25000.0,
#   'actor_3': 'Anne Hathaway',
#   'actor_3_likes': 11000.0},
#  {'imdb_id': 'tt0376994',
#   'title': 'X-Men: The Last Stand',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi, Thriller',
#   'imdb_score': 6.8,
#   'movie_likes': 0,
#   'director': 'Brett Ratner',
#   'director_likes': 420.0,
#   'actor_1': 'Hugh Jackman',
#   'actor_1_likes': 20000.0,
#   'actor_2': 'Kelsey Grammer',
#   'actor_2_likes': 808.0,
#   'actor_3': 'Daniel Cudmore',
#   'actor_3_likes': 560.0},
#  {'imdb_id': 'tt1453405',
#   'title': 'Monsters University',
#   'rating': 'G',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy',
#   'imdb_score': 7.3,
#   'movie_likes': 44000,
#   'director': 'Dan Scanlon',
#   'director_likes': 37.0,
#   'actor_1': 'Steve Buscemi',
#   'actor_1_likes': 12000.0,
#   'actor_2': 'Tyler Labine',
#   'actor_2_likes': 779.0,
#   'actor_3': 'Sean Hayes',
#   'actor_3_likes': 760.0},
#  {'imdb_id': 'tt1055369',
#   'title': 'Transformers: Revenge of the Fallen',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 6.0,
#   'movie_likes': 0,
#   'director': 'Michael Bay',
#   'director_likes': 0.0,
#   'actor_1': 'Glenn Morshower',
#   'actor_1_likes': 894.0,
#   'actor_2': 'Kevin Dunn',
#   'actor_2_likes': 581.0,
#   'actor_3': 'Ramon Rodriguez',
#   'actor_3_likes': 464.0},
#  {'imdb_id': 'tt2109248',
#   'title': 'Transformers: Age of Extinction',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 5.7,
#   'movie_likes': 56000,
#   'director': 'Michael Bay',
#   'director_likes': 0.0,
#   'actor_1': 'Bingbing Li',
#   'actor_1_likes': 974.0,
#   'actor_2': 'Sophia Myles',
#   'actor_2_likes': 956.0,
#   'actor_3': 'Kelsey Grammer',
#   'actor_3_likes': 808.0},
#  {'imdb_id': 'tt1623205',
#   'title': 'Oz the Great and Powerful',
#   'rating': 'PG',
#   'genres': 'Adventure, Family, Fantasy',
#   'imdb_score': 6.4,
#   'movie_likes': 60000,
#   'director': 'Sam Raimi',
#   'director_likes': 0.0,
#   'actor_1': 'Tim Holmes',
#   'actor_1_likes': 44000.0,
#   'actor_2': 'Mila Kunis',
#   'actor_2_likes': 15000.0,
#   'actor_3': 'James Franco',
#   'actor_3_likes': 11000.0},
#  {'imdb_id': 'tt1872181',
#   'title': 'The Amazing Spider-Man 2',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi',
#   'imdb_score': 6.7,
#   'movie_likes': 41000,
#   'director': 'Marc Webb',
#   'director_likes': 464.0,
#   'actor_1': 'Emma Stone',
#   'actor_1_likes': 15000.0,
#   'actor_2': 'Andrew Garfield',
#   'actor_2_likes': 10000.0,
#   'actor_3': 'B.J. Novak',
#   'actor_3_likes': 825.0},
#  {'imdb_id': 'tt1104001',
#   'title': 'TRON: Legacy',
#   'rating': 'PG',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 6.8,
#   'movie_likes': 30000,
#   'director': 'Joseph Kosinski',
#   'director_likes': 364.0,
#   'actor_1': 'Jeff Bridges',
#   'actor_1_likes': 12000.0,
#   'actor_2': 'Olivia Wilde',
#   'actor_2_likes': 10000.0,
#   'actor_3': 'James Frain',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt1216475',
#   'title': 'Cars 2',
#   'rating': 'G',
#   'genres': 'Adventure, Animation, Comedy, Family, Sport',
#   'imdb_score': 6.3,
#   'movie_likes': 10000,
#   'director': 'John Lasseter',
#   'director_likes': 487.0,
#   'actor_1': 'Joe Mantegna',
#   'actor_1_likes': 1000.0,
#   'actor_2': 'Thomas Kretschmann',
#   'actor_2_likes': 919.0,
#   'actor_3': 'Eddie Izzard',
#   'actor_3_likes': 776.0},
#  {'imdb_id': 'tt1133985',
#   'title': 'Green Lantern',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 5.6,
#   'movie_likes': 24000,
#   'director': 'Martin Campbell',
#   'director_likes': 258.0,
#   'actor_1': 'Ryan Reynolds',
#   'actor_1_likes': 16000.0,
#   'actor_2': 'Temuera Morrison',
#   'actor_2_likes': 368.0,
#   'actor_3': 'Taika Waititi',
#   'actor_3_likes': 326.0},
#  {'imdb_id': 'tt0435761',
#   'title': 'Toy Story 3',
#   'rating': 'G',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy',
#   'imdb_score': 8.3,
#   'movie_likes': 30000,
#   'director': 'Lee Unkrich',
#   'director_likes': 125.0,
#   'actor_1': 'Tom Hanks',
#   'actor_1_likes': 15000.0,
#   'actor_2': 'John Ratzenberger',
#   'actor_2_likes': 1000.0,
#   'actor_3': 'Don Rickles',
#   'actor_3_likes': 721.0},
#  {'imdb_id': 'tt0438488',
#   'title': 'Terminator Salvation',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 6.6,
#   'movie_likes': 0,
#   'director': 'McG',
#   'director_likes': 368.0,
#   'actor_1': 'Christian Bale',
#   'actor_1_likes': 23000.0,
#   'actor_2': 'Bryce Dallas Howard',
#   'actor_2_likes': 3000.0,
#   'actor_3': 'Common',
#   'actor_3_likes': 988.0},
#  {'imdb_id': 'tt2820852',
#   'title': 'Furious 7',
#   'rating': 'PG-13',
#   'genres': 'Action, Crime, Thriller',
#   'imdb_score': 7.2,
#   'movie_likes': 94000,
#   'director': 'James Wan',
#   'director_likes': 0.0,
#   'actor_1': 'Jason Statham',
#   'actor_1_likes': 26000.0,
#   'actor_2': 'Paul Walker',
#   'actor_2_likes': 23000.0,
#   'actor_3': 'Vin Diesel',
#   'actor_3_likes': 14000.0},
#  {'imdb_id': 'tt0816711',
#   'title': 'World War Z',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Horror, Sci-Fi, Thriller',
#   'imdb_score': 7.0,
#   'movie_likes': 129000,
#   'director': 'Marc Forster',
#   'director_likes': 395.0,
#   'actor_1': 'Peter Capaldi',
#   'actor_1_likes': 17000.0,
#   'actor_2': 'Brad Pitt',
#   'actor_2_likes': 11000.0,
#   'actor_3': 'Mireille Enos',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt1877832',
#   'title': 'X-Men: Days of Future Past',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy, Sci-Fi, Thriller',
#   'imdb_score': 8.0,
#   'movie_likes': 82000,
#   'director': 'Bryan Singer',
#   'director_likes': 0.0,
#   'actor_1': 'Jennifer Lawrence',
#   'actor_1_likes': 34000.0,
#   'actor_2': 'Peter Dinklage',
#   'actor_2_likes': 22000.0,
#   'actor_3': 'Hugh Jackman',
#   'actor_3_likes': 20000.0},
#  {'imdb_id': 'tt1408101',
#   'title': 'Star Trek Into Darkness',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 7.8,
#   'movie_likes': 92000,
#   'director': 'J.J. Abrams',
#   'director_likes': 14000.0,
#   'actor_1': 'Benedict Cumberbatch',
#   'actor_1_likes': 19000.0,
#   'actor_2': 'Bruce Greenwood',
#   'actor_2_likes': 981.0,
#   'actor_3': 'Noel Clarke',
#   'actor_3_likes': 928.0},
#  {'imdb_id': 'tt1351685',
#   'title': 'Jack the Giant Slayer',
#   'rating': 'PG-13',
#   'genres': 'Adventure, Fantasy',
#   'imdb_score': 6.3,
#   'movie_likes': 22000,
#   'director': 'Bryan Singer',
#   'director_likes': 0.0,
#   'actor_1': 'Eddie Marsan',
#   'actor_1_likes': 979.0,
#   'actor_2': 'Ewen Bremner',
#   'actor_2_likes': 557.0,
#   'actor_3': 'Ralph Brown',
#   'actor_3_likes': 140.0},
#  {'imdb_id': 'tt1343092',
#   'title': 'The Great Gatsby',
#   'rating': 'PG-13',
#   'genres': 'Drama, Romance',
#   'imdb_score': 7.3,
#   'movie_likes': 115000,
#   'director': 'Baz Luhrmann',
#   'director_likes': 1000.0,
#   'actor_1': 'Leonardo DiCaprio',
#   'actor_1_likes': 29000.0,
#   'actor_2': 'Elizabeth Debicki',
#   'actor_2_likes': 509.0,
#   'actor_3': 'Steve Bisley',
#   'actor_3_likes': 77.0},
#  {'imdb_id': 'tt0473075',
#   'title': 'Prince of Persia: The Sands of Time',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy, Romance',
#   'imdb_score': 6.6,
#   'movie_likes': 23000,
#   'director': 'Mike Newell',
#   'director_likes': 179.0,
#   'actor_1': 'Jake Gyllenhaal',
#   'actor_1_likes': 15000.0,
#   'actor_2': 'Richard Coyle',
#   'actor_2_likes': 567.0,
#   'actor_3': 'Reece Ritchie',
#   'actor_3_likes': 236.0},
#  {'imdb_id': 'tt1663662',
#   'title': 'Pacific Rim',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 7.0,
#   'movie_likes': 83000,
#   'director': 'Guillermo del Toro',
#   'director_likes': 0.0,
#   'actor_1': 'Charlie Hunnam',
#   'actor_1_likes': 16000.0,
#   'actor_2': 'Clifton Collins Jr.',
#   'actor_2_likes': 968.0,
#   'actor_3': 'Larry Joe Campbell',
#   'actor_3_likes': 919.0},
#  {'imdb_id': 'tt1399103',
#   'title': 'Transformers: Dark of the Moon',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 6.3,
#   'movie_likes': 46000,
#   'director': 'Michael Bay',
#   'director_likes': 0.0,
#   'actor_1': 'Glenn Morshower',
#   'actor_1_likes': 894.0,
#   'actor_2': 'Lester Speight',
#   'actor_2_likes': 829.0,
#   'actor_3': 'Kevin Dunn',
#   'actor_3_likes': 581.0},
#  {'imdb_id': 'tt0367882',
#   'title': 'Indiana Jones and the Kingdom of the Crystal Skull',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy',
#   'imdb_score': 6.2,
#   'movie_likes': 5000,
#   'director': 'Steven Spielberg',
#   'director_likes': 14000.0,
#   'actor_1': 'Harrison Ford',
#   'actor_1_likes': 11000.0,
#   'actor_2': 'Ray Winstone',
#   'actor_2_likes': 1000.0,
#   'actor_3': 'Jim Broadbent',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt1979388',
#   'title': 'The Good Dinosaur',
#   'rating': 'PG',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy',
#   'imdb_score': 6.8,
#   'movie_likes': 20000,
#   'director': 'Peter Sohn',
#   'director_likes': 113.0,
#   'actor_1': 'A.J. Buckley',
#   'actor_1_likes': 275.0,
#   'actor_2': 'Jack McGraw',
#   'actor_2_likes': 150.0,
#   'actor_3': 'Peter Sohn',
#   'actor_3_likes': 113.0},
#  {'imdb_id': 'tt1217209',
#   'title': 'Brave',
#   'rating': 'PG',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy',
#   'imdb_score': 7.2,
#   'movie_likes': 39000,
#   'director': 'Mark Andrews',
#   'director_likes': 56.0,
#   'actor_1': 'Kelly Macdonald',
#   'actor_1_likes': 2000.0,
#   'actor_2': 'John Ratzenberger',
#   'actor_2_likes': 1000.0,
#   'actor_3': 'Julie Walters',
#   'actor_3_likes': 838.0},
#  {'imdb_id': 'tt2660888',
#   'title': 'Star Trek Beyond',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi, Thriller',
#   'imdb_score': 7.5,
#   'movie_likes': 30000,
#   'director': 'Justin Lin',
#   'director_likes': 681.0,
#   'actor_1': 'Sofia Boutella',
#   'actor_1_likes': 998.0,
#   'actor_2': 'Melissa Roxburgh',
#   'actor_2_likes': 119.0,
#   'actor_3': 'Lydia Wilson',
#   'actor_3_likes': 105.0},
#  {'imdb_id': 'tt0910970',
#   'title': 'WALL·E',
#   'rating': 'G',
#   'genres': 'Adventure, Animation, Family, Sci-Fi',
#   'imdb_score': 8.4,
#   'movie_likes': 16000,
#   'director': 'Andrew Stanton',
#   'director_likes': 475.0,
#   'actor_1': 'John Ratzenberger',
#   'actor_1_likes': 1000.0,
#   'actor_2': 'Fred Willard',
#   'actor_2_likes': 729.0,
#   'actor_3': 'Jeff Garlin',
#   'actor_3_likes': 522.0},
#  {'imdb_id': 'tt0293564',
#   'title': 'Rush Hour 3',
#   'rating': 'PG-13',
#   'genres': 'Action, Comedy, Crime, Thriller',
#   'imdb_score': 6.2,
#   'movie_likes': 0,
#   'director': 'Brett Ratner',
#   'director_likes': 420.0,
#   'actor_1': 'Tzi Ma',
#   'actor_1_likes': 268.0,
#   'actor_2': 'Dana Ivey',
#   'actor_2_likes': 268.0,
#   'actor_3': 'Noémie Lenoir',
#   'actor_3_likes': 173.0},
#  {'imdb_id': 'tt1190080',
#   'title': '2012',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 5.8,
#   'movie_likes': 13000,
#   'director': 'Roland Emmerich',
#   'director_likes': 776.0,
#   'actor_1': 'Oliver Platt',
#   'actor_1_likes': 1000.0,
#   'actor_2': 'Liam James',
#   'actor_2_likes': 468.0,
#   'actor_3': 'Tom McCarthy',
#   'actor_3_likes': 310.0},
#  {'imdb_id': 'tt1067106',
#   'title': 'A Christmas Carol',
#   'rating': 'PG',
#   'genres': 'Animation, Drama, Family, Fantasy',
#   'imdb_score': 6.8,
#   'movie_likes': 0,
#   'director': 'Robert Zemeckis',
#   'director_likes': 0.0,
#   'actor_1': 'Robin Wright',
#   'actor_1_likes': 18000.0,
#   'actor_2': 'Colin Firth',
#   'actor_2_likes': 14000.0,
#   'actor_3': 'Gary Oldman',
#   'actor_3_likes': 10000.0},
#  {'imdb_id': 'tt1617661',
#   'title': 'Jupiter Ascending',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 5.4,
#   'movie_likes': 44000,
#   'director': 'Lana Wachowski',
#   'director_likes': 0.0,
#   'actor_1': 'Channing Tatum',
#   'actor_1_likes': 17000.0,
#   'actor_2': 'Mila Kunis',
#   'actor_2_likes': 15000.0,
#   'actor_3': 'Eddie Redmayne',
#   'actor_3_likes': 13000.0},
#  {'imdb_id': 'tt0918940',
#   'title': 'The Legend of Tarzan',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Drama, Romance',
#   'imdb_score': 6.6,
#   'movie_likes': 29000,
#   'director': 'David Yates',
#   'director_likes': 282.0,
#   'actor_1': 'Christoph Waltz',
#   'actor_1_likes': 11000.0,
#   'actor_2': 'Alexander Skarsgård',
#   'actor_2_likes': 10000.0,
#   'actor_3': 'Casper Crump',
#   'actor_3_likes': 103.0},
#  {'imdb_id': 'tt0363771',
#   'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'rating': 'PG',
#   'genres': 'Adventure, Family, Fantasy',
#   'imdb_score': 6.9,
#   'movie_likes': 0,
#   'director': 'Andrew Adamson',
#   'director_likes': 80.0,
#   'actor_1': 'Jim Broadbent',
#   'actor_1_likes': 1000.0,
#   'actor_2': 'Kiran Shah',
#   'actor_2_likes': 190.0,
#   'actor_3': 'Shane Rangi',
#   'actor_3_likes': 82.0},
#  {'imdb_id': 'tt3385516',
#   'title': 'X-Men: Apocalypse',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 7.3,
#   'movie_likes': 54000,
#   'director': 'Bryan Singer',
#   'director_likes': 0.0,
#   'actor_1': 'Jennifer Lawrence',
#   'actor_1_likes': 34000.0,
#   'actor_2': 'Michael Fassbender',
#   'actor_2_likes': 13000.0,
#   'actor_3': 'Tye Sheridan',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt0468569',
#   'title': 'The Dark Knight',
#   'rating': 'PG-13',
#   'genres': 'Action, Crime, Drama, Thriller',
#   'imdb_score': 9.0,
#   'movie_likes': 37000,
#   'director': 'Christopher Nolan',
#   'director_likes': 22000.0,
#   'actor_1': 'Christian Bale',
#   'actor_1_likes': 23000.0,
#   'actor_2': 'Heath Ledger',
#   'actor_2_likes': 13000.0,
#   'actor_3': 'Morgan Freeman',
#   'actor_3_likes': 11000.0},
#  {'imdb_id': 'tt1049413',
#   'title': 'Up',
#   'rating': 'PG',
#   'genres': 'Adventure, Animation, Comedy, Family',
#   'imdb_score': 8.3,
#   'movie_likes': 27000,
#   'director': 'Pete Docter',
#   'director_likes': 0.0,
#   'actor_1': 'John Ratzenberger',
#   'actor_1_likes': 1000.0,
#   'actor_2': 'Delroy Lindo',
#   'actor_2_likes': 848.0,
#   'actor_3': 'Jess Harnell',
#   'actor_3_likes': 262.0},
#  {'imdb_id': 'tt0892782',
#   'title': 'Monsters vs. Aliens',
#   'rating': 'PG',
#   'genres': 'Action, Adventure, Animation, Comedy, Family, Sci-Fi',
#   'imdb_score': 6.5,
#   'movie_likes': 0,
#   'director': 'Rob Letterman',
#   'director_likes': 11.0,
#   'actor_1': 'Amy Poehler',
#   'actor_1_likes': 1000.0,
#   'actor_2': 'Rainn Wilson',
#   'actor_2_likes': 973.0,
#   'actor_3': 'Stephen Colbert',
#   'actor_3_likes': 459.0},
#  {'imdb_id': 'tt0371746',
#   'title': 'Iron Man',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 7.9,
#   'movie_likes': 10000,
#   'director': 'Jon Favreau',
#   'director_likes': 4000.0,
#   'actor_1': 'Robert Downey Jr.',
#   'actor_1_likes': 21000.0,
#   'actor_2': 'Jeff Bridges',
#   'actor_2_likes': 12000.0,
#   'actor_3': 'Jon Favreau',
#   'actor_3_likes': 4000.0},
#  {'imdb_id': 'tt0970179',
#   'title': 'Hugo',
#   'rating': 'PG',
#   'genres': 'Adventure, Drama, Family, Mystery',
#   'imdb_score': 7.5,
#   'movie_likes': 42000,
#   'director': 'Martin Scorsese',
#   'director_likes': 17000.0,
#   'actor_1': 'Chloë Grace Moretz',
#   'actor_1_likes': 17000.0,
#   'actor_2': 'Christopher Lee',
#   'actor_2_likes': 16000.0,
#   'actor_3': 'Ray Winstone',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt0120891',
#   'title': 'Wild Wild West',
#   'rating': 'PG-13',
#   'genres': 'Action, Comedy, Sci-Fi, Western',
#   'imdb_score': 4.8,
#   'movie_likes': 0,
#   'director': 'Barry Sonnenfeld',
#   'director_likes': 188.0,
#   'actor_1': 'Will Smith',
#   'actor_1_likes': 10000.0,
#   'actor_2': 'Salma Hayek',
#   'actor_2_likes': 4000.0,
#   'actor_3': 'Bai Ling',
#   'actor_3_likes': 582.0},
#  {'imdb_id': 'tt0859163',
#   'title': 'The Mummy: Tomb of the Dragon Emperor',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy, Horror, Thriller',
#   'imdb_score': 5.2,
#   'movie_likes': 0,
#   'director': 'Rob Cohen',
#   'director_likes': 357.0,
#   'actor_1': 'Jet Li',
#   'actor_1_likes': 5000.0,
#   'actor_2': 'Brendan Fraser',
#   'actor_2_likes': 3000.0,
#   'actor_3': 'Russell Wong',
#   'actor_3_likes': 595.0},
#  {'imdb_id': 'tt1386697',
#   'title': 'Suicide Squad',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Comedy, Sci-Fi',
#   'imdb_score': 6.9,
#   'movie_likes': 80000,
#   'director': 'David Ayer',
#   'director_likes': 452.0,
#   'actor_1': 'Will Smith',
#   'actor_1_likes': 10000.0,
#   'actor_2': 'Robin Atkin Downes',
#   'actor_2_likes': 336.0,
#   'actor_3': 'Ike Barinholtz',
#   'actor_3_likes': 329.0},
#  {'imdb_id': 'tt0413099',
#   'title': 'Evan Almighty',
#   'rating': 'PG',
#   'genres': 'Comedy, Family, Fantasy',
#   'imdb_score': 5.4,
#   'movie_likes': 2000,
#   'director': 'Tom Shadyac',
#   'director_likes': 293.0,
#   'actor_1': 'Jimmy Bennett',
#   'actor_1_likes': 87000.0,
#   'actor_2': 'Morgan Freeman',
#   'actor_2_likes': 11000.0,
#   'actor_3': 'Steve Carell',
#   'actor_3_likes': 7000.0},
#  {'imdb_id': 'tt1631867',
#   'title': 'Edge of Tomorrow',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 7.9,
#   'movie_likes': 77000,
#   'director': 'Doug Liman',
#   'director_likes': 218.0,
#   'actor_1': 'Tom Cruise',
#   'actor_1_likes': 10000.0,
#   'actor_2': 'Lara Pulver',
#   'actor_2_likes': 854.0,
#   'actor_3': 'Noah Taylor',
#   'actor_3_likes': 509.0},
#  {'imdb_id': 'tt0114898',
#   'title': 'Waterworld',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi, Thriller',
#   'imdb_score': 6.1,
#   'movie_likes': 0,
#   'director': 'Kevin Reynolds',
#   'director_likes': 58.0,
#   'actor_1': 'Jeanne Tripplehorn',
#   'actor_1_likes': 711.0,
#   'actor_2': 'Rick Aviles',
#   'actor_2_likes': 60.0,
#   'actor_3': 'Zakes Mokae',
#   'actor_3_likes': 60.0},
#  {'imdb_id': 'tt1046173',
#   'title': 'G.I. Joe: The Rise of Cobra',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi, Thriller',
#   'imdb_score': 5.8,
#   'movie_likes': 0,
#   'director': 'Stephen Sommers',
#   'director_likes': 208.0,
#   'actor_1': 'Joseph Gordon-Levitt',
#   'actor_1_likes': 23000.0,
#   'actor_2': 'Dennis Quaid',
#   'actor_2_likes': 2000.0,
#   'actor_3': 'Leo Howard',
#   'actor_3_likes': 570.0},
#  {'imdb_id': 'tt2096673',
#   'title': 'Inside Out',
#   'rating': 'PG',
#   'genres': 'Adventure, Animation, Comedy, Drama, Family, Fantasy',
#   'imdb_score': 8.3,
#   'movie_likes': 118000,
#   'director': 'Pete Docter',
#   'director_likes': 0.0,
#   'actor_1': 'Amy Poehler',
#   'actor_1_likes': 1000.0,
#   'actor_2': 'Mindy Kaling',
#   'actor_2_likes': 767.0,
#   'actor_3': 'Phyllis Smith',
#   'actor_3_likes': 384.0},
#  {'imdb_id': 'tt3040964',
#   'title': 'The Jungle Book',
#   'rating': 'PG',
#   'genres': 'Adventure, Drama, Family, Fantasy',
#   'imdb_score': 7.8,
#   'movie_likes': 65000,
#   'director': 'Jon Favreau',
#   'director_likes': 4000.0,
#   'actor_1': 'Scarlett Johansson',
#   'actor_1_likes': 19000.0,
#   'actor_2': 'Bill Murray',
#   'actor_2_likes': 13000.0,
#   'actor_3': 'Garry Shandling',
#   'actor_3_likes': 591.0},
#  {'imdb_id': 'tt1228705',
#   'title': 'Iron Man 2',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 7.0,
#   'movie_likes': 18000,
#   'director': 'Jon Favreau',
#   'director_likes': 4000.0,
#   'actor_1': 'Robert Downey Jr.',
#   'actor_1_likes': 21000.0,
#   'actor_2': 'Scarlett Johansson',
#   'actor_2_likes': 19000.0,
#   'actor_3': 'Jon Favreau',
#   'actor_3_likes': 4000.0},
#  {'imdb_id': 'tt1735898',
#   'title': 'Snow White and the Huntsman',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Drama, Fantasy',
#   'imdb_score': 6.1,
#   'movie_likes': 53000,
#   'director': 'Rupert Sanders',
#   'director_likes': 274.0,
#   'actor_1': 'Chris Hemsworth',
#   'actor_1_likes': 26000.0,
#   'actor_2': 'Kristen Stewart',
#   'actor_2_likes': 17000.0,
#   'actor_3': 'Sam Claflin',
#   'actor_3_likes': 11000.0},
#  {'imdb_id': 'tt1587310',
#   'title': 'Maleficent',
#   'rating': 'PG',
#   'genres': 'Action, Adventure, Family, Fantasy, Romance',
#   'imdb_score': 7.0,
#   'movie_likes': 89000,
#   'director': 'Robert Stromberg',
#   'director_likes': 171.0,
#   'actor_1': 'Angelina Jolie Pitt',
#   'actor_1_likes': 11000.0,
#   'actor_2': 'Sharlto Copley',
#   'actor_2_likes': 2000.0,
#   'actor_3': 'Sam Riley',
#   'actor_3_likes': 846.0},
#  {'imdb_id': 'tt2103281',
#   'title': 'Dawn of the Planet of the Apes',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Drama, Sci-Fi',
#   'imdb_score': 7.6,
#   'movie_likes': 45000,
#   'director': 'Matt Reeves',
#   'director_likes': 198.0,
#   'actor_1': 'Gary Oldman',
#   'actor_1_likes': 10000.0,
#   'actor_2': 'Judy Greer',
#   'actor_2_likes': 2000.0,
#   'actor_3': 'Kodi Smit-McPhee',
#   'actor_3_likes': 884.0},
#  {'imdb_id': 'tt1321869',
#   'title': 'The Lovers',
#   'rating': 'R',
#   'genres': 'Action, Adventure, Romance, Sci-Fi',
#   'imdb_score': 4.5,
#   'movie_likes': 677,
#   'director': 'Roland Joffé',
#   'director_likes': 596.0,
#   'actor_1': 'Tamsin Egerton',
#   'actor_1_likes': 622.0,
#   'actor_2': 'Alice Englert',
#   'actor_2_likes': 525.0,
#   'actor_3': 'Bipasha Basu',
#   'actor_3_likes': 283.0},
#  {'imdb_id': 'tt1335975',
#   'title': '47 Ronin',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Drama, Fantasy',
#   'imdb_score': 6.3,
#   'movie_likes': 35000,
#   'director': 'Carl Rinsch',
#   'director_likes': 47.0,
#   'actor_1': 'Keanu Reeves',
#   'actor_1_likes': 18000.0,
#   'actor_2': 'Cary-Hiroyuki Tagawa',
#   'actor_2_likes': 1000.0,
#   'actor_3': 'Jin Akanishi',
#   'actor_3_likes': 982.0},
#  {'imdb_id': 'tt1843866',
#   'title': 'Captain America: The Winter Soldier',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 7.8,
#   'movie_likes': 55000,
#   'director': 'Anthony Russo',
#   'director_likes': 94.0,
#   'actor_1': 'Scarlett Johansson',
#   'actor_1_likes': 19000.0,
#   'actor_2': 'Chris Evans',
#   'actor_2_likes': 11000.0,
#   'actor_3': 'Hayley Atwell',
#   'actor_3_likes': 2000.0},
#  {'imdb_id': 'tt0892791',
#   'title': 'Shrek Forever After',
#   'rating': 'PG',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy',
#   'imdb_score': 6.4,
#   'movie_likes': 0,
#   'director': 'Mike Mitchell',
#   'director_likes': 31.0,
#   'actor_1': 'Jon Hamm',
#   'actor_1_likes': 4000.0,
#   'actor_2': 'Kathy Griffin',
#   'actor_2_likes': 225.0,
#   'actor_3': 'Mary Kay Place',
#   'actor_3_likes': 213.0},
#  {'imdb_id': 'tt1964418',
#   'title': 'Tomorrowland',
#   'rating': 'PG',
#   'genres': 'Action, Adventure, Family, Mystery, Sci-Fi',
#   'imdb_score': 6.5,
#   'movie_likes': 37000,
#   'director': 'Brad Bird',
#   'director_likes': 663.0,
#   'actor_1': 'Judy Greer',
#   'actor_1_likes': 2000.0,
#   'actor_2': 'Chris Bauer',
#   'actor_2_likes': 638.0,
#   'actor_3': 'Thomas Robinson',
#   'actor_3_likes': 604.0},
#  {'imdb_id': 'tt2245084',
#   'title': 'Big Hero 6',
#   'rating': 'PG',
#   'genres': 'Action, Adventure, Animation, Comedy, Drama, Family, Sci-Fi',
#   'imdb_score': 7.9,
#   'movie_likes': 41000,
#   'director': 'Don Hall',
#   'director_likes': 38.0,
#   'actor_1': 'Damon Wayans Jr.',
#   'actor_1_likes': 756.0,
#   'actor_2': 'Daniel Henney',
#   'actor_2_likes': 719.0,
#   'actor_3': 'Abraham Benrubi',
#   'actor_3_likes': 562.0},
#  {'imdb_id': 'tt1772341',
#   'title': 'Wreck-It Ralph',
#   'rating': 'PG',
#   'genres': 'Adventure, Animation, Comedy, Family, Sci-Fi',
#   'imdb_score': 7.8,
#   'movie_likes': 40000,
#   'director': 'Rich Moore',
#   'director_likes': 66.0,
#   'actor_1': 'Jack McBrayer',
#   'actor_1_likes': 975.0,
#   'actor_2': 'Sarah Silverman',
#   'actor_2_likes': 931.0,
#   'actor_3': 'Joe Lo Truglio',
#   'actor_3_likes': 833.0},
#  {'imdb_id': 'tt0338348',
#   'title': 'The Polar Express',
#   'rating': 'G',
#   'genres': 'Adventure, Animation, Family, Fantasy',
#   'imdb_score': 6.6,
#   'movie_likes': 10000,
#   'director': 'Robert Zemeckis',
#   'director_likes': 0.0,
#   'actor_1': 'Tom Hanks',
#   'actor_1_likes': 15000.0,
#   'actor_2': 'Eddie Deezen',
#   'actor_2_likes': 726.0,
#   'actor_3': 'Peter Scolari',
#   'actor_3_likes': 267.0},
#  {'imdb_id': 'tt1628841',
#   'title': 'Independence Day: Resurgence',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 5.5,
#   'movie_likes': 67000,
#   'director': 'Roland Emmerich',
#   'director_likes': 776.0,
#   'actor_1': 'Vivica A. Fox',
#   'actor_1_likes': 890.0,
#   'actor_2': 'Sela Ward',
#   'actor_2_likes': 812.0,
#   'actor_3': 'Judd Hirsch',
#   'actor_3_likes': 535.0},
#  {'imdb_id': 'tt0892769',
#   'title': 'How to Train Your Dragon',
#   'rating': 'PG',
#   'genres': 'Adventure, Animation, Family, Fantasy',
#   'imdb_score': 8.2,
#   'movie_likes': 33000,
#   'director': 'Dean DeBlois',
#   'director_likes': 255.0,
#   'actor_1': 'Gerard Butler',
#   'actor_1_likes': 18000.0,
#   'actor_2': 'America Ferrera',
#   'actor_2_likes': 953.0,
#   'actor_3': 'Craig Ferguson',
#   'actor_3_likes': 759.0},
#  {'imdb_id': 'tt0181852',
#   'title': 'Terminator 3: Rise of the Machines',
#   'rating': 'R',
#   'genres': 'Action, Sci-Fi',
#   'imdb_score': 6.4,
#   'movie_likes': 0,
#   'director': 'Jonathan Mostow',
#   'director_likes': 84.0,
#   'actor_1': 'Nick Stahl',
#   'actor_1_likes': 648.0,
#   'actor_2': 'M.C. Gainey',
#   'actor_2_likes': 284.0,
#   'actor_3': 'Carolyn Hennesy',
#   'actor_3_likes': 191.0},
#  {'imdb_id': 'tt2015381',
#   'title': 'Guardians of the Galaxy',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 8.1,
#   'movie_likes': 96000,
#   'director': 'James Gunn',
#   'director_likes': 571.0,
#   'actor_1': 'Bradley Cooper',
#   'actor_1_likes': 14000.0,
#   'actor_2': 'Vin Diesel',
#   'actor_2_likes': 14000.0,
#   'actor_3': 'Djimon Hounsou',
#   'actor_3_likes': 3000.0},
#  {'imdb_id': 'tt0816692',
#   'title': 'Interstellar',
#   'rating': 'PG-13',
#   'genres': 'Adventure, Drama, Sci-Fi',
#   'imdb_score': 8.6,
#   'movie_likes': 349000,
#   'director': 'Christopher Nolan',
#   'director_likes': 22000.0,
#   'actor_1': 'Matthew McConaughey',
#   'actor_1_likes': 11000.0,
#   'actor_2': 'Anne Hathaway',
#   'actor_2_likes': 11000.0,
#   'actor_3': 'Mackenzie Foy',
#   'actor_3_likes': 6000.0},
#  {'imdb_id': 'tt1375666',
#   'title': 'Inception',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi, Thriller',
#   'imdb_score': 8.8,
#   'movie_likes': 175000,
#   'director': 'Christopher Nolan',
#   'director_likes': 22000.0,
#   'actor_1': 'Leonardo DiCaprio',
#   'actor_1_likes': 29000.0,
#   'actor_2': 'Tom Hardy',
#   'actor_2_likes': 27000.0,
#   'actor_3': 'Joseph Gordon-Levitt',
#   'actor_3_likes': 23000.0},
#  {'imdb_id': 'tt4262980',
#   'title': 'Godzilla Resurgence',
#   'rating': nan,
#   'genres': 'Action, Adventure, Drama, Horror, Sci-Fi',
#   'imdb_score': 8.2,
#   'movie_likes': 0,
#   'director': 'Hideaki Anno',
#   'director_likes': 28.0,
#   'actor_1': 'Mark Chinnery',
#   'actor_1_likes': 544.0,
#   'actor_2': "Shin'ya Tsukamoto",
#   'actor_2_likes': 106.0,
#   'actor_3': 'Atsuko Maeda',
#   'actor_3_likes': 12.0},
#  {'imdb_id': 'tt0903624',
#   'title': 'The Hobbit: An Unexpected Journey',
#   'rating': 'PG-13',
#   'genres': 'Adventure, Fantasy',
#   'imdb_score': 7.9,
#   'movie_likes': 166000,
#   'director': 'Peter Jackson',
#   'director_likes': 0.0,
#   'actor_1': 'Aidan Turner',
#   'actor_1_likes': 5000.0,
#   'actor_2': 'Adam Brown',
#   'actor_2_likes': 972.0,
#   'actor_3': 'James Nesbitt',
#   'actor_3_likes': 773.0},
#  {'imdb_id': 'tt0232500',
#   'title': 'The Fast and the Furious',
#   'rating': 'PG-13',
#   'genres': 'Action, Crime, Thriller',
#   'imdb_score': 6.7,
#   'movie_likes': 14000,
#   'director': 'Rob Cohen',
#   'director_likes': 357.0,
#   'actor_1': 'Paul Walker',
#   'actor_1_likes': 23000.0,
#   'actor_2': 'Vin Diesel',
#   'actor_2_likes': 14000.0,
#   'actor_3': 'Jordana Brewster',
#   'actor_3_likes': 4000.0},
#  {'imdb_id': 'tt0421715',
#   'title': 'The Curious Case of Benjamin Button',
#   'rating': 'PG-13',
#   'genres': 'Drama, Fantasy, Romance',
#   'imdb_score': 7.8,
#   'movie_likes': 23000,
#   'director': 'David Fincher',
#   'director_likes': 21000.0,
#   'actor_1': 'Brad Pitt',
#   'actor_1_likes': 11000.0,
#   'actor_2': 'Jason Flemyng',
#   'actor_2_likes': 1000.0,
#   'actor_3': 'Julia Ormond',
#   'actor_3_likes': 919.0},
#  {'imdb_id': 'tt1270798',
#   'title': 'X-Men: First Class',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 7.8,
#   'movie_likes': 54000,
#   'director': 'Matthew Vaughn',
#   'director_likes': 905.0,
#   'actor_1': 'Jennifer Lawrence',
#   'actor_1_likes': 34000.0,
#   'actor_2': 'Michael Fassbender',
#   'actor_2_likes': 13000.0,
#   'actor_3': 'Oliver Platt',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt1951266',
#   'title': 'The Hunger Games: Mockingjay - Part 2',
#   'rating': 'PG-13',
#   'genres': 'Adventure, Sci-Fi',
#   'imdb_score': 6.6,
#   'movie_likes': 38000,
#   'director': 'Francis Lawrence',
#   'director_likes': 508.0,
#   'actor_1': 'Jennifer Lawrence',
#   'actor_1_likes': 34000.0,
#   'actor_2': 'Philip Seymour Hoffman',
#   'actor_2_likes': 22000.0,
#   'actor_3': 'Josh Hutcherson',
#   'actor_3_likes': 14000.0},
#  {'imdb_id': 'tt0963966',
#   'title': "The Sorcerer's Apprentice",
#   'rating': 'PG',
#   'genres': 'Action, Adventure, Family, Fantasy',
#   'imdb_score': 6.1,
#   'movie_likes': 11000,
#   'director': 'Jon Turteltaub',
#   'director_likes': 226.0,
#   'actor_1': 'Nicolas Cage',
#   'actor_1_likes': 12000.0,
#   'actor_2': 'Omar Benson Miller',
#   'actor_2_likes': 418.0,
#   'actor_3': 'Robert Capron',
#   'actor_3_likes': 370.0},
#  {'imdb_id': 'tt0409182',
#   'title': 'Poseidon',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Drama, Thriller',
#   'imdb_score': 5.6,
#   'movie_likes': 0,
#   'director': 'Wolfgang Petersen',
#   'director_likes': 249.0,
#   'actor_1': 'Jimmy Bennett',
#   'actor_1_likes': 87000.0,
#   'actor_2': 'Mike Vogel',
#   'actor_2_likes': 2000.0,
#   'actor_3': 'Andre Braugher',
#   'actor_3_likes': 702.0},
#  {'imdb_id': 'tt2567026',
#   'title': 'Alice Through the Looking Glass',
#   'rating': 'PG',
#   'genres': 'Adventure, Family, Fantasy',
#   'imdb_score': 6.4,
#   'movie_likes': 30000,
#   'director': 'James Bobin',
#   'director_likes': 33.0,
#   'actor_1': 'Johnny Depp',
#   'actor_1_likes': 40000.0,
#   'actor_2': 'Alan Rickman',
#   'actor_2_likes': 25000.0,
#   'actor_3': 'Anne Hathaway',
#   'actor_3_likes': 11000.0},
#  {'imdb_id': 'tt0413267',
#   'title': 'Shrek the Third',
#   'rating': 'PG',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy',
#   'imdb_score': 6.1,
#   'movie_likes': 0,
#   'director': 'Chris Miller',
#   'director_likes': 50.0,
#   'actor_1': 'Justin Timberlake',
#   'actor_1_likes': 3000.0,
#   'actor_2': 'Eric Idle',
#   'actor_2_likes': 795.0,
#   'actor_3': 'Rupert Everett',
#   'actor_3_likes': 692.0},
#  {'imdb_id': 'tt0803096',
#   'title': 'Warcraft',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Fantasy',
#   'imdb_score': 7.3,
#   'movie_likes': 89000,
#   'director': 'Duncan Jones',
#   'director_likes': 0.0,
#   'actor_1': 'Dominic Cooper',
#   'actor_1_likes': 3000.0,
#   'actor_2': 'Callum Rennie',
#   'actor_2_likes': 716.0,
#   'actor_3': 'Ruth Negga',
#   'actor_3_likes': 648.0},
#  {'imdb_id': 'tt1340138',
#   'title': 'Terminator Genisys',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 6.6,
#   'movie_likes': 82000,
#   'director': 'Alan Taylor',
#   'director_likes': 230.0,
#   'actor_1': 'J.K. Simmons',
#   'actor_1_likes': 24000.0,
#   'actor_2': 'Emilia Clarke',
#   'actor_2_likes': 10000.0,
#   'actor_3': 'Matt Smith',
#   'actor_3_likes': 2000.0},
#  {'imdb_id': 'tt0980970',
#   'title': 'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#   'rating': 'PG',
#   'genres': 'Adventure, Family, Fantasy',
#   'imdb_score': 6.3,
#   'movie_likes': 11000,
#   'director': 'Michael Apted',
#   'director_likes': 150.0,
#   'actor_1': 'Bruce Spence',
#   'actor_1_likes': 531.0,
#   'actor_2': 'Shane Rangi',
#   'actor_2_likes': 82.0,
#   'actor_3': 'Laura Brent',
#   'actor_3_likes': 59.0},
#  {'imdb_id': 'tt0213149',
#   'title': 'Pearl Harbor',
#   'rating': 'PG-13',
#   'genres': 'Action, Drama, History, Romance, War',
#   'imdb_score': 6.1,
#   'movie_likes': 0,
#   'director': 'Michael Bay',
#   'director_likes': 0.0,
#   'actor_1': 'Jennifer Garner',
#   'actor_1_likes': 3000.0,
#   'actor_2': 'Jaime King',
#   'actor_2_likes': 961.0,
#   'actor_3': 'Mako',
#   'actor_3_likes': 691.0},
#  {'imdb_id': 'tt0418279',
#   'title': 'Transformers',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi',
#   'imdb_score': 7.1,
#   'movie_likes': 8000,
#   'director': 'Michael Bay',
#   'director_likes': 0.0,
#   'actor_1': 'Zack Ward',
#   'actor_1_likes': 662.0,
#   'actor_2': "Michael O'Neill",
#   'actor_2_likes': 599.0,
#   'actor_3': 'Kevin Dunn',
#   'actor_3_likes': 581.0},
#  {'imdb_id': 'tt0346491',
#   'title': 'Alexander',
#   'rating': 'R',
#   'genres': 'Action, Adventure, Biography, Drama, History, Romance, War',
#   'imdb_score': 5.5,
#   'movie_likes': 0,
#   'director': 'Oliver Stone',
#   'director_likes': 0.0,
#   'actor_1': 'Anthony Hopkins',
#   'actor_1_likes': 12000.0,
#   'actor_2': 'Angelina Jolie Pitt',
#   'actor_2_likes': 11000.0,
#   'actor_3': 'Brian Blessed',
#   'actor_3_likes': 591.0},
#  {'imdb_id': 'tt0373889',
#   'title': 'Harry Potter and the Order of the Phoenix',
#   'rating': 'PG-13',
#   'genres': 'Adventure, Family, Fantasy, Mystery',
#   'imdb_score': 7.5,
#   'movie_likes': 0,
#   'director': 'David Yates',
#   'director_likes': 282.0,
#   'actor_1': 'Robert Pattinson',
#   'actor_1_likes': 21000.0,
#   'actor_2': 'Daniel Radcliffe',
#   'actor_2_likes': 11000.0,
#   'actor_3': 'Fiona Shaw',
#   'actor_3_likes': 687.0},
#  {'imdb_id': 'tt0330373',
#   'title': 'Harry Potter and the Goblet of Fire',
#   'rating': 'PG-13',
#   'genres': 'Adventure, Family, Fantasy, Mystery',
#   'imdb_score': 7.6,
#   'movie_likes': 0,
#   'director': 'Mike Newell',
#   'director_likes': 179.0,
#   'actor_1': 'Robert Pattinson',
#   'actor_1_likes': 21000.0,
#   'actor_2': 'Daniel Radcliffe',
#   'actor_2_likes': 11000.0,
#   'actor_3': 'Rupert Grint',
#   'actor_3_likes': 10000.0},
#  {'imdb_id': 'tt0448157',
#   'title': 'Hancock',
#   'rating': 'PG-13',
#   'genres': 'Action, Drama',
#   'imdb_score': 6.4,
#   'movie_likes': 0,
#   'director': 'Peter Berg',
#   'director_likes': 532.0,
#   'actor_1': 'Will Smith',
#   'actor_1_likes': 10000.0,
#   'actor_2': 'Charlize Theron',
#   'actor_2_likes': 9000.0,
#   'actor_3': 'Eddie Marsan',
#   'actor_3_likes': 979.0},
#  {'imdb_id': 'tt0480249',
#   'title': 'I Am Legend',
#   'rating': 'PG-13',
#   'genres': 'Drama, Horror, Sci-Fi',
#   'imdb_score': 7.2,
#   'movie_likes': 11000,
#   'director': 'Francis Lawrence',
#   'director_likes': 508.0,
#   'actor_1': 'Will Smith',
#   'actor_1_likes': 10000.0,
#   'actor_2': 'Alice Braga',
#   'actor_2_likes': 1000.0,
#   'actor_3': 'Willow Smith',
#   'actor_3_likes': 558.0},
#  {'imdb_id': 'tt0367594',
#   'title': 'Charlie and the Chocolate Factory',
#   'rating': 'PG',
#   'genres': 'Adventure, Comedy, Family, Fantasy',
#   'imdb_score': 6.7,
#   'movie_likes': 0,
#   'director': 'Tim Burton',
#   'director_likes': 13000.0,
#   'actor_1': 'Johnny Depp',
#   'actor_1_likes': 40000.0,
#   'actor_2': 'Christopher Lee',
#   'actor_2_likes': 16000.0,
#   'actor_3': 'David Kelly',
#   'actor_3_likes': 588.0},
#  {'imdb_id': 'tt0382932',
#   'title': 'Ratatouille',
#   'rating': 'G',
#   'genres': 'Animation, Comedy, Family, Fantasy',
#   'imdb_score': 8.0,
#   'movie_likes': 10000,
#   'director': 'Brad Bird',
#   'director_likes': 663.0,
#   'actor_1': 'Janeane Garofalo',
#   'actor_1_likes': 1000.0,
#   'actor_2': 'John Ratzenberger',
#   'actor_2_likes': 1000.0,
#   'actor_3': 'Brian Dennehy',
# ...
#   'actor_1_likes': 838.0,
#   'actor_2': 'Erik Per Sullivan',
#   'actor_2_likes': 593.0,
#   'actor_3': 'Chad Lowe',
#   'actor_3_likes': 372.0},
#  {'imdb_id': 'tt1464540',
#   'title': 'I Am Number Four',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Sci-Fi, Thriller',
#   'imdb_score': 6.1,
#   'movie_likes': 27000,
#   'director': 'D.J. Caruso',
#   'director_likes': 154.0,
#   'actor_1': 'Alex Pettyfer',
#   'actor_1_likes': 15000.0,
#   'actor_2': 'Emily Wickersham',
#   'actor_2_likes': 348.0,
#   'actor_3': 'Reuben Langdon',
#   'actor_3_likes': 144.0},
#  {'imdb_id': 'tt0365737',
#   'title': 'Syriana',
#   'rating': 'R',
#   'genres': 'Drama, Thriller',
#   'imdb_score': 7.0,
#   'movie_likes': 0,
#   'director': 'Stephen Gaghan',
#   'director_likes': 79.0,
#   'actor_1': 'Matt Damon',
#   'actor_1_likes': 13000.0,
#   'actor_2': 'Amr Waked',
#   'actor_2_likes': 903.0,
#   'actor_3': 'Kayvan Novak',
#   'actor_3_likes': 414.0},
#  {'imdb_id': 'tt4172430',
#   'title': '13 Hours',
#   'rating': 'R',
#   'genres': 'Action, Drama, Thriller, War',
#   'imdb_score': 7.4,
#   'movie_likes': 44000,
#   'director': 'Michael Bay',
#   'director_likes': 0.0,
#   'actor_1': 'Toby Stephens',
#   'actor_1_likes': 769.0,
#   'actor_2': 'James Badge Dale',
#   'actor_2_likes': 726.0,
#   'actor_3': 'David Costabile',
#   'actor_3_likes': 681.0},
#  {'imdb_id': 'tt2262227',
#   'title': 'The Book of Life',
#   'rating': 'PG',
#   'genres': 'Adventure, Animation, Comedy, Family, Fantasy, Romance',
#   'imdb_score': 7.3,
#   'movie_likes': 18000,
#   'director': 'Jorge R. Gutiérrez',
#   'director_likes': 34.0,
#   'actor_1': 'Channing Tatum',
#   'actor_1_likes': 17000.0,
#   'actor_2': 'Hector Elizondo',
#   'actor_2_likes': 995.0,
#   'actor_3': 'Ana de la Reguera',
#   'actor_3_likes': 679.0},
#  {'imdb_id': 'tt0408345',
#   'title': 'Firewall',
#   'rating': 'PG-13',
#   'genres': 'Crime, Thriller',
#   'imdb_score': 5.8,
#   'movie_likes': 773,
#   'director': 'Richard Loncraine',
#   'director_likes': 12.0,
#   'actor_1': 'Jimmy Bennett',
#   'actor_1_likes': 87000.0,
#   'actor_2': 'Harrison Ford',
#   'actor_2_likes': 11000.0,
#   'actor_3': 'Mary Lynn Rajskub',
#   'actor_3_likes': 935.0},
#  {'imdb_id': 'tt0118548',
#   'title': 'Absolute Power',
#   'rating': 'R',
#   'genres': 'Action, Crime, Drama, Thriller',
#   'imdb_score': 6.7,
#   'movie_likes': 1000,
#   'director': 'Clint Eastwood',
#   'director_likes': 16000.0,
#   'actor_1': 'Clint Eastwood',
#   'actor_1_likes': 16000.0,
#   'actor_2': 'Mark Margolis',
#   'actor_2_likes': 1000.0,
#   'actor_3': 'Scott Glenn',
#   'actor_3_likes': 826.0},
#  {'imdb_id': 'tt0119173',
#   'title': 'G.I. Jane',
#   'rating': 'R',
#   'genres': 'Action, Drama, War',
#   'imdb_score': 5.8,
#   'movie_likes': 2000,
#   'director': 'Ridley Scott',
#   'director_likes': 0.0,
#   'actor_1': 'Viggo Mortensen',
#   'actor_1_likes': 10000.0,
#   'actor_2': 'Demi Moore',
#   'actor_2_likes': 2000.0,
#   'actor_3': 'John Michael Higgins',
#   'actor_3_likes': 957.0},
#  {'imdb_id': 'tt0119174',
#   'title': 'The Game',
#   'rating': 'R',
#   'genres': 'Drama, Mystery, Thriller',
#   'imdb_score': 7.8,
#   'movie_likes': 25000,
#   'director': 'David Fincher',
#   'director_likes': 21000.0,
#   'actor_1': 'Deborah Kara Unger',
#   'actor_1_likes': 495.0,
#   'actor_2': 'Armin Mueller-Stahl',
#   'actor_2_likes': 294.0,
#   'actor_3': 'Charles Martinet',
#   'actor_3_likes': 283.0},
#  {'imdb_id': 'tt0384537',
#   'title': 'Silent Hill',
#   'rating': 'R',
#   'genres': 'Adventure, Horror, Mystery',
#   'imdb_score': 6.6,
#   'movie_likes': 0,
#   'director': 'Christophe Gans',
#   'director_likes': 50.0,
#   'actor_1': 'Radha Mitchell',
#   'actor_1_likes': 992.0,
#   'actor_2': 'Deborah Kara Unger',
#   'actor_2_likes': 495.0,
#   'actor_3': 'Alice Krige',
#   'actor_3_likes': 368.0},
#  {'imdb_id': 'tt0191397',
#   'title': 'The Replacements',
#   'rating': 'PG-13',
#   'genres': 'Comedy, Sport',
#   'imdb_score': 6.5,
#   'movie_likes': 0,
#   'director': 'Howard Deutch',
#   'director_likes': 41.0,
#   'actor_1': 'Keanu Reeves',
#   'actor_1_likes': 18000.0,
#   'actor_2': 'Jon Favreau',
#   'actor_2_likes': 4000.0,
#   'actor_3': 'Faizon Love',
#   'actor_3_likes': 585.0},
#  {'imdb_id': 'tt1605630',
#   'title': 'American Reunion',
#   'rating': 'R',
#   'genres': 'Comedy',
#   'imdb_score': 6.7,
#   'movie_likes': 39000,
#   'director': 'Jon Hurwitz',
#   'director_likes': 22.0,
#   'actor_1': 'Alyson Hannigan',
#   'actor_1_likes': 3000.0,
#   'actor_2': 'Dania Ramirez',
#   'actor_2_likes': 1000.0,
#   'actor_3': 'Natasha Lyonne',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt0120768',
#   'title': 'The Negotiator',
#   'rating': 'R',
#   'genres': 'Action, Crime, Drama, Mystery, Thriller',
#   'imdb_score': 7.3,
#   'movie_likes': 3000,
#   'director': 'F. Gary Gray',
#   'director_likes': 473.0,
#   'actor_1': 'Kevin Spacey',
#   'actor_1_likes': 18000.0,
#   'actor_2': 'Michael Cudlitz',
#   'actor_2_likes': 822.0,
#   'actor_3': 'Siobhan Fallon Hogan',
#   'actor_3_likes': 294.0},
#  {'imdb_id': 'tt2106361',
#   'title': 'Into the Storm',
#   'rating': 'PG-13',
#   'genres': 'Action, Thriller',
#   'imdb_score': 5.8,
#   'movie_likes': 15000,
#   'director': 'Steven Quale',
#   'director_likes': 77.0,
#   'actor_1': 'Matt Walsh',
#   'actor_1_likes': 490.0,
#   'actor_2': 'Alycia Debnam-Carey',
#   'actor_2_likes': 298.0,
#   'actor_3': 'Scott Lawrence',
#   'actor_3_likes': 159.0},
#  {'imdb_id': 'tt0109254',
#   'title': 'Beverly Hills Cop III',
#   'rating': 'R',
#   'genres': 'Action, Comedy, Crime, Thriller',
#   'imdb_score': 5.5,
#   'movie_likes': 669,
#   'director': 'John Landis',
#   'director_likes': 644.0,
#   'actor_1': 'Louis Lombardi',
#   'actor_1_likes': 437.0,
#   'actor_2': 'Jon Tenney',
#   'actor_2_likes': 289.0,
#   'actor_3': 'Gilbert R. Hill',
#   'actor_3_likes': 174.0},
#  {'imdb_id': 'tt0099700',
#   'title': 'Gremlins 2: The New Batch',
#   'rating': 'PG-13',
#   'genres': 'Comedy, Fantasy, Horror',
#   'imdb_score': 6.3,
#   'movie_likes': 0,
#   'director': 'Joe Dante',
#   'director_likes': 287.0,
#   'actor_1': 'Christopher Lee',
#   'actor_1_likes': 16000.0,
#   'actor_2': 'Robert Picardo',
#   'actor_2_likes': 823.0,
#   'actor_3': 'Phoebe Cates',
#   'actor_3_likes': 767.0},
#  {'imdb_id': 'tt1872194',
#   'title': 'The Judge',
#   'rating': 'R',
#   'genres': 'Crime, Drama',
#   'imdb_score': 7.4,
#   'movie_likes': 47000,
#   'director': 'David Dobkin',
#   'director_likes': 71.0,
#   'actor_1': 'Robert Downey Jr.',
#   'actor_1_likes': 21000.0,
#   'actor_2': 'Robert Duvall',
#   'actor_2_likes': 3000.0,
#   'actor_3': 'Leighton Meester',
#   'actor_3_likes': 3000.0},
#  {'imdb_id': 'tt0119874',
#   'title': 'The Peacemaker',
#   'rating': 'R',
#   'genres': 'Action, Thriller',
#   'imdb_score': 5.9,
#   'movie_likes': 0,
#   'director': 'Mimi Leder',
#   'director_likes': 75.0,
#   'actor_1': 'Armin Mueller-Stahl',
#   'actor_1_likes': 294.0,
#   'actor_2': 'Holt McCallany',
#   'actor_2_likes': 273.0,
#   'actor_3': 'Marcel Iures',
#   'actor_3_likes': 258.0},
#  {'imdb_id': 'tt0318627',
#   'title': 'Resident Evil: Apocalypse',
#   'rating': 'R',
#   'genres': 'Action, Horror, Sci-Fi, Thriller',
#   'imdb_score': 6.2,
#   'movie_likes': 0,
#   'director': 'Alexander Witt',
#   'director_likes': 38.0,
#   'actor_1': 'Milla Jovovich',
#   'actor_1_likes': 14000.0,
#   'actor_2': 'Thomas Kretschmann',
#   'actor_2_likes': 919.0,
#   'actor_3': 'Mike Epps',
#   'actor_3_likes': 706.0},
#  {'imdb_id': 'tt0317198',
#   'title': 'Bridget Jones: The Edge of Reason',
#   'rating': 'R',
#   'genres': 'Comedy, Drama, Romance',
#   'imdb_score': 5.9,
#   'movie_likes': 0,
#   'director': 'Beeban Kidron',
#   'director_likes': 17.0,
#   'actor_1': 'Colin Firth',
#   'actor_1_likes': 14000.0,
#   'actor_2': 'Jim Broadbent',
#   'actor_2_likes': 1000.0,
#   'actor_3': 'Celia Imrie',
#   'actor_3_likes': 186.0},
#  {'imdb_id': 'tt0313443',
#   'title': 'Out of Time',
#   'rating': 'R',
#   'genres': 'Crime, Drama, Romance, Thriller',
#   'imdb_score': 6.5,
#   'movie_likes': 1000,
#   'director': 'Carl Franklin',
#   'director_likes': 73.0,
#   'actor_1': 'Denzel Washington',
#   'actor_1_likes': 18000.0,
#   'actor_2': 'Sanaa Lathan',
#   'actor_2_likes': 886.0,
#   'actor_3': 'John Billingsley',
#   'actor_3_likes': 323.0},
#  {'imdb_id': 'tt0110725',
#   'title': 'On Deadly Ground',
#   'rating': 'R',
#   'genres': 'Action, Adventure, Thriller',
#   'imdb_score': 4.4,
#   'movie_likes': 812,
#   'director': 'Steven Seagal',
#   'director_likes': 0.0,
#   'actor_1': 'Mike Starr',
#   'actor_1_likes': 854.0,
#   'actor_2': 'Joan Chen',
#   'actor_2_likes': 643.0,
#   'actor_3': 'Sven-Ole Thorsen',
#   'actor_3_likes': 158.0},
#  {'imdb_id': 'tt0424774',
#   'title': 'The Adventures of Sharkboy and Lavagirl 3-D',
#   'rating': 'PG',
#   'genres': 'Action, Adventure, Family, Fantasy',
#   'imdb_score': 3.5,
#   'movie_likes': 0,
#   'director': 'Robert Rodriguez',
#   'director_likes': 0.0,
#   'actor_1': 'Taylor Lautner',
#   'actor_1_likes': 12000.0,
#   'actor_2': 'Kristin Davis',
#   'actor_2_likes': 722.0,
#   'actor_3': 'Taylor Dooley',
#   'actor_3_likes': 717.0},
#  {'imdb_id': 'tt0163978',
#   'title': 'The Beach',
#   'rating': 'R',
#   'genres': 'Adventure, Drama, Thriller',
#   'imdb_score': 6.6,
#   'movie_likes': 0,
#   'director': 'Danny Boyle',
#   'director_likes': 0.0,
#   'actor_1': 'Leonardo DiCaprio',
#   'actor_1_likes': 29000.0,
#   'actor_2': 'Virginie Ledoyen',
#   'actor_2_likes': 414.0,
#   'actor_3': 'Peter Youngblood Hills',
#   'actor_3_likes': 39.0},
#  {'imdb_id': 'tt0350028',
#   'title': 'Raising Helen',
#   'rating': 'PG-13',
#   'genres': 'Comedy, Drama, Romance',
#   'imdb_score': 6.0,
#   'movie_likes': 718,
#   'director': 'Garry Marshall',
#   'director_likes': 0.0,
#   'actor_1': 'Amber Valletta',
#   'actor_1_likes': 627.0,
#   'actor_2': 'Felicity Huffman',
#   'actor_2_likes': 508.0,
#   'actor_3': 'Spencer Breslin',
#   'actor_3_likes': 434.0},
#  {'imdb_id': 'tt1186367',
#   'title': 'Ninja Assassin',
#   'rating': 'R',
#   'genres': 'Action, Crime, Thriller',
#   'imdb_score': 6.4,
#   'movie_likes': 0,
#   'director': 'James McTeigue',
#   'director_likes': 160.0,
#   'actor_1': 'Shô Kosugi',
#   'actor_1_likes': 330.0,
#   'actor_2': 'Ben Miles',
#   'actor_2_likes': 119.0,
#   'actor_3': 'Rain',
#   'actor_3_likes': 72.0},
#  {'imdb_id': 'tt0126916',
#   'title': 'For Love of the Game',
#   'rating': 'PG-13',
#   'genres': 'Drama, Romance, Sport',
#   'imdb_score': 6.5,
#   'movie_likes': 0,
#   'director': 'Sam Raimi',
#   'director_likes': 0.0,
#   'actor_1': 'J.K. Simmons',
#   'actor_1_likes': 24000.0,
#   'actor_2': 'Kelly Preston',
#   'actor_2_likes': 743.0,
#   'actor_3': 'Carmine Giovinazzo',
#   'actor_3_likes': 432.0},
#  {'imdb_id': 'tt0108967',
#   'title': 'A Touch of Frost',
#   'rating': nan,
#   'genres': 'Crime, Drama, Mystery',
#   'imdb_score': 7.8,
#   'movie_likes': 361,
#   'director': nan,
#   'director_likes': nan,
#   'actor_1': 'David Jason',
#   'actor_1_likes': 325.0,
#   'actor_2': 'Bruce Alexander',
#   'actor_2_likes': 7.0,
#   'actor_3': 'John Lyons',
#   'actor_3_likes': 5.0},
#  {'imdb_id': 'tt0117765',
#   'title': 'Striptease',
#   'rating': 'R',
#   'genres': 'Comedy, Crime, Drama, Thriller',
#   'imdb_score': 4.3,
#   'movie_likes': 877,
#   'director': 'Andrew Bergman',
#   'director_likes': 31.0,
#   'actor_1': 'Demi Moore',
#   'actor_1_likes': 2000.0,
#   'actor_2': 'Rumer Willis',
#   'actor_2_likes': 472.0,
#   'actor_3': 'Paul Guilfoyle',
#   'actor_3_likes': 210.0},
#  {'imdb_id': 'tt1392197',
#   'title': 'Marmaduke',
#   'rating': 'PG',
#   'genres': 'Comedy, Family',
#   'imdb_score': 4.2,
#   'movie_likes': 0,
#   'director': 'Tom Dey',
#   'director_likes': 9.0,
#   'actor_1': 'Emma Stone',
#   'actor_1_likes': 15000.0,
#   'actor_2': 'Judy Greer',
#   'actor_2_likes': 2000.0,
#   'actor_3': 'Steve Coogan',
#   'actor_3_likes': 1000.0},
#  {'imdb_id': 'tt1212419',
#   'title': 'Hereafter',
#   'rating': 'PG-13',
#   'genres': 'Drama, Fantasy',
#   'imdb_score': 6.5,
#   'movie_likes': 16000,
#   'director': 'Clint Eastwood',
#   'director_likes': 16000.0,
#   'actor_1': 'Matt Damon',
#   'actor_1_likes': 13000.0,
#   'actor_2': 'Jay Mohr',
#   'actor_2_likes': 563.0,
#   'actor_3': 'Cécile De France',
#   'actor_3_likes': 447.0},
#  {'imdb_id': 'tt0264935',
#   'title': 'Murder by Numbers',
#   'rating': 'R',
#   'genres': 'Crime, Mystery, Thriller',
#   'imdb_score': 6.1,
#   'movie_likes': 0,
#   'director': 'Barbet Schroeder',
#   'director_likes': 58.0,
#   'actor_1': 'Ryan Gosling',
#   'actor_1_likes': 33000.0,
#   'actor_2': 'Chris Penn',
#   'actor_2_likes': 455.0,
#   'actor_3': 'Agnes Bruckner',
#   'actor_3_likes': 401.0},
#  {'imdb_id': 'tt0112401',
#   'title': 'Assassins',
#   'rating': 'R',
#   'genres': 'Action, Crime, Thriller',
#   'imdb_score': 6.3,
#   'movie_likes': 0,
#   'director': 'Richard Donner',
#   'director_likes': 503.0,
#   'actor_1': 'Muse Watson',
#   'actor_1_likes': 45000.0,
#   'actor_2': 'Sylvester Stallone',
#   'actor_2_likes': 13000.0,
#   'actor_3': 'Kelly Rowan',
#   'actor_3_likes': 282.0},
#  {'imdb_id': 'tt0367959',
#   'title': 'Hannibal Rising',
#   'rating': 'R',
#   'genres': 'Crime, Drama, Thriller',
#   'imdb_score': 6.2,
#   'movie_likes': 3000,
#   'director': 'Peter Webber',
#   'director_likes': 73.0,
#   'actor_1': 'Li Gong',
#   'actor_1_likes': 879.0,
#   'actor_2': 'Stephen Walters',
#   'actor_2_likes': 184.0,
#   'actor_3': 'Richard Brake',
#   'actor_3_likes': 163.0},
#  {'imdb_id': 'tt0160916',
#   'title': 'The Story of Us',
#   'rating': 'R',
#   'genres': 'Comedy, Drama, Romance',
#   'imdb_score': 5.9,
#   'movie_likes': 0,
#   'director': 'Rob Reiner',
#   'director_likes': 0.0,
#   'actor_1': 'Bruce Willis',
#   'actor_1_likes': 13000.0,
#   'actor_2': 'Tim Matheson',
#   'actor_2_likes': 559.0,
#   'actor_3': 'Rita Wilson',
#   'actor_3_likes': 323.0},
#  {'imdb_id': 'tt1517260',
#   'title': 'The Host',
#   'rating': 'PG-13',
#   'genres': 'Action, Adventure, Romance, Sci-Fi, Thriller',
#   'imdb_score': 5.9,
#   'movie_likes': 43000,
#   'director': 'Andrew Niccol',
#   'director_likes': 487.0,
#   'actor_1': 'J.D. Evermore',
#   'actor_1_likes': 430.0,
#   'actor_2': 'Chandler Canterbury',
#   'actor_2_likes': 329.0,
#   'actor_3': 'Rachel Roberts',
#   'actor_3_likes': 201.0},
#  {'imdb_id': 'tt0264395',
#   'title': 'Basic',
#   'rating': 'R',
#   'genres': 'Action, Crime, Drama, Mystery, Thriller',
#   'imdb_score': 6.5,
#   'movie_likes': 0,
#   'director': 'John McTiernan',
#   'director_likes': 323.0,
#   'actor_1': 'Connie Nielsen',
#   'actor_1_likes': 933.0,
#   'actor_2': 'Harry Connick Jr.',
#   'actor_2_likes': 631.0,
#   'actor_3': 'Tim Daly',
#   'actor_3_likes': 511.0},
#  {'imdb_id': 'tt0309377',
#   'title': 'Blood Work',
#   'rating': 'R',
#   'genres': 'Action, Crime, Drama, Mystery, Thriller',
#   'imdb_score': 6.4,
#   'movie_likes': 705,
#   'director': 'Clint Eastwood',
#   'director_likes': 16000.0,
#   'actor_1': 'Clint Eastwood',
#   'actor_1_likes': 16000.0,
#   'actor_2': 'Anjelica Huston',
#   'actor_2_likes': 1000.0,
#   'actor_3': 'Rick Hoffman',
#   'actor_3_likes': 581.0},
#  {'imdb_id': 'tt0963178',
#   'title': 'The International',
#   'rating': 'R',
#   'genres': 'Action, Crime, Drama, Mystery, Thriller',
#   'imdb_score': 6.5,
#   'movie_likes': 0,
#   'director': 'Tom Tykwer',
#   'director_likes': 670.0,
#   'actor_1': 'Naomi Watts',
#   'actor_1_likes': 6000.0,
#   'actor_2': "Brían F. O'Byrne",
#   'actor_2_likes': 450.0,
#   'actor_3': 'Armin Mueller-Stahl',
#   'actor_3_likes': 294.0},
#  {'imdb_id': 'tt0116225',
#   'title': 'Escape from L.A.',
#   'rating': 'R',
#   'genres': 'Action, Adventure, Sci-Fi, Thriller',
#   'imdb_score': 5.7,
#   'movie_likes': 0,
#   'director': 'John Carpenter',
#   'director_likes': 0.0,
#   'actor_1': 'Steve Buscemi',
#   'actor_1_likes': 12000.0,
#   'actor_2': 'Valeria Golino',
#   'actor_2_likes': 898.0,
#   'actor_3': 'Michelle Forbes',
#   'actor_3_likes': 764.0},
#  {'imdb_id': 'tt2355844',
#   'title': 'Twisted',
#   'rating': nan,
#   'genres': 'Drama, Mystery, Thriller',
#   'imdb_score': 7.5,
#   'movie_likes': 915,
#   'director': nan,
#   'director_likes': nan,
#   'actor_1': 'Grey Damon',
#   'actor_1_likes': 629.0,
#   'actor_2': 'Brittany Curran',
#   'actor_2_likes': 512.0,
#   'actor_3': 'Aaron Hill',
#   'actor_3_likes': 398.0},
#  {'imdb_id': 'tt0129167',
#   'title': 'The Iron Giant',
#   'rating': 'PG',
#   'genres': 'Action, Adventure, Animation, Comedy, Drama, Family, Sci-Fi',
#   'imdb_score': 8.0,
#   'movie_likes': 0,
#   'director': 'Brad Bird',
#   'director_likes': 663.0,
#   'actor_1': 'Vin Diesel',
#   'actor_1_likes': 14000.0,
#   'actor_2': 'Harry Connick Jr.',
#   'actor_2_likes': 631.0,
#   'actor_3': 'M. Emmet Walsh',
#   'actor_3_likes': 521.0},
#  ...]

# %% [markdown]
# For testing purposes lets create dictionaries only from the first dictionary in the above list.

# %%
# Create dictionary for cast
i = 0
cast_d = {}
cast_d['cast'] = dict(list(dffb_d[i].items())[6:])
cast_d
# Out:
# {'cast': {'director': 'James Cameron',
#   'director_likes': 0.0,
#   'actor_1': 'CCH Pounder',
#   'actor_1_likes': 1000.0,
#   'actor_2': 'Joel David Moore',
#   'actor_2_likes': 936.0,
#   'actor_3': 'Wes Studi',
#   'actor_3_likes': 855.0}}

# %%
# Create facebook dictionary by adding movie likes
fb_d = dict(list(dffb_d[i].items())[5:6])
fb_d.update(cast_d)
fb_d
# Out:
# {'movie_likes': 33000,
#  'cast': {'director': 'James Cameron',
#   'director_likes': 0.0,
#   'actor_1': 'CCH Pounder',
#   'actor_1_likes': 1000.0,
#   'actor_2': 'Joel David Moore',
#   'actor_2_likes': 936.0,
#   'actor_3': 'Wes Studi',
#   'actor_3_likes': 855.0}}

# %% [markdown]
# **Let's now put this in a loop:**

# %%
# Create facebook directory and list of IMDB ids
facebook_d = []
id_l = []

for i in range(len(dffb_d)):
    cast_d = {}
    fb_d = {}
   
    # Create dictionary for cast
    cast_d['cast'] = dict(list(dffb_d[i].items())[6:])
    # Add movie likes to create facebook dictionary
    fb_d = dict(list(dffb_d[i].items())[5:6])
    fb_d.update(cast_d)
    
    facebook_d.append(fb_d)
    id_l.append(dffb_d[i]['imdb_id'])

# %%
facebook_d
# Out:
# [{'movie_likes': 33000,
#   'cast': {'director': 'James Cameron',
#    'director_likes': 0.0,
#    'actor_1': 'CCH Pounder',
#    'actor_1_likes': 1000.0,
#    'actor_2': 'Joel David Moore',
#    'actor_2_likes': 936.0,
#    'actor_3': 'Wes Studi',
#    'actor_3_likes': 855.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Gore Verbinski',
#    'director_likes': 563.0,
#    'actor_1': 'Johnny Depp',
#    'actor_1_likes': 40000.0,
#    'actor_2': 'Orlando Bloom',
#    'actor_2_likes': 5000.0,
#    'actor_3': 'Jack Davenport',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 85000,
#   'cast': {'director': 'Sam Mendes',
#    'director_likes': 0.0,
#    'actor_1': 'Christoph Waltz',
#    'actor_1_likes': 11000.0,
#    'actor_2': 'Rory Kinnear',
#    'actor_2_likes': 393.0,
#    'actor_3': 'Stephanie Sigman',
#    'actor_3_likes': 161.0}},
#  {'movie_likes': 164000,
#   'cast': {'director': 'Christopher Nolan',
#    'director_likes': 22000.0,
#    'actor_1': 'Tom Hardy',
#    'actor_1_likes': 27000.0,
#    'actor_2': 'Christian Bale',
#    'actor_2_likes': 23000.0,
#    'actor_3': 'Joseph Gordon-Levitt',
#    'actor_3_likes': 23000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Doug Walker',
#    'director_likes': 131.0,
#    'actor_1': 'Doug Walker',
#    'actor_1_likes': 131.0,
#    'actor_2': 'Rob Walker',
#    'actor_2_likes': 12.0,
#    'actor_3': nan,
#    'actor_3_likes': nan}},
#  {'movie_likes': 24000,
#   'cast': {'director': 'Andrew Stanton',
#    'director_likes': 475.0,
#    'actor_1': 'Daryl Sabara',
#    'actor_1_likes': 640.0,
#    'actor_2': 'Samantha Morton',
#    'actor_2_likes': 632.0,
#    'actor_3': 'Polly Walker',
#    'actor_3_likes': 530.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Sam Raimi',
#    'director_likes': 0.0,
#    'actor_1': 'J.K. Simmons',
#    'actor_1_likes': 24000.0,
#    'actor_2': 'James Franco',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Kirsten Dunst',
#    'actor_3_likes': 4000.0}},
#  {'movie_likes': 29000,
#   'cast': {'director': 'Nathan Greno',
#    'director_likes': 15.0,
#    'actor_1': 'Brad Garrett',
#    'actor_1_likes': 799.0,
#    'actor_2': 'Donna Murphy',
#    'actor_2_likes': 553.0,
#    'actor_3': 'M.C. Gainey',
#    'actor_3_likes': 284.0}},
#  {'movie_likes': 118000,
#   'cast': {'director': 'Joss Whedon',
#    'director_likes': 0.0,
#    'actor_1': 'Chris Hemsworth',
#    'actor_1_likes': 26000.0,
#    'actor_2': 'Robert Downey Jr.',
#    'actor_2_likes': 21000.0,
#    'actor_3': 'Scarlett Johansson',
#    'actor_3_likes': 19000.0}},
#  {'movie_likes': 10000,
#   'cast': {'director': 'David Yates',
#    'director_likes': 282.0,
#    'actor_1': 'Alan Rickman',
#    'actor_1_likes': 25000.0,
#    'actor_2': 'Daniel Radcliffe',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Rupert Grint',
#    'actor_3_likes': 10000.0}},
#  {'movie_likes': 197000,
#   'cast': {'director': 'Zack Snyder',
#    'director_likes': 0.0,
#    'actor_1': 'Henry Cavill',
#    'actor_1_likes': 15000.0,
#    'actor_2': 'Lauren Cohan',
#    'actor_2_likes': 4000.0,
#    'actor_3': 'Alan D. Purwin',
#    'actor_3_likes': 2000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Bryan Singer',
#    'director_likes': 0.0,
#    'actor_1': 'Kevin Spacey',
#    'actor_1_likes': 18000.0,
#    'actor_2': 'Marlon Brando',
#    'actor_2_likes': 10000.0,
#    'actor_3': 'Frank Langella',
#    'actor_3_likes': 903.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Marc Forster',
#    'director_likes': 395.0,
#    'actor_1': 'Giancarlo Giannini',
#    'actor_1_likes': 451.0,
#    'actor_2': 'Mathieu Amalric',
#    'actor_2_likes': 412.0,
#    'actor_3': 'Rory Kinnear',
#    'actor_3_likes': 393.0}},
#  {'movie_likes': 5000,
#   'cast': {'director': 'Gore Verbinski',
#    'director_likes': 563.0,
#    'actor_1': 'Johnny Depp',
#    'actor_1_likes': 40000.0,
#    'actor_2': 'Orlando Bloom',
#    'actor_2_likes': 5000.0,
#    'actor_3': 'Jack Davenport',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 48000,
#   'cast': {'director': 'Gore Verbinski',
#    'director_likes': 563.0,
#    'actor_1': 'Johnny Depp',
#    'actor_1_likes': 40000.0,
#    'actor_2': 'Ruth Wilson',
#    'actor_2_likes': 2000.0,
#    'actor_3': 'Tom Wilkinson',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 118000,
#   'cast': {'director': 'Zack Snyder',
#    'director_likes': 0.0,
#    'actor_1': 'Henry Cavill',
#    'actor_1_likes': 15000.0,
#    'actor_2': 'Christopher Meloni',
#    'actor_2_likes': 3000.0,
#    'actor_3': 'Harry Lennix',
#    'actor_3_likes': 748.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Andrew Adamson',
#    'director_likes': 80.0,
#    'actor_1': 'Peter Dinklage',
#    'actor_1_likes': 22000.0,
#    'actor_2': 'Pierfrancesco Favino',
#    'actor_2_likes': 216.0,
#    'actor_3': 'Damián Alcázar',
#    'actor_3_likes': 201.0}},
#  {'movie_likes': 123000,
#   'cast': {'director': 'Joss Whedon',
#    'director_likes': 0.0,
#    'actor_1': 'Chris Hemsworth',
#    'actor_1_likes': 26000.0,
#    'actor_2': 'Robert Downey Jr.',
#    'actor_2_likes': 21000.0,
#    'actor_3': 'Scarlett Johansson',
#    'actor_3_likes': 19000.0}},
#  {'movie_likes': 58000,
#   'cast': {'director': 'Rob Marshall',
#    'director_likes': 252.0,
#    'actor_1': 'Johnny Depp',
#    'actor_1_likes': 40000.0,
#    'actor_2': 'Sam Claflin',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Stephen Graham',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 40000,
#   'cast': {'director': 'Barry Sonnenfeld',
#    'director_likes': 188.0,
#    'actor_1': 'Will Smith',
#    'actor_1_likes': 10000.0,
#    'actor_2': 'Michael Stuhlbarg',
#    'actor_2_likes': 816.0,
#    'actor_3': 'Nicole Scherzinger',
#    'actor_3_likes': 718.0}},
#  {'movie_likes': 65000,
#   'cast': {'director': 'Peter Jackson',
#    'director_likes': 0.0,
#    'actor_1': 'Aidan Turner',
#    'actor_1_likes': 5000.0,
#    'actor_2': 'Adam Brown',
#    'actor_2_likes': 972.0,
#    'actor_3': 'James Nesbitt',
#    'actor_3_likes': 773.0}},
#  {'movie_likes': 56000,
#   'cast': {'director': 'Marc Webb',
#    'director_likes': 464.0,
#    'actor_1': 'Emma Stone',
#    'actor_1_likes': 15000.0,
#    'actor_2': 'Andrew Garfield',
#    'actor_2_likes': 10000.0,
#    'actor_3': 'Chris Zylka',
#    'actor_3_likes': 963.0}},
#  {'movie_likes': 17000,
#   'cast': {'director': 'Ridley Scott',
#    'director_likes': 0.0,
#    'actor_1': 'Mark Addy',
#    'actor_1_likes': 891.0,
#    'actor_2': 'William Hurt',
#    'actor_2_likes': 882.0,
#    'actor_3': 'Scott Grimes',
#    'actor_3_likes': 738.0}},
#  {'movie_likes': 83000,
#   'cast': {'director': 'Peter Jackson',
#    'director_likes': 0.0,
#    'actor_1': 'Aidan Turner',
#    'actor_1_likes': 5000.0,
#    'actor_2': 'Adam Brown',
#    'actor_2_likes': 972.0,
#    'actor_3': 'James Nesbitt',
#    'actor_3_likes': 773.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Chris Weitz',
#    'director_likes': 129.0,
#    'actor_1': 'Christopher Lee',
#    'actor_1_likes': 16000.0,
#    'actor_2': 'Eva Green',
#    'actor_2_likes': 6000.0,
#    'actor_3': 'Kristin Scott Thomas',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Peter Jackson',
#    'director_likes': 0.0,
#    'actor_1': 'Naomi Watts',
#    'actor_1_likes': 6000.0,
#    'actor_2': 'Thomas Kretschmann',
#    'actor_2_likes': 919.0,
#    'actor_3': 'Evan Parke',
#    'actor_3_likes': 84.0}},
#  {'movie_likes': 26000,
#   'cast': {'director': 'James Cameron',
#    'director_likes': 0.0,
#    'actor_1': 'Leonardo DiCaprio',
#    'actor_1_likes': 29000.0,
#    'actor_2': 'Kate Winslet',
#    'actor_2_likes': 14000.0,
#    'actor_3': 'Gloria Stuart',
#    'actor_3_likes': 794.0}},
#  {'movie_likes': 72000,
#   'cast': {'director': 'Anthony Russo',
#    'director_likes': 94.0,
#    'actor_1': 'Robert Downey Jr.',
#    'actor_1_likes': 21000.0,
#    'actor_2': 'Scarlett Johansson',
#    'actor_2_likes': 19000.0,
#    'actor_3': 'Chris Evans',
#    'actor_3_likes': 11000.0}},
#  {'movie_likes': 44000,
#   'cast': {'director': 'Peter Berg',
#    'director_likes': 532.0,
#    'actor_1': 'Liam Neeson',
#    'actor_1_likes': 14000.0,
#    'actor_2': 'Alexander Skarsgård',
#    'actor_2_likes': 10000.0,
#    'actor_3': 'Tadanobu Asano',
#    'actor_3_likes': 627.0}},
#  {'movie_likes': 150000,
#   'cast': {'director': 'Colin Trevorrow',
#    'director_likes': 365.0,
#    'actor_1': 'Bryce Dallas Howard',
#    'actor_1_likes': 3000.0,
#    'actor_2': 'Judy Greer',
#    'actor_2_likes': 2000.0,
#    'actor_3': 'Omar Sy',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 80000,
#   'cast': {'director': 'Sam Mendes',
#    'director_likes': 0.0,
#    'actor_1': 'Albert Finney',
#    'actor_1_likes': 883.0,
#    'actor_2': 'Helen McCrory',
#    'actor_2_likes': 563.0,
#    'actor_3': 'Rory Kinnear',
#    'actor_3_likes': 393.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Sam Raimi',
#    'director_likes': 0.0,
#    'actor_1': 'J.K. Simmons',
#    'actor_1_likes': 24000.0,
#    'actor_2': 'James Franco',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Kirsten Dunst',
#    'actor_3_likes': 4000.0}},
#  {'movie_likes': 95000,
#   'cast': {'director': 'Shane Black',
#    'director_likes': 1000.0,
#    'actor_1': 'Robert Downey Jr.',
#    'actor_1_likes': 21000.0,
#    'actor_2': 'Jon Favreau',
#    'actor_2_likes': 4000.0,
#    'actor_3': 'Don Cheadle',
#    'actor_3_likes': 3000.0}},
#  {'movie_likes': 24000,
#   'cast': {'director': 'Tim Burton',
#    'director_likes': 13000.0,
#    'actor_1': 'Johnny Depp',
#    'actor_1_likes': 40000.0,
#    'actor_2': 'Alan Rickman',
#    'actor_2_likes': 25000.0,
#    'actor_3': 'Anne Hathaway',
#    'actor_3_likes': 11000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Brett Ratner',
#    'director_likes': 420.0,
#    'actor_1': 'Hugh Jackman',
#    'actor_1_likes': 20000.0,
#    'actor_2': 'Kelsey Grammer',
#    'actor_2_likes': 808.0,
#    'actor_3': 'Daniel Cudmore',
#    'actor_3_likes': 560.0}},
#  {'movie_likes': 44000,
#   'cast': {'director': 'Dan Scanlon',
#    'director_likes': 37.0,
#    'actor_1': 'Steve Buscemi',
#    'actor_1_likes': 12000.0,
#    'actor_2': 'Tyler Labine',
#    'actor_2_likes': 779.0,
#    'actor_3': 'Sean Hayes',
#    'actor_3_likes': 760.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Michael Bay',
#    'director_likes': 0.0,
#    'actor_1': 'Glenn Morshower',
#    'actor_1_likes': 894.0,
#    'actor_2': 'Kevin Dunn',
#    'actor_2_likes': 581.0,
#    'actor_3': 'Ramon Rodriguez',
#    'actor_3_likes': 464.0}},
#  {'movie_likes': 56000,
#   'cast': {'director': 'Michael Bay',
#    'director_likes': 0.0,
#    'actor_1': 'Bingbing Li',
#    'actor_1_likes': 974.0,
#    'actor_2': 'Sophia Myles',
#    'actor_2_likes': 956.0,
#    'actor_3': 'Kelsey Grammer',
#    'actor_3_likes': 808.0}},
#  {'movie_likes': 60000,
#   'cast': {'director': 'Sam Raimi',
#    'director_likes': 0.0,
#    'actor_1': 'Tim Holmes',
#    'actor_1_likes': 44000.0,
#    'actor_2': 'Mila Kunis',
#    'actor_2_likes': 15000.0,
#    'actor_3': 'James Franco',
#    'actor_3_likes': 11000.0}},
#  {'movie_likes': 41000,
#   'cast': {'director': 'Marc Webb',
#    'director_likes': 464.0,
#    'actor_1': 'Emma Stone',
#    'actor_1_likes': 15000.0,
#    'actor_2': 'Andrew Garfield',
#    'actor_2_likes': 10000.0,
#    'actor_3': 'B.J. Novak',
#    'actor_3_likes': 825.0}},
#  {'movie_likes': 30000,
#   'cast': {'director': 'Joseph Kosinski',
#    'director_likes': 364.0,
#    'actor_1': 'Jeff Bridges',
#    'actor_1_likes': 12000.0,
#    'actor_2': 'Olivia Wilde',
#    'actor_2_likes': 10000.0,
#    'actor_3': 'James Frain',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 10000,
#   'cast': {'director': 'John Lasseter',
#    'director_likes': 487.0,
#    'actor_1': 'Joe Mantegna',
#    'actor_1_likes': 1000.0,
#    'actor_2': 'Thomas Kretschmann',
#    'actor_2_likes': 919.0,
#    'actor_3': 'Eddie Izzard',
#    'actor_3_likes': 776.0}},
#  {'movie_likes': 24000,
#   'cast': {'director': 'Martin Campbell',
#    'director_likes': 258.0,
#    'actor_1': 'Ryan Reynolds',
#    'actor_1_likes': 16000.0,
#    'actor_2': 'Temuera Morrison',
#    'actor_2_likes': 368.0,
#    'actor_3': 'Taika Waititi',
#    'actor_3_likes': 326.0}},
#  {'movie_likes': 30000,
#   'cast': {'director': 'Lee Unkrich',
#    'director_likes': 125.0,
#    'actor_1': 'Tom Hanks',
#    'actor_1_likes': 15000.0,
#    'actor_2': 'John Ratzenberger',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'Don Rickles',
#    'actor_3_likes': 721.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'McG',
#    'director_likes': 368.0,
#    'actor_1': 'Christian Bale',
#    'actor_1_likes': 23000.0,
#    'actor_2': 'Bryce Dallas Howard',
#    'actor_2_likes': 3000.0,
#    'actor_3': 'Common',
#    'actor_3_likes': 988.0}},
#  {'movie_likes': 94000,
#   'cast': {'director': 'James Wan',
#    'director_likes': 0.0,
#    'actor_1': 'Jason Statham',
#    'actor_1_likes': 26000.0,
#    'actor_2': 'Paul Walker',
#    'actor_2_likes': 23000.0,
#    'actor_3': 'Vin Diesel',
#    'actor_3_likes': 14000.0}},
#  {'movie_likes': 129000,
#   'cast': {'director': 'Marc Forster',
#    'director_likes': 395.0,
#    'actor_1': 'Peter Capaldi',
#    'actor_1_likes': 17000.0,
#    'actor_2': 'Brad Pitt',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Mireille Enos',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 82000,
#   'cast': {'director': 'Bryan Singer',
#    'director_likes': 0.0,
#    'actor_1': 'Jennifer Lawrence',
#    'actor_1_likes': 34000.0,
#    'actor_2': 'Peter Dinklage',
#    'actor_2_likes': 22000.0,
#    'actor_3': 'Hugh Jackman',
#    'actor_3_likes': 20000.0}},
#  {'movie_likes': 92000,
#   'cast': {'director': 'J.J. Abrams',
#    'director_likes': 14000.0,
#    'actor_1': 'Benedict Cumberbatch',
#    'actor_1_likes': 19000.0,
#    'actor_2': 'Bruce Greenwood',
#    'actor_2_likes': 981.0,
#    'actor_3': 'Noel Clarke',
#    'actor_3_likes': 928.0}},
#  {'movie_likes': 22000,
#   'cast': {'director': 'Bryan Singer',
#    'director_likes': 0.0,
#    'actor_1': 'Eddie Marsan',
#    'actor_1_likes': 979.0,
#    'actor_2': 'Ewen Bremner',
#    'actor_2_likes': 557.0,
#    'actor_3': 'Ralph Brown',
#    'actor_3_likes': 140.0}},
#  {'movie_likes': 115000,
#   'cast': {'director': 'Baz Luhrmann',
#    'director_likes': 1000.0,
#    'actor_1': 'Leonardo DiCaprio',
#    'actor_1_likes': 29000.0,
#    'actor_2': 'Elizabeth Debicki',
#    'actor_2_likes': 509.0,
#    'actor_3': 'Steve Bisley',
#    'actor_3_likes': 77.0}},
#  {'movie_likes': 23000,
#   'cast': {'director': 'Mike Newell',
#    'director_likes': 179.0,
#    'actor_1': 'Jake Gyllenhaal',
#    'actor_1_likes': 15000.0,
#    'actor_2': 'Richard Coyle',
#    'actor_2_likes': 567.0,
#    'actor_3': 'Reece Ritchie',
#    'actor_3_likes': 236.0}},
#  {'movie_likes': 83000,
#   'cast': {'director': 'Guillermo del Toro',
#    'director_likes': 0.0,
#    'actor_1': 'Charlie Hunnam',
#    'actor_1_likes': 16000.0,
#    'actor_2': 'Clifton Collins Jr.',
#    'actor_2_likes': 968.0,
#    'actor_3': 'Larry Joe Campbell',
#    'actor_3_likes': 919.0}},
#  {'movie_likes': 46000,
#   'cast': {'director': 'Michael Bay',
#    'director_likes': 0.0,
#    'actor_1': 'Glenn Morshower',
#    'actor_1_likes': 894.0,
#    'actor_2': 'Lester Speight',
#    'actor_2_likes': 829.0,
#    'actor_3': 'Kevin Dunn',
#    'actor_3_likes': 581.0}},
#  {'movie_likes': 5000,
#   'cast': {'director': 'Steven Spielberg',
#    'director_likes': 14000.0,
#    'actor_1': 'Harrison Ford',
#    'actor_1_likes': 11000.0,
#    'actor_2': 'Ray Winstone',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'Jim Broadbent',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 20000,
#   'cast': {'director': 'Peter Sohn',
#    'director_likes': 113.0,
#    'actor_1': 'A.J. Buckley',
#    'actor_1_likes': 275.0,
#    'actor_2': 'Jack McGraw',
#    'actor_2_likes': 150.0,
#    'actor_3': 'Peter Sohn',
#    'actor_3_likes': 113.0}},
#  {'movie_likes': 39000,
#   'cast': {'director': 'Mark Andrews',
#    'director_likes': 56.0,
#    'actor_1': 'Kelly Macdonald',
#    'actor_1_likes': 2000.0,
#    'actor_2': 'John Ratzenberger',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'Julie Walters',
#    'actor_3_likes': 838.0}},
#  {'movie_likes': 30000,
#   'cast': {'director': 'Justin Lin',
#    'director_likes': 681.0,
#    'actor_1': 'Sofia Boutella',
#    'actor_1_likes': 998.0,
#    'actor_2': 'Melissa Roxburgh',
#    'actor_2_likes': 119.0,
#    'actor_3': 'Lydia Wilson',
#    'actor_3_likes': 105.0}},
#  {'movie_likes': 16000,
#   'cast': {'director': 'Andrew Stanton',
#    'director_likes': 475.0,
#    'actor_1': 'John Ratzenberger',
#    'actor_1_likes': 1000.0,
#    'actor_2': 'Fred Willard',
#    'actor_2_likes': 729.0,
#    'actor_3': 'Jeff Garlin',
#    'actor_3_likes': 522.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Brett Ratner',
#    'director_likes': 420.0,
#    'actor_1': 'Tzi Ma',
#    'actor_1_likes': 268.0,
#    'actor_2': 'Dana Ivey',
#    'actor_2_likes': 268.0,
#    'actor_3': 'Noémie Lenoir',
#    'actor_3_likes': 173.0}},
#  {'movie_likes': 13000,
#   'cast': {'director': 'Roland Emmerich',
#    'director_likes': 776.0,
#    'actor_1': 'Oliver Platt',
#    'actor_1_likes': 1000.0,
#    'actor_2': 'Liam James',
#    'actor_2_likes': 468.0,
#    'actor_3': 'Tom McCarthy',
#    'actor_3_likes': 310.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Robert Zemeckis',
#    'director_likes': 0.0,
#    'actor_1': 'Robin Wright',
#    'actor_1_likes': 18000.0,
#    'actor_2': 'Colin Firth',
#    'actor_2_likes': 14000.0,
#    'actor_3': 'Gary Oldman',
#    'actor_3_likes': 10000.0}},
#  {'movie_likes': 44000,
#   'cast': {'director': 'Lana Wachowski',
#    'director_likes': 0.0,
#    'actor_1': 'Channing Tatum',
#    'actor_1_likes': 17000.0,
#    'actor_2': 'Mila Kunis',
#    'actor_2_likes': 15000.0,
#    'actor_3': 'Eddie Redmayne',
#    'actor_3_likes': 13000.0}},
#  {'movie_likes': 29000,
#   'cast': {'director': 'David Yates',
#    'director_likes': 282.0,
#    'actor_1': 'Christoph Waltz',
#    'actor_1_likes': 11000.0,
#    'actor_2': 'Alexander Skarsgård',
#    'actor_2_likes': 10000.0,
#    'actor_3': 'Casper Crump',
#    'actor_3_likes': 103.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Andrew Adamson',
#    'director_likes': 80.0,
#    'actor_1': 'Jim Broadbent',
#    'actor_1_likes': 1000.0,
#    'actor_2': 'Kiran Shah',
#    'actor_2_likes': 190.0,
#    'actor_3': 'Shane Rangi',
#    'actor_3_likes': 82.0}},
#  {'movie_likes': 54000,
#   'cast': {'director': 'Bryan Singer',
#    'director_likes': 0.0,
#    'actor_1': 'Jennifer Lawrence',
#    'actor_1_likes': 34000.0,
#    'actor_2': 'Michael Fassbender',
#    'actor_2_likes': 13000.0,
#    'actor_3': 'Tye Sheridan',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 37000,
#   'cast': {'director': 'Christopher Nolan',
#    'director_likes': 22000.0,
#    'actor_1': 'Christian Bale',
#    'actor_1_likes': 23000.0,
#    'actor_2': 'Heath Ledger',
#    'actor_2_likes': 13000.0,
#    'actor_3': 'Morgan Freeman',
#    'actor_3_likes': 11000.0}},
#  {'movie_likes': 27000,
#   'cast': {'director': 'Pete Docter',
#    'director_likes': 0.0,
#    'actor_1': 'John Ratzenberger',
#    'actor_1_likes': 1000.0,
#    'actor_2': 'Delroy Lindo',
#    'actor_2_likes': 848.0,
#    'actor_3': 'Jess Harnell',
#    'actor_3_likes': 262.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Rob Letterman',
#    'director_likes': 11.0,
#    'actor_1': 'Amy Poehler',
#    'actor_1_likes': 1000.0,
#    'actor_2': 'Rainn Wilson',
#    'actor_2_likes': 973.0,
#    'actor_3': 'Stephen Colbert',
#    'actor_3_likes': 459.0}},
#  {'movie_likes': 10000,
#   'cast': {'director': 'Jon Favreau',
#    'director_likes': 4000.0,
#    'actor_1': 'Robert Downey Jr.',
#    'actor_1_likes': 21000.0,
#    'actor_2': 'Jeff Bridges',
#    'actor_2_likes': 12000.0,
#    'actor_3': 'Jon Favreau',
#    'actor_3_likes': 4000.0}},
#  {'movie_likes': 42000,
#   'cast': {'director': 'Martin Scorsese',
#    'director_likes': 17000.0,
#    'actor_1': 'Chloë Grace Moretz',
#    'actor_1_likes': 17000.0,
#    'actor_2': 'Christopher Lee',
#    'actor_2_likes': 16000.0,
#    'actor_3': 'Ray Winstone',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Barry Sonnenfeld',
#    'director_likes': 188.0,
#    'actor_1': 'Will Smith',
#    'actor_1_likes': 10000.0,
#    'actor_2': 'Salma Hayek',
#    'actor_2_likes': 4000.0,
#    'actor_3': 'Bai Ling',
#    'actor_3_likes': 582.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Rob Cohen',
#    'director_likes': 357.0,
#    'actor_1': 'Jet Li',
#    'actor_1_likes': 5000.0,
#    'actor_2': 'Brendan Fraser',
#    'actor_2_likes': 3000.0,
#    'actor_3': 'Russell Wong',
#    'actor_3_likes': 595.0}},
#  {'movie_likes': 80000,
#   'cast': {'director': 'David Ayer',
#    'director_likes': 452.0,
#    'actor_1': 'Will Smith',
#    'actor_1_likes': 10000.0,
#    'actor_2': 'Robin Atkin Downes',
#    'actor_2_likes': 336.0,
#    'actor_3': 'Ike Barinholtz',
#    'actor_3_likes': 329.0}},
#  {'movie_likes': 2000,
#   'cast': {'director': 'Tom Shadyac',
#    'director_likes': 293.0,
#    'actor_1': 'Jimmy Bennett',
#    'actor_1_likes': 87000.0,
#    'actor_2': 'Morgan Freeman',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Steve Carell',
#    'actor_3_likes': 7000.0}},
#  {'movie_likes': 77000,
#   'cast': {'director': 'Doug Liman',
#    'director_likes': 218.0,
#    'actor_1': 'Tom Cruise',
#    'actor_1_likes': 10000.0,
#    'actor_2': 'Lara Pulver',
#    'actor_2_likes': 854.0,
#    'actor_3': 'Noah Taylor',
#    'actor_3_likes': 509.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Kevin Reynolds',
#    'director_likes': 58.0,
#    'actor_1': 'Jeanne Tripplehorn',
#    'actor_1_likes': 711.0,
#    'actor_2': 'Rick Aviles',
#    'actor_2_likes': 60.0,
#    'actor_3': 'Zakes Mokae',
#    'actor_3_likes': 60.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Stephen Sommers',
#    'director_likes': 208.0,
#    'actor_1': 'Joseph Gordon-Levitt',
#    'actor_1_likes': 23000.0,
#    'actor_2': 'Dennis Quaid',
#    'actor_2_likes': 2000.0,
#    'actor_3': 'Leo Howard',
#    'actor_3_likes': 570.0}},
#  {'movie_likes': 118000,
#   'cast': {'director': 'Pete Docter',
#    'director_likes': 0.0,
#    'actor_1': 'Amy Poehler',
#    'actor_1_likes': 1000.0,
#    'actor_2': 'Mindy Kaling',
#    'actor_2_likes': 767.0,
#    'actor_3': 'Phyllis Smith',
#    'actor_3_likes': 384.0}},
#  {'movie_likes': 65000,
#   'cast': {'director': 'Jon Favreau',
#    'director_likes': 4000.0,
#    'actor_1': 'Scarlett Johansson',
#    'actor_1_likes': 19000.0,
#    'actor_2': 'Bill Murray',
#    'actor_2_likes': 13000.0,
#    'actor_3': 'Garry Shandling',
#    'actor_3_likes': 591.0}},
#  {'movie_likes': 18000,
#   'cast': {'director': 'Jon Favreau',
#    'director_likes': 4000.0,
#    'actor_1': 'Robert Downey Jr.',
#    'actor_1_likes': 21000.0,
#    'actor_2': 'Scarlett Johansson',
#    'actor_2_likes': 19000.0,
#    'actor_3': 'Jon Favreau',
#    'actor_3_likes': 4000.0}},
#  {'movie_likes': 53000,
#   'cast': {'director': 'Rupert Sanders',
#    'director_likes': 274.0,
#    'actor_1': 'Chris Hemsworth',
#    'actor_1_likes': 26000.0,
#    'actor_2': 'Kristen Stewart',
#    'actor_2_likes': 17000.0,
#    'actor_3': 'Sam Claflin',
#    'actor_3_likes': 11000.0}},
#  {'movie_likes': 89000,
#   'cast': {'director': 'Robert Stromberg',
#    'director_likes': 171.0,
#    'actor_1': 'Angelina Jolie Pitt',
#    'actor_1_likes': 11000.0,
#    'actor_2': 'Sharlto Copley',
#    'actor_2_likes': 2000.0,
#    'actor_3': 'Sam Riley',
#    'actor_3_likes': 846.0}},
#  {'movie_likes': 45000,
#   'cast': {'director': 'Matt Reeves',
#    'director_likes': 198.0,
#    'actor_1': 'Gary Oldman',
#    'actor_1_likes': 10000.0,
#    'actor_2': 'Judy Greer',
#    'actor_2_likes': 2000.0,
#    'actor_3': 'Kodi Smit-McPhee',
#    'actor_3_likes': 884.0}},
#  {'movie_likes': 677,
#   'cast': {'director': 'Roland Joffé',
#    'director_likes': 596.0,
#    'actor_1': 'Tamsin Egerton',
#    'actor_1_likes': 622.0,
#    'actor_2': 'Alice Englert',
#    'actor_2_likes': 525.0,
#    'actor_3': 'Bipasha Basu',
#    'actor_3_likes': 283.0}},
#  {'movie_likes': 35000,
#   'cast': {'director': 'Carl Rinsch',
#    'director_likes': 47.0,
#    'actor_1': 'Keanu Reeves',
#    'actor_1_likes': 18000.0,
#    'actor_2': 'Cary-Hiroyuki Tagawa',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'Jin Akanishi',
#    'actor_3_likes': 982.0}},
#  {'movie_likes': 55000,
#   'cast': {'director': 'Anthony Russo',
#    'director_likes': 94.0,
#    'actor_1': 'Scarlett Johansson',
#    'actor_1_likes': 19000.0,
#    'actor_2': 'Chris Evans',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Hayley Atwell',
#    'actor_3_likes': 2000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Mike Mitchell',
#    'director_likes': 31.0,
#    'actor_1': 'Jon Hamm',
#    'actor_1_likes': 4000.0,
#    'actor_2': 'Kathy Griffin',
#    'actor_2_likes': 225.0,
#    'actor_3': 'Mary Kay Place',
#    'actor_3_likes': 213.0}},
#  {'movie_likes': 37000,
#   'cast': {'director': 'Brad Bird',
#    'director_likes': 663.0,
#    'actor_1': 'Judy Greer',
#    'actor_1_likes': 2000.0,
#    'actor_2': 'Chris Bauer',
#    'actor_2_likes': 638.0,
#    'actor_3': 'Thomas Robinson',
#    'actor_3_likes': 604.0}},
#  {'movie_likes': 41000,
#   'cast': {'director': 'Don Hall',
#    'director_likes': 38.0,
#    'actor_1': 'Damon Wayans Jr.',
#    'actor_1_likes': 756.0,
#    'actor_2': 'Daniel Henney',
#    'actor_2_likes': 719.0,
#    'actor_3': 'Abraham Benrubi',
#    'actor_3_likes': 562.0}},
#  {'movie_likes': 40000,
#   'cast': {'director': 'Rich Moore',
#    'director_likes': 66.0,
#    'actor_1': 'Jack McBrayer',
#    'actor_1_likes': 975.0,
#    'actor_2': 'Sarah Silverman',
#    'actor_2_likes': 931.0,
#    'actor_3': 'Joe Lo Truglio',
#    'actor_3_likes': 833.0}},
#  {'movie_likes': 10000,
#   'cast': {'director': 'Robert Zemeckis',
#    'director_likes': 0.0,
#    'actor_1': 'Tom Hanks',
#    'actor_1_likes': 15000.0,
#    'actor_2': 'Eddie Deezen',
#    'actor_2_likes': 726.0,
#    'actor_3': 'Peter Scolari',
#    'actor_3_likes': 267.0}},
#  {'movie_likes': 67000,
#   'cast': {'director': 'Roland Emmerich',
#    'director_likes': 776.0,
#    'actor_1': 'Vivica A. Fox',
#    'actor_1_likes': 890.0,
#    'actor_2': 'Sela Ward',
#    'actor_2_likes': 812.0,
#    'actor_3': 'Judd Hirsch',
#    'actor_3_likes': 535.0}},
#  {'movie_likes': 33000,
#   'cast': {'director': 'Dean DeBlois',
#    'director_likes': 255.0,
#    'actor_1': 'Gerard Butler',
#    'actor_1_likes': 18000.0,
#    'actor_2': 'America Ferrera',
#    'actor_2_likes': 953.0,
#    'actor_3': 'Craig Ferguson',
#    'actor_3_likes': 759.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Jonathan Mostow',
#    'director_likes': 84.0,
#    'actor_1': 'Nick Stahl',
#    'actor_1_likes': 648.0,
#    'actor_2': 'M.C. Gainey',
#    'actor_2_likes': 284.0,
#    'actor_3': 'Carolyn Hennesy',
#    'actor_3_likes': 191.0}},
#  {'movie_likes': 96000,
#   'cast': {'director': 'James Gunn',
#    'director_likes': 571.0,
#    'actor_1': 'Bradley Cooper',
#    'actor_1_likes': 14000.0,
#    'actor_2': 'Vin Diesel',
#    'actor_2_likes': 14000.0,
#    'actor_3': 'Djimon Hounsou',
#    'actor_3_likes': 3000.0}},
#  {'movie_likes': 349000,
#   'cast': {'director': 'Christopher Nolan',
#    'director_likes': 22000.0,
#    'actor_1': 'Matthew McConaughey',
#    'actor_1_likes': 11000.0,
#    'actor_2': 'Anne Hathaway',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Mackenzie Foy',
#    'actor_3_likes': 6000.0}},
#  {'movie_likes': 175000,
#   'cast': {'director': 'Christopher Nolan',
#    'director_likes': 22000.0,
#    'actor_1': 'Leonardo DiCaprio',
#    'actor_1_likes': 29000.0,
#    'actor_2': 'Tom Hardy',
#    'actor_2_likes': 27000.0,
#    'actor_3': 'Joseph Gordon-Levitt',
#    'actor_3_likes': 23000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Hideaki Anno',
#    'director_likes': 28.0,
#    'actor_1': 'Mark Chinnery',
#    'actor_1_likes': 544.0,
#    'actor_2': "Shin'ya Tsukamoto",
#    'actor_2_likes': 106.0,
#    'actor_3': 'Atsuko Maeda',
#    'actor_3_likes': 12.0}},
#  {'movie_likes': 166000,
#   'cast': {'director': 'Peter Jackson',
#    'director_likes': 0.0,
#    'actor_1': 'Aidan Turner',
#    'actor_1_likes': 5000.0,
#    'actor_2': 'Adam Brown',
#    'actor_2_likes': 972.0,
#    'actor_3': 'James Nesbitt',
#    'actor_3_likes': 773.0}},
#  {'movie_likes': 14000,
#   'cast': {'director': 'Rob Cohen',
#    'director_likes': 357.0,
#    'actor_1': 'Paul Walker',
#    'actor_1_likes': 23000.0,
#    'actor_2': 'Vin Diesel',
#    'actor_2_likes': 14000.0,
#    'actor_3': 'Jordana Brewster',
#    'actor_3_likes': 4000.0}},
#  {'movie_likes': 23000,
#   'cast': {'director': 'David Fincher',
#    'director_likes': 21000.0,
#    'actor_1': 'Brad Pitt',
#    'actor_1_likes': 11000.0,
#    'actor_2': 'Jason Flemyng',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'Julia Ormond',
#    'actor_3_likes': 919.0}},
#  {'movie_likes': 54000,
#   'cast': {'director': 'Matthew Vaughn',
#    'director_likes': 905.0,
#    'actor_1': 'Jennifer Lawrence',
#    'actor_1_likes': 34000.0,
#    'actor_2': 'Michael Fassbender',
#    'actor_2_likes': 13000.0,
#    'actor_3': 'Oliver Platt',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 38000,
#   'cast': {'director': 'Francis Lawrence',
#    'director_likes': 508.0,
#    'actor_1': 'Jennifer Lawrence',
#    'actor_1_likes': 34000.0,
#    'actor_2': 'Philip Seymour Hoffman',
#    'actor_2_likes': 22000.0,
#    'actor_3': 'Josh Hutcherson',
#    'actor_3_likes': 14000.0}},
#  {'movie_likes': 11000,
#   'cast': {'director': 'Jon Turteltaub',
#    'director_likes': 226.0,
#    'actor_1': 'Nicolas Cage',
#    'actor_1_likes': 12000.0,
#    'actor_2': 'Omar Benson Miller',
#    'actor_2_likes': 418.0,
#    'actor_3': 'Robert Capron',
#    'actor_3_likes': 370.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Wolfgang Petersen',
#    'director_likes': 249.0,
#    'actor_1': 'Jimmy Bennett',
#    'actor_1_likes': 87000.0,
#    'actor_2': 'Mike Vogel',
#    'actor_2_likes': 2000.0,
#    'actor_3': 'Andre Braugher',
#    'actor_3_likes': 702.0}},
#  {'movie_likes': 30000,
#   'cast': {'director': 'James Bobin',
#    'director_likes': 33.0,
#    'actor_1': 'Johnny Depp',
#    'actor_1_likes': 40000.0,
#    'actor_2': 'Alan Rickman',
#    'actor_2_likes': 25000.0,
#    'actor_3': 'Anne Hathaway',
#    'actor_3_likes': 11000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Chris Miller',
#    'director_likes': 50.0,
#    'actor_1': 'Justin Timberlake',
#    'actor_1_likes': 3000.0,
#    'actor_2': 'Eric Idle',
#    'actor_2_likes': 795.0,
#    'actor_3': 'Rupert Everett',
#    'actor_3_likes': 692.0}},
#  {'movie_likes': 89000,
#   'cast': {'director': 'Duncan Jones',
#    'director_likes': 0.0,
#    'actor_1': 'Dominic Cooper',
#    'actor_1_likes': 3000.0,
#    'actor_2': 'Callum Rennie',
#    'actor_2_likes': 716.0,
#    'actor_3': 'Ruth Negga',
#    'actor_3_likes': 648.0}},
#  {'movie_likes': 82000,
#   'cast': {'director': 'Alan Taylor',
#    'director_likes': 230.0,
#    'actor_1': 'J.K. Simmons',
#    'actor_1_likes': 24000.0,
#    'actor_2': 'Emilia Clarke',
#    'actor_2_likes': 10000.0,
#    'actor_3': 'Matt Smith',
#    'actor_3_likes': 2000.0}},
#  {'movie_likes': 11000,
#   'cast': {'director': 'Michael Apted',
#    'director_likes': 150.0,
#    'actor_1': 'Bruce Spence',
#    'actor_1_likes': 531.0,
#    'actor_2': 'Shane Rangi',
#    'actor_2_likes': 82.0,
#    'actor_3': 'Laura Brent',
#    'actor_3_likes': 59.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Michael Bay',
#    'director_likes': 0.0,
#    'actor_1': 'Jennifer Garner',
#    'actor_1_likes': 3000.0,
#    'actor_2': 'Jaime King',
#    'actor_2_likes': 961.0,
#    'actor_3': 'Mako',
#    'actor_3_likes': 691.0}},
#  {'movie_likes': 8000,
#   'cast': {'director': 'Michael Bay',
#    'director_likes': 0.0,
#    'actor_1': 'Zack Ward',
#    'actor_1_likes': 662.0,
#    'actor_2': "Michael O'Neill",
#    'actor_2_likes': 599.0,
#    'actor_3': 'Kevin Dunn',
#    'actor_3_likes': 581.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Oliver Stone',
#    'director_likes': 0.0,
#    'actor_1': 'Anthony Hopkins',
#    'actor_1_likes': 12000.0,
#    'actor_2': 'Angelina Jolie Pitt',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Brian Blessed',
#    'actor_3_likes': 591.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'David Yates',
#    'director_likes': 282.0,
#    'actor_1': 'Robert Pattinson',
#    'actor_1_likes': 21000.0,
#    'actor_2': 'Daniel Radcliffe',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Fiona Shaw',
#    'actor_3_likes': 687.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Mike Newell',
#    'director_likes': 179.0,
#    'actor_1': 'Robert Pattinson',
#    'actor_1_likes': 21000.0,
#    'actor_2': 'Daniel Radcliffe',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Rupert Grint',
#    'actor_3_likes': 10000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Peter Berg',
#    'director_likes': 532.0,
#    'actor_1': 'Will Smith',
#    'actor_1_likes': 10000.0,
#    'actor_2': 'Charlize Theron',
#    'actor_2_likes': 9000.0,
#    'actor_3': 'Eddie Marsan',
#    'actor_3_likes': 979.0}},
#  {'movie_likes': 11000,
#   'cast': {'director': 'Francis Lawrence',
#    'director_likes': 508.0,
#    'actor_1': 'Will Smith',
#    'actor_1_likes': 10000.0,
#    'actor_2': 'Alice Braga',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'Willow Smith',
#    'actor_3_likes': 558.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Tim Burton',
#    'director_likes': 13000.0,
#    'actor_1': 'Johnny Depp',
#    'actor_1_likes': 40000.0,
#    'actor_2': 'Christopher Lee',
#    'actor_2_likes': 16000.0,
#    'actor_3': 'David Kelly',
#    'actor_3_likes': 588.0}},
#  {'movie_likes': 10000,
#   'cast': {'director': 'Brad Bird',
#    'director_likes': 663.0,
#    'actor_1': 'Janeane Garofalo',
#    'actor_1_likes': 1000.0,
#    'actor_2': 'John Ratzenberger',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'Brian Dennehy',
#    'actor_3_likes': 954.0}},
#  {'movie_likes': 15000,
#   'cast': {'director': 'Christopher Nolan',
#    'director_likes': 22000.0,
#    'actor_1': 'Christian Bale',
#    'actor_1_likes': 23000.0,
#    'actor_2': 'Liam Neeson',
#    'actor_2_likes': 14000.0,
#    'actor_3': 'Morgan Freeman',
#    'actor_3_likes': 11000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Eric Darnell',
#    'director_likes': 35.0,
#    'actor_1': 'Bernie Mac',
#    'actor_1_likes': 1000.0,
#    'actor_2': 'Jada Pinkett Smith',
#    'actor_2_likes': 851.0,
#    'actor_3': 'Cedric the Entertainer',
#    'actor_3_likes': 436.0}},
#  {'movie_likes': 2000,
#   'cast': {'director': 'Shawn Levy',
#    'director_likes': 189.0,
#    'actor_1': 'Robin Williams',
#    'actor_1_likes': 49000.0,
#    'actor_2': 'Rami Malek',
#    'actor_2_likes': 3000.0,
#    'actor_3': 'Steve Coogan',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Gavin Hood',
#    'director_likes': 151.0,
#    'actor_1': 'Hugh Jackman',
#    'actor_1_likes': 20000.0,
#    'actor_2': 'Ryan Reynolds',
#    'actor_2_likes': 16000.0,
#    'actor_3': 'Dominic Monaghan',
#    'actor_3_likes': 2000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Lana Wachowski',
#    'director_likes': 0.0,
#    'actor_1': 'Essie Davis',
#    'actor_1_likes': 309.0,
#    'actor_2': 'Collin Chou',
#    'actor_2_likes': 269.0,
#    'actor_3': 'Nona Gaye',
#    'actor_3_likes': 233.0}},
#  {'movie_likes': 58000,
#   'cast': {'director': 'Chris Buck',
#    'director_likes': 69.0,
#    'actor_1': 'Josh Gad',
#    'actor_1_likes': 1000.0,
#    'actor_2': 'Maurice LaMarche',
#    'actor_2_likes': 523.0,
#    'actor_3': 'Livvy Stubenrauch',
#    'actor_3_likes': 490.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Lana Wachowski',
#    'director_likes': 0.0,
#    'actor_1': 'Steve Bastoni',
#    'actor_1_likes': 234.0,
#    'actor_2': 'Daniel Bernhardt',
#    'actor_2_likes': 198.0,
#    'actor_3': 'Helmut Bakaitis',
#    'actor_3_likes': 30.0}},
#  {'movie_likes': 63000,
#   'cast': {'director': 'Alan Taylor',
#    'director_likes': 230.0,
#    'actor_1': 'Chris Hemsworth',
#    'actor_1_likes': 26000.0,
#    'actor_2': 'Natalie Portman',
#    'actor_2_likes': 20000.0,
#    'actor_3': 'Anthony Hopkins',
#    'actor_3_likes': 12000.0}},
#  {'movie_likes': 191000,
#   'cast': {'director': 'George Miller',
#    'director_likes': 750.0,
#    'actor_1': 'Tom Hardy',
#    'actor_1_likes': 27000.0,
#    'actor_2': 'Charlize Theron',
#    'actor_2_likes': 9000.0,
#    'actor_3': 'Zoë Kravitz',
#    'actor_3_likes': 943.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Ron Howard',
#    'director_likes': 2000.0,
#    'actor_1': 'Tom Hanks',
#    'actor_1_likes': 15000.0,
#    'actor_2': 'Ayelet Zurer',
#    'actor_2_likes': 745.0,
#    'actor_3': 'Armin Mueller-Stahl',
#    'actor_3_likes': 294.0}},
#  {'movie_likes': 63000,
#   'cast': {'director': 'Kenneth Branagh',
#    'director_likes': 0.0,
#    'actor_1': 'Chris Hemsworth',
#    'actor_1_likes': 26000.0,
#    'actor_2': 'Natalie Portman',
#    'actor_2_likes': 20000.0,
#    'actor_3': 'Anthony Hopkins',
#    'actor_3_likes': 12000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Byron Howard',
#    'director_likes': 59.0,
#    'actor_1': 'Chloë Grace Moretz',
#    'actor_1_likes': 17000.0,
#    'actor_2': 'Diedrich Bader',
#    'actor_2_likes': 759.0,
#    'actor_3': 'James Lipton',
#    'actor_3_likes': 699.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Hoyt Yeatman',
#    'director_likes': 12.0,
#    'actor_1': 'Kelli Garner',
#    'actor_1_likes': 730.0,
#    'actor_2': 'Piper Mackenzie Harris',
#    'actor_2_likes': 607.0,
#    'actor_3': 'Niecy Nash',
#    'actor_3_likes': 182.0}},
#  {'movie_likes': 19000,
#   'cast': {'director': 'Jonathan Liebesman',
#    'director_likes': 473.0,
#    'actor_1': 'Liam Neeson',
#    'actor_1_likes': 14000.0,
#    'actor_2': 'Edgar Ramírez',
#    'actor_2_likes': 897.0,
#    'actor_3': 'Lily James',
#    'actor_3_likes': 502.0}},
#  {'movie_likes': 82000,
#   'cast': {'director': 'Tim Burton',
#    'director_likes': 13000.0,
#    'actor_1': 'Johnny Depp',
#    'actor_1_likes': 40000.0,
#    'actor_2': 'Chloë Grace Moretz',
#    'actor_2_likes': 17000.0,
#    'actor_3': 'Christopher Lee',
#    'actor_3_likes': 16000.0}},
#  {'movie_likes': 47000,
#   'cast': {'director': 'Christopher McQuarrie',
#    'director_likes': 188.0,
#    'actor_1': 'Tom Cruise',
#    'actor_1_likes': 10000.0,
#    'actor_2': 'Jeremy Renner',
#    'actor_2_likes': 10000.0,
#    'actor_3': 'Sean Harris',
#    'actor_3_likes': 641.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Joe Johnston',
#    'director_likes': 394.0,
#    'actor_1': 'Anthony Hopkins',
#    'actor_1_likes': 12000.0,
#    'actor_2': 'Simon Merrells',
#    'actor_2_likes': 490.0,
#    'actor_3': 'Art Malik',
#    'actor_3_likes': 162.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Steve Hickner',
#    'director_likes': 58.0,
#    'actor_1': 'Matthew Broderick',
#    'actor_1_likes': 2000.0,
#    'actor_2': 'Oprah Winfrey',
#    'actor_2_likes': 852.0,
#    'actor_3': 'Rip Torn',
#    'actor_3_likes': 826.0}},
#  {'movie_likes': 20000,
#   'cast': {'director': 'Jennifer Yuh Nelson',
#    'director_likes': 90.0,
#    'actor_1': 'Angelina Jolie Pitt',
#    'actor_1_likes': 11000.0,
#    'actor_2': 'Gary Oldman',
#    'actor_2_likes': 10000.0,
#    'actor_3': 'Mike Bell',
#    'actor_3_likes': 15.0}},
#  {'movie_likes': 18000,
#   'cast': {'director': 'M. Night Shyamalan',
#    'director_likes': 0.0,
#    'actor_1': 'Seychelle Gabriel',
#    'actor_1_likes': 1000.0,
#    'actor_2': 'Noah Ringer',
#    'actor_2_likes': 756.0,
#    'actor_3': 'Aasif Mandvi',
#    'actor_3_likes': 346.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'J.J. Abrams',
#    'director_likes': 14000.0,
#    'actor_1': 'Philip Seymour Hoffman',
#    'actor_1_likes': 22000.0,
#    'actor_2': 'Tom Cruise',
#    'actor_2_likes': 10000.0,
#    'actor_3': 'Eddie Marsan',
#    'actor_3_likes': 979.0}},
#  {'movie_likes': 33000,
#   'cast': {'director': 'Roland Emmerich',
#    'director_likes': 776.0,
#    'actor_1': 'Channing Tatum',
#    'actor_1_likes': 17000.0,
#    'actor_2': 'Jake Weber',
#    'actor_2_likes': 551.0,
#    'actor_3': 'Matt Craven',
#    'actor_3_likes': 256.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Simon Wells',
#    'director_likes': 25.0,
#    'actor_1': 'Elisabeth Harnois',
#    'actor_1_likes': 921.0,
#    'actor_2': 'Dan Fogler',
#    'actor_2_likes': 562.0,
#    'actor_3': 'Tom Everett Scott',
#    'actor_3_likes': 433.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'David Bowers',
#    'director_likes': 42.0,
#    'actor_1': 'Hugh Jackman',
#    'actor_1_likes': 20000.0,
#    'actor_2': 'Kate Winslet',
#    'actor_2_likes': 14000.0,
#    'actor_3': 'David Suchet',
#    'actor_3_likes': 586.0}},
#  {'movie_likes': 24000,
#   'cast': {'director': 'Joe Wright',
#    'director_likes': 456.0,
#    'actor_1': 'Hugh Jackman',
#    'actor_1_likes': 20000.0,
#    'actor_2': 'Cara Delevingne',
#    'actor_2_likes': 548.0,
#    'actor_3': 'Nonso Anozie',
#    'actor_3_likes': 394.0}},
#  {'movie_likes': 11000,
#   'cast': {'director': 'Rob Minkoff',
#    'director_likes': 50.0,
#    'actor_1': 'Ty Burrell',
#    'actor_1_likes': 3000.0,
#    'actor_2': 'Zach Callison',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'Karan Brar',
#    'actor_3_likes': 517.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Wolfgang Petersen',
#    'director_likes': 249.0,
#    'actor_1': 'Brad Pitt',
#    'actor_1_likes': 11000.0,
#    'actor_2': 'Orlando Bloom',
#    'actor_2_likes': 5000.0,
#    'actor_3': 'Julian Glover',
#    'actor_3_likes': 844.0}},
#  {'movie_likes': 17000,
#   'cast': {'director': 'Eric Darnell',
#    'director_likes': 35.0,
#    'actor_1': 'Jada Pinkett Smith',
#    'actor_1_likes': 851.0,
#    'actor_2': 'Martin Short',
#    'actor_2_likes': 770.0,
#    'actor_3': 'Cedric the Entertainer',
#    'actor_3_likes': 436.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Lee Tamahori',
#    'director_likes': 93.0,
#    'actor_1': 'Toby Stephens',
#    'actor_1_likes': 769.0,
#    'actor_2': 'Colin Salmon',
#    'actor_2_likes': 766.0,
#    'actor_3': 'Rick Yune',
#    'actor_3_likes': 746.0}},
#  {'movie_likes': 62000,
#   'cast': {'director': 'Paul Feig',
#    'director_likes': 176.0,
#    'actor_1': 'Ed Begley Jr.',
#    'actor_1_likes': 783.0,
#    'actor_2': 'Kate McKinnon',
#    'actor_2_likes': 370.0,
#    'actor_3': 'Zach Woods',
#    'actor_3_likes': 322.0}},
#  {'movie_likes': 11000,
#   'cast': {'director': 'Michael Bay',
#    'director_likes': 0.0,
#    'actor_1': 'Bruce Willis',
#    'actor_1_likes': 13000.0,
#    'actor_2': 'Steve Buscemi',
#    'actor_2_likes': 12000.0,
#    'actor_3': 'Will Patton',
#    'actor_3_likes': 537.0}},
#  {'movie_likes': 2000,
#   'cast': {'director': 'Barry Sonnenfeld',
#    'director_likes': 188.0,
#    'actor_1': 'Will Smith',
#    'actor_1_likes': 10000.0,
#    'actor_2': 'Rosario Dawson',
#    'actor_2_likes': 3000.0,
#    'actor_3': 'Rip Torn',
#    'actor_3_likes': 826.0}},
#  {'movie_likes': 3000,
#   'cast': {'director': 'Robert Zemeckis',
#    'director_likes': 0.0,
#    'actor_1': 'Robin Wright',
#    'actor_1_likes': 18000.0,
#    'actor_2': 'Anthony Hopkins',
#    'actor_2_likes': 12000.0,
#    'actor_3': 'Sebastian Roché',
#    'actor_3_likes': 964.0}},
#  {'movie_likes': 24000,
#   'cast': {'director': 'Alessandro Carloni',
#    'director_likes': 5.0,
#    'actor_1': 'J.K. Simmons',
#    'actor_1_likes': 24000.0,
#    'actor_2': 'Angelina Jolie Pitt',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Wayne Knight',
#    'actor_3_likes': 967.0}},
#  {'movie_likes': 35000,
#   'cast': {'director': 'Brad Bird',
#    'director_likes': 663.0,
#    'actor_1': 'Tom Cruise',
#    'actor_1_likes': 10000.0,
#    'actor_2': 'Jeremy Renner',
#    'actor_2_likes': 10000.0,
#    'actor_3': 'Michael Nyqvist',
#    'actor_3_likes': 690.0}},
#  {'movie_likes': 25000,
#   'cast': {'director': 'Peter Ramsey',
#    'director_likes': 52.0,
#    'actor_1': 'Hugh Jackman',
#    'actor_1_likes': 20000.0,
#    'actor_2': 'Kamil McFadden',
#    'actor_2_likes': 315.0,
#    'actor_3': 'Khamani Griffin',
#    'actor_3_likes': 161.0}},
#  {'movie_likes': 2000,
#   'cast': {'director': 'Dean Parisot',
#    'director_likes': 23.0,
#    'actor_1': 'John Michael Higgins',
#    'actor_1_likes': 957.0,
#    'actor_2': 'Richard Burgi',
#    'actor_2_likes': 550.0,
#    'actor_3': 'David Herman',
#    'actor_3_likes': 233.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Edward Zwick',
#    'director_likes': 380.0,
#    'actor_1': 'Tom Cruise',
#    'actor_1_likes': 10000.0,
#    'actor_2': 'Tony Goldwyn',
#    'actor_2_likes': 956.0,
#    'actor_3': 'Chad Lindberg',
#    'actor_3_likes': 445.0}},
#  {'movie_likes': 51000,
#   'cast': {'director': 'Ridley Scott',
#    'director_likes': 0.0,
#    'actor_1': 'Christian Bale',
#    'actor_1_likes': 23000.0,
#    'actor_2': 'María Valverde',
#    'actor_2_likes': 893.0,
#    'actor_3': 'Ben Mendelsohn',
#    'actor_3_likes': 748.0}},
#  {'movie_likes': 19000,
#   'cast': {'director': 'J.J. Abrams',
#    'director_likes': 14000.0,
#    'actor_1': 'Chris Hemsworth',
#    'actor_1_likes': 26000.0,
#    'actor_2': 'Leonard Nimoy',
#    'actor_2_likes': 12000.0,
#    'actor_3': 'Bruce Greenwood',
#    'actor_3_likes': 981.0}},
#  {'movie_likes': 5000,
#   'cast': {'director': 'Sam Raimi',
#    'director_likes': 0.0,
#    'actor_1': 'J.K. Simmons',
#    'actor_1_likes': 24000.0,
#    'actor_2': 'James Franco',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Kirsten Dunst',
#    'actor_3_likes': 4000.0}},
#  {'movie_likes': 46000,
#   'cast': {'director': 'Dean DeBlois',
#    'director_likes': 255.0,
#    'actor_1': 'Gerard Butler',
#    'actor_1_likes': 18000.0,
#    'actor_2': 'Djimon Hounsou',
#    'actor_2_likes': 3000.0,
#    'actor_3': 'America Ferrera',
#    'actor_3_likes': 953.0}},
#  {'movie_likes': 24000,
#   'cast': {'director': 'Alex Proyas',
#    'director_likes': 295.0,
#    'actor_1': 'Gerard Butler',
#    'actor_1_likes': 18000.0,
#    'actor_2': 'Elodie Yung',
#    'actor_2_likes': 934.0,
#    'actor_3': 'Bryan Brown',
#    'actor_3_likes': 284.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Rob Cohen',
#    'director_likes': 357.0,
#    'actor_1': 'Sam Shepard',
#    'actor_1_likes': 820.0,
#    'actor_2': 'Joe Morton',
#    'actor_2_likes': 780.0,
#    'actor_3': 'Richard Roxburgh',
#    'actor_3_likes': 653.0}},
#  {'movie_likes': 18000,
#   'cast': {'director': 'Zack Snyder',
#    'director_likes': 0.0,
#    'actor_1': 'Matt Frewer',
#    'actor_1_likes': 986.0,
#    'actor_2': 'Billy Crudup',
#    'actor_2_likes': 745.0,
#    'actor_3': 'Stephen McHattie',
#    'actor_3_likes': 413.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Richard Donner',
#    'director_likes': 503.0,
#    'actor_1': 'Jet Li',
#    'actor_1_likes': 5000.0,
#    'actor_2': 'Rene Russo',
#    'actor_2_likes': 808.0,
#    'actor_3': 'Darlene Love',
#    'actor_3_likes': 91.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Ang Lee',
#    'director_likes': 0.0,
#    'actor_1': 'Kevin Rankin',
#    'actor_1_likes': 820.0,
#    'actor_2': 'Regi Davis',
#    'actor_2_likes': 300.0,
#    'actor_3': 'Celia Weston',
#    'actor_3_likes': 258.0}},
#  {'movie_likes': 42000,
#   'cast': {'director': 'Jon M. Chu',
#    'director_likes': 209.0,
#    'actor_1': 'Channing Tatum',
#    'actor_1_likes': 17000.0,
#    'actor_2': 'Dwayne Johnson',
#    'actor_2_likes': 12000.0,
#    'actor_3': 'Elodie Yung',
#    'actor_3_likes': 934.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Breck Eisner',
#    'director_likes': 42.0,
#    'actor_1': 'Matthew McConaughey',
#    'actor_1_likes': 11000.0,
#    'actor_2': 'Rainn Wilson',
#    'actor_2_likes': 973.0,
#    'actor_3': 'Delroy Lindo',
#    'actor_3_likes': 848.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Hironobu Sakaguchi',
#    'director_likes': 6.0,
#    'actor_1': 'Steve Buscemi',
#    'actor_1_likes': 12000.0,
#    'actor_2': 'Ming-Na Wen',
#    'actor_2_likes': 2000.0,
#    'actor_3': 'Jean Simmons',
#    'actor_3_likes': 422.0}},
#  {'movie_likes': 46000,
#   'cast': {'director': 'Joe Johnston',
#    'director_likes': 394.0,
#    'actor_1': 'Chris Evans',
#    'actor_1_likes': 11000.0,
#    'actor_2': 'Dominic Cooper',
#    'actor_2_likes': 3000.0,
#    'actor_3': 'Hayley Atwell',
#    'actor_3_likes': 2000.0}},
#  {'movie_likes': 2000,
#   'cast': {'director': 'Michael Apted',
#    'director_likes': 150.0,
#    'actor_1': 'Colin Salmon',
#    'actor_1_likes': 766.0,
#    'actor_2': 'Maria Grazia Cucinotta',
#    'actor_2_likes': 536.0,
#    'actor_3': 'Desmond Llewelyn',
#    'actor_3_likes': 244.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Peter Weir',
#    'director_likes': 608.0,
#    'actor_1': "James D'Arcy",
#    'actor_1_likes': 613.0,
#    'actor_2': 'Lee Ingleby',
#    'actor_2_likes': 172.0,
#    'actor_3': 'David Threlfall',
#    'actor_3_likes': 168.0}},
#  {'movie_likes': 65000,
#   'cast': {'director': 'Bill Condon',
#    'director_likes': 386.0,
#    'actor_1': 'Robert Pattinson',
#    'actor_1_likes': 21000.0,
#    'actor_2': 'Kristen Stewart',
#    'actor_2_likes': 17000.0,
#    'actor_3': 'Taylor Lautner',
#    'actor_3_likes': 12000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'George Miller',
#    'director_likes': 750.0,
#    'actor_1': 'Robin Williams',
#    'actor_1_likes': 49000.0,
#    'actor_2': 'Brad Pitt',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Common',
#    'actor_3_likes': 988.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Louis Leterrier',
#    'director_likes': 255.0,
#    'actor_1': 'Ty Burrell',
#    'actor_1_likes': 3000.0,
#    'actor_2': 'Peter Mensah',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'William Hurt',
#    'actor_3_likes': 882.0}},
#  {'movie_likes': 0,
#   'cast': {'director': nan,
#    'director_likes': nan,
#    'actor_1': 'Don Johnson',
#    'actor_1_likes': 982.0,
#    'actor_2': 'Philip Michael Thomas',
#    'actor_2_likes': 321.0,
#    'actor_3': 'John Diehl',
#    'actor_3_likes': 184.0}},
#  {'movie_likes': 27000,
#   'cast': {'director': 'Steven Spielberg',
#    'director_likes': 14000.0,
#    'actor_1': 'Mark Rylance',
#    'actor_1_likes': 535.0,
#    'actor_2': 'Penelope Wilton',
#    'actor_2_likes': 400.0,
#    'actor_3': 'Rafe Spall',
#    'actor_3_likes': 358.0}},
#  {'movie_likes': 190000,
#   'cast': {'director': 'Alejandro G. Iñárritu',
#    'director_likes': 0.0,
#    'actor_1': 'Leonardo DiCaprio',
#    'actor_1_likes': 29000.0,
#    'actor_2': 'Tom Hardy',
#    'actor_2_likes': 27000.0,
# ...
#    'director_likes': 488.0,
#    'actor_1': 'Scarlett Johansson',
#    'actor_1_likes': 19000.0,
#    'actor_2': 'Matt Damon',
#    'actor_2_likes': 13000.0,
#    'actor_3': 'Stephanie Szostak',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Alex Proyas',
#    'director_likes': 295.0,
#    'actor_1': 'Nicolas Cage',
#    'actor_1_likes': 12000.0,
#    'actor_2': 'Ben Mendelsohn',
#    'actor_2_likes': 748.0,
#    'actor_3': 'Chandler Canterbury',
#    'actor_3_likes': 329.0}},
#  {'movie_likes': 2000,
#   'cast': {'director': 'Tom Dey',
#    'director_likes': 9.0,
#    'actor_1': 'Bradley Cooper',
#    'actor_1_likes': 14000.0,
#    'actor_2': 'Matthew McConaughey',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Zooey Deschanel',
#    'actor_3_likes': 11000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Hideo Nakata',
#    'director_likes': 62.0,
#    'actor_1': 'Naomi Watts',
#    'actor_1_likes': 6000.0,
#    'actor_2': 'Gary Cole',
#    'actor_2_likes': 989.0,
#    'actor_3': 'Sissy Spacek',
#    'actor_3_likes': 874.0}},
#  {'movie_likes': 44000,
#   'cast': {'director': 'Glenn Ficarra',
#    'director_likes': 43.0,
#    'actor_1': 'Ryan Gosling',
#    'actor_1_likes': 33000.0,
#    'actor_2': 'Emma Stone',
#    'actor_2_likes': 15000.0,
#    'actor_3': 'Steve Carell',
#    'actor_3_likes': 7000.0}},
#  {'movie_likes': 795,
#   'cast': {'director': 'Peter Hewitt',
#    'director_likes': 12.0,
#    'actor_1': 'Bill Murray',
#    'actor_1_likes': 13000.0,
#    'actor_2': 'Mark Christopher Lawrence',
#    'actor_2_likes': 258.0,
#    'actor_3': 'Michael Monks',
#    'actor_3_likes': 58.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Joe Roth',
#    'director_likes': 148.0,
#    'actor_1': 'Jamie Lee Curtis',
#    'actor_1_likes': 2000.0,
#    'actor_2': 'Cheech Marin',
#    'actor_2_likes': 843.0,
#    'actor_3': 'Jake Busey',
#    'actor_3_likes': 660.0}},
#  {'movie_likes': 27000,
#   'cast': {'director': 'Bennett Miller',
#    'director_likes': 152.0,
#    'actor_1': 'Philip Seymour Hoffman',
#    'actor_1_likes': 22000.0,
#    'actor_2': 'Robin Wright',
#    'actor_2_likes': 18000.0,
#    'actor_3': 'Brad Pitt',
#    'actor_3_likes': 11000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Wolfgang Petersen',
#    'director_likes': 249.0,
#    'actor_1': 'Kevin Spacey',
#    'actor_1_likes': 18000.0,
#    'actor_2': 'Morgan Freeman',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Rene Russo',
#    'actor_3_likes': 808.0}},
#  {'movie_likes': 24000,
#   'cast': {'director': 'Jaume Collet-Serra',
#    'director_likes': 174.0,
#    'actor_1': 'Liam Neeson',
#    'actor_1_likes': 14000.0,
#    'actor_2': 'Nate Parker',
#    'actor_2_likes': 664.0,
#    'actor_3': 'Scoot McNairy',
#    'actor_3_likes': 660.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Andy Fickman',
#    'director_likes': 99.0,
#    'actor_1': 'Dwayne Johnson',
#    'actor_1_likes': 12000.0,
#    'actor_2': 'Billy Brown',
#    'actor_2_likes': 536.0,
#    'actor_3': 'Tom Everett Scott',
#    'actor_3_likes': 433.0}},
#  {'movie_likes': 48000,
#   'cast': {'director': 'James McTeigue',
#    'director_likes': 160.0,
#    'actor_1': 'Natalie Portman',
#    'actor_1_likes': 20000.0,
#    'actor_2': 'Eddie Marsan',
#    'actor_2_likes': 979.0,
#    'actor_3': 'Rupert Graves',
#    'actor_3_likes': 443.0}},
#  {'movie_likes': 955,
#   'cast': {'director': 'David Dobkin',
#    'director_likes': 71.0,
#    'actor_1': 'Fann Wong',
#    'actor_1_likes': 154.0,
#    'actor_2': 'Anna-Louise Plowman',
#    'actor_2_likes': 131.0,
#    'actor_3': 'Georgina Chapman',
#    'actor_3_likes': 55.0}},
#  {'movie_likes': 0,
#   'cast': {'director': nan,
#    'director_likes': nan,
#    'actor_1': 'Bernard Hill',
#    'actor_1_likes': 416.0,
#    'actor_2': 'Gemma Jones',
#    'actor_2_likes': 171.0,
#    'actor_3': 'Nicola Walker',
#    'actor_3_likes': 132.0}},
#  {'movie_likes': 624,
#   'cast': {'director': "Matthew O'Callaghan",
#    'director_likes': 5.0,
#    'actor_1': 'Will Ferrell',
#    'actor_1_likes': 8000.0,
#    'actor_2': 'Frank Welker',
#    'actor_2_likes': 2000.0,
#    'actor_3': 'Alexander Gould',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 1000,
#   'cast': {'director': 'Angela Robinson',
#    'director_likes': 23.0,
#    'actor_1': 'Scoot McNairy',
#    'actor_1_likes': 660.0,
#    'actor_2': 'Thomas Lennon',
#    'actor_2_likes': 651.0,
#    'actor_3': 'Cheryl Hines',
#    'actor_3_likes': 541.0}},
#  {'movie_likes': 970,
#   'cast': {'director': 'Gary Fleder',
#    'director_likes': 39.0,
#    'actor_1': 'Oliver Platt',
#    'actor_1_likes': 1000.0,
#    'actor_2': 'Jennifer Esposito',
#    'actor_2_likes': 912.0,
#    'actor_3': 'Conrad Goode',
#    'actor_3_likes': 477.0}},
#  {'movie_likes': 45000,
#   'cast': {'director': 'Tommy Wirkola',
#    'director_likes': 75.0,
#    'actor_1': 'Jeremy Renner',
#    'actor_1_likes': 10000.0,
#    'actor_2': 'Derek Mears',
#    'actor_2_likes': 520.0,
#    'actor_3': 'Ingrid Bolsø Berdal',
#    'actor_3_likes': 467.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Adrian Lyne',
#    'director_likes': 213.0,
#    'actor_1': 'Olivier Martinez',
#    'actor_1_likes': 838.0,
#    'actor_2': 'Erik Per Sullivan',
#    'actor_2_likes': 593.0,
#    'actor_3': 'Chad Lowe',
#    'actor_3_likes': 372.0}},
#  {'movie_likes': 27000,
#   'cast': {'director': 'D.J. Caruso',
#    'director_likes': 154.0,
#    'actor_1': 'Alex Pettyfer',
#    'actor_1_likes': 15000.0,
#    'actor_2': 'Emily Wickersham',
#    'actor_2_likes': 348.0,
#    'actor_3': 'Reuben Langdon',
#    'actor_3_likes': 144.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Stephen Gaghan',
#    'director_likes': 79.0,
#    'actor_1': 'Matt Damon',
#    'actor_1_likes': 13000.0,
#    'actor_2': 'Amr Waked',
#    'actor_2_likes': 903.0,
#    'actor_3': 'Kayvan Novak',
#    'actor_3_likes': 414.0}},
#  {'movie_likes': 44000,
#   'cast': {'director': 'Michael Bay',
#    'director_likes': 0.0,
#    'actor_1': 'Toby Stephens',
#    'actor_1_likes': 769.0,
#    'actor_2': 'James Badge Dale',
#    'actor_2_likes': 726.0,
#    'actor_3': 'David Costabile',
#    'actor_3_likes': 681.0}},
#  {'movie_likes': 18000,
#   'cast': {'director': 'Jorge R. Gutiérrez',
#    'director_likes': 34.0,
#    'actor_1': 'Channing Tatum',
#    'actor_1_likes': 17000.0,
#    'actor_2': 'Hector Elizondo',
#    'actor_2_likes': 995.0,
#    'actor_3': 'Ana de la Reguera',
#    'actor_3_likes': 679.0}},
#  {'movie_likes': 773,
#   'cast': {'director': 'Richard Loncraine',
#    'director_likes': 12.0,
#    'actor_1': 'Jimmy Bennett',
#    'actor_1_likes': 87000.0,
#    'actor_2': 'Harrison Ford',
#    'actor_2_likes': 11000.0,
#    'actor_3': 'Mary Lynn Rajskub',
#    'actor_3_likes': 935.0}},
#  {'movie_likes': 1000,
#   'cast': {'director': 'Clint Eastwood',
#    'director_likes': 16000.0,
#    'actor_1': 'Clint Eastwood',
#    'actor_1_likes': 16000.0,
#    'actor_2': 'Mark Margolis',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'Scott Glenn',
#    'actor_3_likes': 826.0}},
#  {'movie_likes': 2000,
#   'cast': {'director': 'Ridley Scott',
#    'director_likes': 0.0,
#    'actor_1': 'Viggo Mortensen',
#    'actor_1_likes': 10000.0,
#    'actor_2': 'Demi Moore',
#    'actor_2_likes': 2000.0,
#    'actor_3': 'John Michael Higgins',
#    'actor_3_likes': 957.0}},
#  {'movie_likes': 25000,
#   'cast': {'director': 'David Fincher',
#    'director_likes': 21000.0,
#    'actor_1': 'Deborah Kara Unger',
#    'actor_1_likes': 495.0,
#    'actor_2': 'Armin Mueller-Stahl',
#    'actor_2_likes': 294.0,
#    'actor_3': 'Charles Martinet',
#    'actor_3_likes': 283.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Christophe Gans',
#    'director_likes': 50.0,
#    'actor_1': 'Radha Mitchell',
#    'actor_1_likes': 992.0,
#    'actor_2': 'Deborah Kara Unger',
#    'actor_2_likes': 495.0,
#    'actor_3': 'Alice Krige',
#    'actor_3_likes': 368.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Howard Deutch',
#    'director_likes': 41.0,
#    'actor_1': 'Keanu Reeves',
#    'actor_1_likes': 18000.0,
#    'actor_2': 'Jon Favreau',
#    'actor_2_likes': 4000.0,
#    'actor_3': 'Faizon Love',
#    'actor_3_likes': 585.0}},
#  {'movie_likes': 39000,
#   'cast': {'director': 'Jon Hurwitz',
#    'director_likes': 22.0,
#    'actor_1': 'Alyson Hannigan',
#    'actor_1_likes': 3000.0,
#    'actor_2': 'Dania Ramirez',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'Natasha Lyonne',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 3000,
#   'cast': {'director': 'F. Gary Gray',
#    'director_likes': 473.0,
#    'actor_1': 'Kevin Spacey',
#    'actor_1_likes': 18000.0,
#    'actor_2': 'Michael Cudlitz',
#    'actor_2_likes': 822.0,
#    'actor_3': 'Siobhan Fallon Hogan',
#    'actor_3_likes': 294.0}},
#  {'movie_likes': 15000,
#   'cast': {'director': 'Steven Quale',
#    'director_likes': 77.0,
#    'actor_1': 'Matt Walsh',
#    'actor_1_likes': 490.0,
#    'actor_2': 'Alycia Debnam-Carey',
#    'actor_2_likes': 298.0,
#    'actor_3': 'Scott Lawrence',
#    'actor_3_likes': 159.0}},
#  {'movie_likes': 669,
#   'cast': {'director': 'John Landis',
#    'director_likes': 644.0,
#    'actor_1': 'Louis Lombardi',
#    'actor_1_likes': 437.0,
#    'actor_2': 'Jon Tenney',
#    'actor_2_likes': 289.0,
#    'actor_3': 'Gilbert R. Hill',
#    'actor_3_likes': 174.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Joe Dante',
#    'director_likes': 287.0,
#    'actor_1': 'Christopher Lee',
#    'actor_1_likes': 16000.0,
#    'actor_2': 'Robert Picardo',
#    'actor_2_likes': 823.0,
#    'actor_3': 'Phoebe Cates',
#    'actor_3_likes': 767.0}},
#  {'movie_likes': 47000,
#   'cast': {'director': 'David Dobkin',
#    'director_likes': 71.0,
#    'actor_1': 'Robert Downey Jr.',
#    'actor_1_likes': 21000.0,
#    'actor_2': 'Robert Duvall',
#    'actor_2_likes': 3000.0,
#    'actor_3': 'Leighton Meester',
#    'actor_3_likes': 3000.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Mimi Leder',
#    'director_likes': 75.0,
#    'actor_1': 'Armin Mueller-Stahl',
#    'actor_1_likes': 294.0,
#    'actor_2': 'Holt McCallany',
#    'actor_2_likes': 273.0,
#    'actor_3': 'Marcel Iures',
#    'actor_3_likes': 258.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Alexander Witt',
#    'director_likes': 38.0,
#    'actor_1': 'Milla Jovovich',
#    'actor_1_likes': 14000.0,
#    'actor_2': 'Thomas Kretschmann',
#    'actor_2_likes': 919.0,
#    'actor_3': 'Mike Epps',
#    'actor_3_likes': 706.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Beeban Kidron',
#    'director_likes': 17.0,
#    'actor_1': 'Colin Firth',
#    'actor_1_likes': 14000.0,
#    'actor_2': 'Jim Broadbent',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'Celia Imrie',
#    'actor_3_likes': 186.0}},
#  {'movie_likes': 1000,
#   'cast': {'director': 'Carl Franklin',
#    'director_likes': 73.0,
#    'actor_1': 'Denzel Washington',
#    'actor_1_likes': 18000.0,
#    'actor_2': 'Sanaa Lathan',
#    'actor_2_likes': 886.0,
#    'actor_3': 'John Billingsley',
#    'actor_3_likes': 323.0}},
#  {'movie_likes': 812,
#   'cast': {'director': 'Steven Seagal',
#    'director_likes': 0.0,
#    'actor_1': 'Mike Starr',
#    'actor_1_likes': 854.0,
#    'actor_2': 'Joan Chen',
#    'actor_2_likes': 643.0,
#    'actor_3': 'Sven-Ole Thorsen',
#    'actor_3_likes': 158.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Robert Rodriguez',
#    'director_likes': 0.0,
#    'actor_1': 'Taylor Lautner',
#    'actor_1_likes': 12000.0,
#    'actor_2': 'Kristin Davis',
#    'actor_2_likes': 722.0,
#    'actor_3': 'Taylor Dooley',
#    'actor_3_likes': 717.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Danny Boyle',
#    'director_likes': 0.0,
#    'actor_1': 'Leonardo DiCaprio',
#    'actor_1_likes': 29000.0,
#    'actor_2': 'Virginie Ledoyen',
#    'actor_2_likes': 414.0,
#    'actor_3': 'Peter Youngblood Hills',
#    'actor_3_likes': 39.0}},
#  {'movie_likes': 718,
#   'cast': {'director': 'Garry Marshall',
#    'director_likes': 0.0,
#    'actor_1': 'Amber Valletta',
#    'actor_1_likes': 627.0,
#    'actor_2': 'Felicity Huffman',
#    'actor_2_likes': 508.0,
#    'actor_3': 'Spencer Breslin',
#    'actor_3_likes': 434.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'James McTeigue',
#    'director_likes': 160.0,
#    'actor_1': 'Shô Kosugi',
#    'actor_1_likes': 330.0,
#    'actor_2': 'Ben Miles',
#    'actor_2_likes': 119.0,
#    'actor_3': 'Rain',
#    'actor_3_likes': 72.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Sam Raimi',
#    'director_likes': 0.0,
#    'actor_1': 'J.K. Simmons',
#    'actor_1_likes': 24000.0,
#    'actor_2': 'Kelly Preston',
#    'actor_2_likes': 743.0,
#    'actor_3': 'Carmine Giovinazzo',
#    'actor_3_likes': 432.0}},
#  {'movie_likes': 361,
#   'cast': {'director': nan,
#    'director_likes': nan,
#    'actor_1': 'David Jason',
#    'actor_1_likes': 325.0,
#    'actor_2': 'Bruce Alexander',
#    'actor_2_likes': 7.0,
#    'actor_3': 'John Lyons',
#    'actor_3_likes': 5.0}},
#  {'movie_likes': 877,
#   'cast': {'director': 'Andrew Bergman',
#    'director_likes': 31.0,
#    'actor_1': 'Demi Moore',
#    'actor_1_likes': 2000.0,
#    'actor_2': 'Rumer Willis',
#    'actor_2_likes': 472.0,
#    'actor_3': 'Paul Guilfoyle',
#    'actor_3_likes': 210.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Tom Dey',
#    'director_likes': 9.0,
#    'actor_1': 'Emma Stone',
#    'actor_1_likes': 15000.0,
#    'actor_2': 'Judy Greer',
#    'actor_2_likes': 2000.0,
#    'actor_3': 'Steve Coogan',
#    'actor_3_likes': 1000.0}},
#  {'movie_likes': 16000,
#   'cast': {'director': 'Clint Eastwood',
#    'director_likes': 16000.0,
#    'actor_1': 'Matt Damon',
#    'actor_1_likes': 13000.0,
#    'actor_2': 'Jay Mohr',
#    'actor_2_likes': 563.0,
#    'actor_3': 'Cécile De France',
#    'actor_3_likes': 447.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Barbet Schroeder',
#    'director_likes': 58.0,
#    'actor_1': 'Ryan Gosling',
#    'actor_1_likes': 33000.0,
#    'actor_2': 'Chris Penn',
#    'actor_2_likes': 455.0,
#    'actor_3': 'Agnes Bruckner',
#    'actor_3_likes': 401.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Richard Donner',
#    'director_likes': 503.0,
#    'actor_1': 'Muse Watson',
#    'actor_1_likes': 45000.0,
#    'actor_2': 'Sylvester Stallone',
#    'actor_2_likes': 13000.0,
#    'actor_3': 'Kelly Rowan',
#    'actor_3_likes': 282.0}},
#  {'movie_likes': 3000,
#   'cast': {'director': 'Peter Webber',
#    'director_likes': 73.0,
#    'actor_1': 'Li Gong',
#    'actor_1_likes': 879.0,
#    'actor_2': 'Stephen Walters',
#    'actor_2_likes': 184.0,
#    'actor_3': 'Richard Brake',
#    'actor_3_likes': 163.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Rob Reiner',
#    'director_likes': 0.0,
#    'actor_1': 'Bruce Willis',
#    'actor_1_likes': 13000.0,
#    'actor_2': 'Tim Matheson',
#    'actor_2_likes': 559.0,
#    'actor_3': 'Rita Wilson',
#    'actor_3_likes': 323.0}},
#  {'movie_likes': 43000,
#   'cast': {'director': 'Andrew Niccol',
#    'director_likes': 487.0,
#    'actor_1': 'J.D. Evermore',
#    'actor_1_likes': 430.0,
#    'actor_2': 'Chandler Canterbury',
#    'actor_2_likes': 329.0,
#    'actor_3': 'Rachel Roberts',
#    'actor_3_likes': 201.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'John McTiernan',
#    'director_likes': 323.0,
#    'actor_1': 'Connie Nielsen',
#    'actor_1_likes': 933.0,
#    'actor_2': 'Harry Connick Jr.',
#    'actor_2_likes': 631.0,
#    'actor_3': 'Tim Daly',
#    'actor_3_likes': 511.0}},
#  {'movie_likes': 705,
#   'cast': {'director': 'Clint Eastwood',
#    'director_likes': 16000.0,
#    'actor_1': 'Clint Eastwood',
#    'actor_1_likes': 16000.0,
#    'actor_2': 'Anjelica Huston',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'Rick Hoffman',
#    'actor_3_likes': 581.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Tom Tykwer',
#    'director_likes': 670.0,
#    'actor_1': 'Naomi Watts',
#    'actor_1_likes': 6000.0,
#    'actor_2': "Brían F. O'Byrne",
#    'actor_2_likes': 450.0,
#    'actor_3': 'Armin Mueller-Stahl',
#    'actor_3_likes': 294.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'John Carpenter',
#    'director_likes': 0.0,
#    'actor_1': 'Steve Buscemi',
#    'actor_1_likes': 12000.0,
#    'actor_2': 'Valeria Golino',
#    'actor_2_likes': 898.0,
#    'actor_3': 'Michelle Forbes',
#    'actor_3_likes': 764.0}},
#  {'movie_likes': 915,
#   'cast': {'director': nan,
#    'director_likes': nan,
#    'actor_1': 'Grey Damon',
#    'actor_1_likes': 629.0,
#    'actor_2': 'Brittany Curran',
#    'actor_2_likes': 512.0,
#    'actor_3': 'Aaron Hill',
#    'actor_3_likes': 398.0}},
#  {'movie_likes': 0,
#   'cast': {'director': 'Brad Bird',
#    'director_likes': 663.0,
#    'actor_1': 'Vin Diesel',
#    'actor_1_likes': 14000.0,
#    'actor_2': 'Harry Connick Jr.',
#    'actor_2_likes': 631.0,
#    'actor_3': 'M. Emmet Walsh',
#    'actor_3_likes': 521.0}},
#  ...]

# %%
id_l
# Out:
# ['tt0499549',
#  'tt0449088',
#  'tt2379713',
#  'tt1345836',
#  'tt5289954',
#  'tt0401729',
#  'tt0413300',
#  'tt0398286',
#  'tt2395427',
#  'tt0417741',
#  'tt2975590',
#  'tt0348150',
#  'tt0830515',
#  'tt0383574',
#  'tt1210819',
#  'tt0770828',
#  'tt0499448',
#  'tt0848228',
#  'tt1298650',
#  'tt1409024',
#  'tt2310332',
#  'tt0948470',
#  'tt0955308',
#  'tt1170358',
#  'tt0385752',
#  'tt0360717',
#  'tt0120338',
#  'tt3498820',
#  'tt1440129',
#  'tt0369610',
#  'tt1074638',
#  'tt0316654',
#  'tt1300854',
#  'tt1014759',
#  'tt0376994',
#  'tt1453405',
#  'tt1055369',
#  'tt2109248',
#  'tt1623205',
#  'tt1872181',
#  'tt1104001',
#  'tt1216475',
#  'tt1133985',
#  'tt0435761',
#  'tt0438488',
#  'tt2820852',
#  'tt0816711',
#  'tt1877832',
#  'tt1408101',
#  'tt1351685',
#  'tt1343092',
#  'tt0473075',
#  'tt1663662',
#  'tt1399103',
#  'tt0367882',
#  'tt1979388',
#  'tt1217209',
#  'tt2660888',
#  'tt0910970',
#  'tt0293564',
#  'tt1190080',
#  'tt1067106',
#  'tt1617661',
#  'tt0918940',
#  'tt0363771',
#  'tt3385516',
#  'tt0468569',
#  'tt1049413',
#  'tt0892782',
#  'tt0371746',
#  'tt0970179',
#  'tt0120891',
#  'tt0859163',
#  'tt1386697',
#  'tt0413099',
#  'tt1631867',
#  'tt0114898',
#  'tt1046173',
#  'tt2096673',
#  'tt3040964',
#  'tt1228705',
#  'tt1735898',
#  'tt1587310',
#  'tt2103281',
#  'tt1321869',
#  'tt1335975',
#  'tt1843866',
#  'tt0892791',
#  'tt1964418',
#  'tt2245084',
#  'tt1772341',
#  'tt0338348',
#  'tt1628841',
#  'tt0892769',
#  'tt0181852',
#  'tt2015381',
#  'tt0816692',
#  'tt1375666',
#  'tt4262980',
#  'tt0903624',
#  'tt0232500',
#  'tt0421715',
#  'tt1270798',
#  'tt1951266',
#  'tt0963966',
#  'tt0409182',
#  'tt2567026',
#  'tt0413267',
#  'tt0803096',
#  'tt1340138',
#  'tt0980970',
#  'tt0213149',
#  'tt0418279',
#  'tt0346491',
#  'tt0373889',
#  'tt0330373',
#  'tt0448157',
#  'tt0480249',
#  'tt0367594',
#  'tt0382932',
#  'tt0372784',
#  'tt0479952',
#  'tt1078912',
#  'tt0458525',
#  'tt0242653',
#  'tt2294629',
#  'tt0234215',
#  'tt1981115',
#  'tt1392190',
#  'tt0808151',
#  'tt0800369',
#  'tt0397892',
#  'tt0436339',
#  'tt1646987',
#  'tt1077368',
#  'tt2381249',
#  'tt0780653',
#  'tt0389790',
#  'tt1302011',
#  'tt0938283',
#  'tt0317919',
#  'tt2334879',
#  'tt1305591',
#  'tt0424095',
#  'tt3332064',
#  'tt0864835',
#  'tt0332452',
#  'tt1277953',
#  'tt0246460',
#  'tt1289401',
#  'tt0120591',
#  'tt0120912',
#  'tt0442933',
#  'tt2267968',
#  'tt1229238',
#  'tt1446192',
#  'tt0369441',
#  'tt0325710',
#  'tt1528100',
#  'tt0796366',
#  'tt0145487',
#  'tt1646971',
#  'tt2404233',
#  'tt0382992',
#  'tt0409459',
#  'tt0122151',
#  'tt0286716',
#  'tt1583421',
#  'tt0318649',
#  'tt0173840',
#  'tt0458339',
#  'tt0143145',
#  'tt0311113',
#  'tt1673434',
#  'tt1402488',
#  'tt0800080',
#  'tt0086759',
#  'tt3691740',
#  'tt1663202',
#  'tt1860353',
#  'tt1192628',
#  'tt1911658',
#  'tt0440963',
#  'tt0441773',
#  'tt0478970',
#  'tt1951264',
#  'tt2224026',
#  'tt0407304',
#  'tt0172156',
#  'tt0448694',
#  'tt0944835',
#  'tt1959490',
#  'tt0983193',
#  'tt0304141',
#  'tt0455824',
#  'tt1815862',
#  'tt0130623',
#  'tt1680310',
#  'tt2692250',
#  'tt1001526',
#  'tt0241527',
#  'tt0790736',
#  'tt0325980',
#  'tt1571403',
#  'tt1951265',
#  'tt0382625',
#  'tt2357291',
#  'tt0290334',
#  'tt1596343',
#  'tt1515091',
#  'tt0800320',
#  'tt0100802',
#  'tt0120657',
#  'tt1194173',
#  'tt0118688',
#  'tt0170016',
#  'tt0319262',
#  'tt0120755',
#  'tt0177971',
#  'tt0486576',
#  'tt0454876',
#  'tt0259324',
#  'tt4196776',
#  'tt0305357',
#  'tt1446714',
#  'tt0243585',
#  'tt1535108',
#  'tt0296572',
#  'tt1234721',
#  'tt0811080',
#  'tt1341188',
#  'tt1013743',
#  'tt1483013',
#  'tt0121766',
#  'tt0121765',
#  'tt0198781',
#  'tt1430132',
#  'tt0120915',
#  'tt0481499',
#  'tt0463872',
#  'tt0245562',
#  'tt2381991',
#  'tt1291150',
#  'tt1454468',
#  'tt0118928',
#  'tt3949660',
#  'tt1502712',
#  'tt0477347',
#  'tt2126355',
#  'tt0120347',
#  'tt0187393',
#  'tt0349903',
#  'tt0356910',
#  'tt2908446',
#  'tt0338751',
#  'tt1320261',
#  'tt0990407',
#  'tt0084967',
#  'tt1253863',
#  'tt0472181',
#  'tt0299172',
#  'tt3410834',
#  'tt0433035',
#  'tt2017020',
#  'tt0120179',
#  'tt1731141',
#  'tt0337978',
#  'tt0120737',
#  'tt0327437',
#  'tt0248667',
#  'tt0312528',
#  'tt0343818',
#  'tt0320661',
#  'tt0164912',
#  'tt0780521',
#  'tt3659388',
#  'tt1869849',
#  'tt0399201',
#  'tt0141907',
#  'tt0187078',
#  'tt0172495',
#  'tt0181689',
#  'tt0295297',
#  'tt0381061',
#  'tt0133152',
#  'tt0103064',
#  'tt1152836',
#  'tt0765429',
#  'tt0111503',
#  'tt1111422',
#  'tt0970866',
#  'tt1386588',
#  'tt0116213',
#  'tt1853728',
#  'tt0116583',
#  'tt0120917',
#  'tt1764651',
#  'tt0368891',
#  'tt0449010',
#  'tt0386117',
#  'tt0848537',
#  'tt1243957',
#  'tt0146675',
#  'tt0450259',
#  'tt0993846',
#  'tt0112462',
#  'tt0120201',
#  'tt1371111',
#  'tt1219342',
#  'tt0327554',
#  'tt1267297',
#  'tt0133240',
#  'tt0457400',
#  'tt2333784',
#  'tt2058673',
#  'tt0362165',
#  'tt1390411',
#  'tt0180052',
#  'tt0947810',
#  'tt2452042',
#  'tt0120176',
#  'tt0209163',
#  'tt0217505',
#  'tt1410063',
#  'tt0423294',
#  'tt0327162',
#  'tt0265086',
#  'tt1790886',
#  'tt0119116',
#  'tt1261945',
#  'tt0138749',
#  'tt1667889',
#  'tt1661199',
#  'tt0380510',
#  'tt0266543',
#  'tt0167260',
#  'tt0167261',
#  'tt1121096',
#  'tt0146316',
#  'tt2209764',
#  'tt0163025',
#  'tt1318514',
#  'tt0416236',
#  'tt1606378',
#  'tt0318974',
#  'tt0317705',
#  'tt0112760',
#  'tt0814255',
#  'tt0119654',
#  'tt0120363',
#  'tt0477080',
#  'tt0266915',
#  'tt0161081',
#  'tt0844471',
#  'tt1080016',
#  'tt0359950',
#  'tt0160127',
#  'tt0407887',
#  'tt0120762',
#  'tt0942385',
#  'tt1568346',
#  'tt0112864',
#  'tt0988045',
#  'tt2638144',
#  'tt0230011',
#  'tt2974918',
#  'tt0985699',
#  'tt0960144',
#  'tt2120120',
#  'tt0212720',
#  'tt0338094',
#  'tt0118884',
#  'tt0164052',
#  'tt0373926',
#  'tt1854564',
#  'tt0325703',
#  'tt3110958',
#  'tt0120053',
#  'tt0266987',
#  'tt0183523',
#  'tt1436562',
#  'tt0182789',
#  'tt0120461',
#  'tt0118972',
#  'tt0267626',
#  'tt0082198',
#  'tt0352248',
#  'tt1041804',
#  'tt0329575',
#  'tt0117998',
#  'tt0162222',
#  'tt0366548',
#  'tt0372183',
#  'tt0118571',
#  'tt0240772',
#  'tt1509767',
#  'tt0837562',
#  'tt0461770',
#  'tt2243973',
#  'tt1599348',
#  'tt0211181',
#  'tt0471042',
#  'tt0457939',
#  'tt0120660',
#  'tt1230414',
#  'tt0496806',
#  'tt0400717',
#  'tt1840309',
#  'tt0215750',
#  'tt0327850',
#  'tt0107362',
#  'tt0397535',
#  'tt0463985',
#  'tt1430607',
#  'tt0119643',
#  'tt0233469',
#  'tt0078754',
#  'tt1667353',
#  'tt0446029',
#  'tt0298814',
#  'tt0144528',
#  'tt0267913',
#  'tt1343727',
#  'tt0389860',
#  'tt0083767',
#  'tt1287468',
#  'tt0489099',
#  'tt0411477',
#  'tt0443706',
#  'tt0216216',
#  'tt0315327',
#  'tt1320253',
#  'tt0117060',
#  'tt1392170',
#  'tt1411697',
#  'tt0103776',
#  'tt0327084',
#  'tt0275847',
#  'tt0413895',
#  'tt0120647',
#  'tt1821694',
#  'tt0398165',
#  'tt1615918',
#  'tt2191701',
#  'tt0425061',
#  'tt0337741',
#  'tt1130884',
#  'tt0369436',
#  'tt0358082',
#  'tt0119094',
#  'tt0960731',
#  'tt0257044',
#  'tt1564367',
#  'tt3322312',
#  'tt0118880',
#  'tt1059786',
#  'tt0159365',
#  'tt1037705',
#  'tt0119137',
#  'tt0171363',
#  'tt0117705',
#  'tt0383216',
#  'tt0970416',
#  'tt0118883',
#  'tt2713180',
#  'tt0120828',
#  'tt1302067',
#  'tt0166813',
#  'tt1222817',
#  'tt0120738',
#  'tt0368008',
#  'tt0119033',
#  'tt2510894',
#  'tt0057733',
#  'tt0120910',
#  'tt0268695',
#  'tt0120751',
#  'tt0244244',
#  'tt0386140',
#  'tt0120889',
#  'tt0185431',
#  'tt0355295',
#  'tt0116996',
#  'tt4291590',
#  'tt0119051',
#  'tt0986263',
#  'tt0146309',
#  'tt0116040',
#  'tt1762399',
#  'tt0185183',
#  'tt0318155',
#  'tt0875034',
#  'tt0300556',
#  'tt0119925',
#  'tt0120595',
#  'tt1618442',
#  'tt0199753',
#  'tt0344854',
#  'tt0765128',
#  'tt0318081',
#  'tt1921064',
#  'tt4057916',
#  'tt0268978',
#  'tt0110357',
#  'tt1397514',
#  'tt1985966',
#  'tt0289765',
#  'tt0317648',
#  'tt0810913',
#  'tt0322259',
#  'tt1754656',
#  'tt0427392',
#  'tt0131704',
#  'tt2709768',
#  'tt0311429',
#  'tt1690953',
#  'tt0116629',
#  'tt0119567',
#  'tt0351283',
#  'tt0206634',
#  'tt0120903',
#  'tt0493464',
#  'tt0117500',
#  'tt0438097',
#  'tt0343660',
#  'tt0427327',
#  'tt0204313',
#  'tt0141369',
#  'tt1670345',
#  'tt1375670',
#  'tt0362227',
#  'tt3489184',
#  'tt0785006',
#  'tt0190865',
#  'tt0472062',
#  'tt0307453',
#  'tt0443489',
#  'tt0874936',
#  'tt0377471',
#  'tt0408306',
#  'tt0314353',
#  'tt1103153',
#  'tt1638355',
#  'tt0371246',
#  'tt0385880',
#  'tt0219965',
#  'tt0113071',
#  'tt0166485',
#  'tt1253864',
#  'tt0340163',
#  'tt0120913',
#  'tt0329717',
#  'tt0120157',
#  'tt0806203',
#  'tt0166276',
#  'tt0377062',
#  'tt0217869',
#  'tt2293640',
#  'tt0978764',
#  'tt0120832',
#  'tt0120184',
#  'tt1985949',
#  'tt0770752',
#  'tt1201167',
#  'tt0431197',
#  'tt0415306',
#  'tt0240462',
#  'tt0112573',
#  'tt0418763',
#  'tt0462538',
#  'tt0268995',
#  'tt0132245',
#  'tt0338512',
#  'tt0368447',
#  'tt0118998',
#  'tt0286106',
#  'tt0298148',
#  'tt0317219',
#  'tt0163187',
#  'tt0295701',
#  'tt2279373',
#  'tt0117438',
#  'tt0361748',
#  'tt0102057',
#  'tt0099423',
#  'tt0257076',
#  'tt2647544',
#  'tt0259711',
#  'tt0452637',
#  'tt0370263',
#  'tt1231580',
#  'tt0277434',
#  'tt2302755',
#  'tt0120844',
#  'tt1217613',
#  'tt0319061',
#  'tt0111742',
#  'tt1568911',
#  'tt2177771',
#  'tt0096754',
#  'tt1027718',
#  'tt0829150',
#  'tt0133952',
#  'tt0486655',
#  'tt0120102',
#  'tt1578275',
#  'tt0280486',
#  'tt0419706',
#  'tt0297181',
#  'tt1496025',
#  'tt1336608',
#  'tt0251114',
#  'tt1448755',
#  'tt0246894',
#  'tt0308208',
#  'tt0120696',
#  'tt0181739',
#  'tt0884726',
#  'tt2717822',
#  'tt0346156',
#  'tt0430912',
#  'tt1211956',
#  'tt1043726',
#  'tt0164184',
#  'tt1325004',
#  'tt0227445',
#  'tt1323594',
#  'tt0113845',
#  'tt2637276',
#  'tt1186830',
#  'tt0132347',
#  'tt0480687',
#  'tt0140352',
#  'tt2025690',
#  'tt0758774',
#  'tt0427152',
#  'tt1611224',
#  'tt0137494',
#  'tt1828327',
#  'tt0120902',
#  'tt0462396',
#  'tt0120815',
#  'tt2369135',
#  'tt0207201',
#  'tt0268380',
#  'tt0285531',
#  'tt0443272',
#  'tt0133093',
#  'tt0112384',
#  'tt0304669',
#  'tt1707386',
#  'tt0128853',
#  'tt0838283',
#  'tt0120746',
#  'tt1231583',
#  'tt1809398',
#  'tt0186566',
#  'tt0106582',
#  'tt0115759',
#  'tt0219854',
#  'tt0469641',
#  'tt0304415',
#  'tt1645170',
#  'tt0120663',
#  'tt1823664',
#  'tt2381941',
#  'tt1596350',
#  'tt0359013',
#  'tt0087985',
#  'tt0119942',
#  'tt1855325',
#  'tt0452608',
#  'tt0116908',
#  'tt0228750',
#  'tt0406375',
#  'tt0137523',
#  'tt0758794',
#  'tt3877200',
#  'tt0102070',
#  'tt0219952',
#  'tt1418377',
#  'tt0380599',
#  'tt0357277',
#  'tt0458481',
#  'tt0156934',
#  'tt2719848',
#  'tt0396171',
#  'tt0295178',
#  'tt0375568',
#  'tt0107290',
#  'tt0111756',
#  'tt0109444',
#  'tt3672840',
#  'tt0430304',
#  'tt0141926',
#  'tt0112346',
#  'tt0811138',
#  'tt0233142',
#  'tt3460252',
#  'tt0445934',
#  'tt1411704',
#  'tt0416449',
#  'tt0290002',
#  'tt0822832',
#  'tt0120689',
#  'tt0486946',
#  'tt0371606',
#  'tt2267998',
#  'tt0258463',
#  'tt0113189',
#  'tt0144214',
#  'tt0120382',
#  'tt0120794',
#  'tt0317303',
#  'tt1272878',
#  'tt0239395',
#  'tt0317740',
#  'tt0313737',
#  'tt0120587',
#  'tt1078940',
#  'tt0099371',
#  'tt0452598',
#  'tt4046784',
#  'tt0879870',
#  'tt0218967',
#  'tt1245526',
#  'tt0146838',
#  'tt0119314',
#  'tt0369339',
#  'tt0277296',
#  'tt0349710',
#  'tt0790724',
#  'tt0149261',
#  'tt1477715',
#  'tt1598778',
#  'tt0257568',
#  'tt0327597',
#  'tt0949731',
#  'tt0328107',
#  'tt0393735',
#  'tt0335438',
#  'tt0116705',
#  'tt0167190',
#  'tt0120633',
#  'tt1623288',
#  'tt0119395',
#  'tt0338337',
#  'tt0118055',
#  'tt0420238',
#  'tt0790772',
#  'tt0290095',
#  'tt0114781',
#  'tt1205537',
#  'tt2446980',
#  'tt3300542',
#  'tt0118583',
#  'tt0822854',
#  'tt0787474',
#  'tt0120791',
#  'tt1490017',
#  'tt0385307',
#  'tt0253556',
#  'tt1321870',
#  'tt1045778',
#  'tt1057500',
#  'tt0473705',
#  'tt1135487',
#  'tt0120764',
#  'tt0443632',
#  'tt0762125',
#  'tt0253754',
#  'tt0138524',
#  'tt2083383',
#  'tt1226273',
#  'tt0120004',
#  'tt0289848',
#  'tt1034331',
#  'tt0120749',
#  'tt0821642',
#  'tt0146984',
#  'tt0181875',
#  'tt0455499',
#  'tt0329774',
#  'tt0822847',
#  'tt0165982',
#  'tt0119081',
#  'tt0259288',
#  'tt0387877',
#  'tt0454824',
#  'tt0272020',
#  'tt0134983',
#  'tt1837709',
#  'tt1538403',
#  'tt0765476',
#  'tt0382628',
#  'tt0131369',
#  'tt0494238',
#  'tt0831887',
#  'tt3045616',
#  'tt0460780',
#  'tt0294357',
#  'tt4591310',
#  'tt0326905',
#  'tt1431045',
#  'tt0120701',
#  'tt2179136',
#  'tt1051904',
#  'tt0115341',
#  'tt0425123',
#  'tt0158622',
#  'tt0095956',
#  'tt0379865',
#  'tt2479478',
#  'tt1314228',
#  'tt2234155',
#  'tt1220634',
#  'tt0485985',
#  'tt0159206',
#  'tt0118971',
#  'tt1232200',
#  'tt0116136',
#  'tt0367479',
#  'tt1071875',
#  'tt0238112',
#  'tt1986770',
#  'tt0395699',
#  'tt0351977',
#  'tt0109830',
#  'tt0952640',
#  'tt0212338',
#  'tt0114148',
#  'tt0078346',
#  'tt0117218',
#  'tt0386588',
#  'tt0119190',
#  'tt0328828',
#  'tt1535109',
#  'tt1279935',
#  'tt0112642',
#  'tt0455944',
#  'tt0252076',
#  'tt0112740',
#  'tt0454921',
#  'tt0408790',
#  'tt0109635',
#  'tt0120632',
#  'tt0266697',
#  'tt0131325',
#  'tt0118480',
#  'tt0378194',
#  'tt0098439',
#  'tt0104070',
#  'tt0184894',
#  'tt0116253',
#  'tt1396218',
#  'tt0865556',
#  'tt1621039',
#  'tt0103644',
#  'tt0116250',
#  'tt0122690',
#  'tt0116409',
#  'tt1109624',
#  'tt1298649',
#  'tt0269347',
#  'tt0128278',
#  'tt0338466',
#  'tt0839980',
#  'tt1430626',
#  'tt0824747',
#  'tt0115857',
#  'tt0116277',
#  'tt0293508',
#  'tt0414055',
#  'tt0402022',
#  'tt0279111',
#  'tt0120390',
#  'tt0780567',
#  'tt2281587',
#  'tt0167456',
#  'tt1126591',
#  'tt0344510',
#  'tt0056193',
#  'tt0160184',
#  'tt0187738',
#  'tt0814314',
#  'tt1308729',
#  'tt0099674',
#  'tt0368709',
#  'tt0463034',
#  'tt0081573',
#  'tt0299930',
#  'tt0405676',
#  'tt0162650',
#  'tt0118617',
#  'tt0203009',
#  'tt0249478',
#  'tt1355683',
#  'tt0418689',
#  'tt1197624',
#  'tt0462322',
#  'tt0120603',
#  'tt0338216',
#  'tt0264464',
#  'tt1790885',
#  'tt0452594',
#  'tt0795421',
#  'tt0817230',
#  'tt0377818',
#  'tt0120863',
#  'tt1488555',
#  'tt0125664',
#  'tt0112641',
#  'tt1179034',
#  'tt0245803',
#  'tt0183505',
#  'tt0414853',
#  'tt0790604',
#  'tt1259571',
#  'tt0126029',
#  'tt1385826',
#  'tt0102798',
#  'tt0116695',
#  'tt1637725',
#  'tt0119822',
#  'tt0129290',
#  'tt1229340',
#  'tt0280590',
#  'tt1650062',
#  'tt0195685',
#  'tt0251127',
#  'tt2294449',
#  'tt0110148',
#  'tt1068680',
#  'tt1489889',
#  'tt0120686',
#  'tt1528854',
#  'tt2180411',
#  'tt0454848',
#  'tt0120784',
#  'tt0112715',
#  'tt1389137',
#  'tt0448011',
#  'tt0427229',
#  'tt0377109',
#  'tt1570728',
#  'tt0356634',
#  'tt0388419',
#  'tt1210166',
#  'tt0114069',
#  'tt2024469',
#  'tt1075417',
#  'tt0434409',
#  'tt0300471',
#  'tt4192812',
#  'tt0381971',
#  'tt0400497',
#  'tt0260866',
#  'tt1428538',
#  'tt0250797',
#  'tt1464540',
#  'tt0365737',
#  'tt4172430',
#  'tt2262227',
#  'tt0408345',
#  'tt0118548',
#  'tt0119173',
#  'tt0119174',
#  'tt0384537',
#  'tt0191397',
#  'tt1605630',
#  'tt0120768',
#  'tt2106361',
#  'tt0109254',
#  'tt0099700',
#  'tt1872194',
#  'tt0119874',
#  'tt0318627',
#  'tt0317198',
#  'tt0313443',
#  'tt0110725',
#  'tt0424774',
#  'tt0163978',
#  'tt0350028',
#  'tt1186367',
#  'tt0126916',
#  'tt0108967',
#  'tt0117765',
#  'tt1392197',
#  'tt1212419',
#  'tt0264935',
#  'tt0112401',
#  'tt0367959',
#  'tt0160916',
#  'tt1517260',
#  'tt0264395',
#  'tt0309377',
#  'tt0963178',
#  'tt0116225',
#  'tt2355844',
#  'tt0129167',
#  ...]

# %% [markdown]
# **Update previously created collection with these dictionaries**

# %%
for i in range(len(dffb_d)):
    coll.update_one({'imdb_id': id_l[i]}, {"$set": {'title': dffb_d[i]['title']}}, upsert=True )
    coll.update_one({'imdb_id': id_l[i]}, {"$set": {'rating': dffb_d[i]['rating']}}, upsert=True )
    coll.update_one({'imdb_id': id_l[i]}, {"$set": {'genres': dffb_d[i]['genres']}}, upsert=True )
    coll.update_one({'imdb_id': id_l[i]}, {"$set": {'imdb_score': dffb_d[i]['imdb_score']}}, upsert=True )
    coll.update_one({'imdb_id': id_l[i]}, {"$set": {'facebook': facebook_d[i]}}, upsert=True )

# %% [markdown]
# **Confirm data has been added by querying the collection**

# %%
# Count documents
coll.count_documents({})
# Out:
# 45737

# %%
# Record in df only
coll.find_one({'imdb_id': 'tt0113497'})
# Out:
# {'_id': ObjectId('5ecd7a289bbb609a3d756150'),
#  'imdb_id': 'tt0113497',
#  'title': 'Jumanji',
#  'genres': 'Adventure, Fantasy, Family',
#  'budget': '65000000',
#  'revenue': 262797249.0,
#  'popularity': '17.015539',
#  'vote_average': 6.9,
#  'vote_count': 2413.0}

# %%
# Record in dffb only
coll.find_one({'imdb_id': 'tt0430371'})
# Out:
# {'_id': ObjectId('5ecd7c038d36a8465d86a18a'),
#  'imdb_id': 'tt0430371',
#  'title': 'The Mongol King',
#  'rating': 'PG-13',
#  'genres': 'Crime, Drama',
#  'imdb_score': 7.8,
#  'facebook': {'movie_likes': 4,
#   'cast': {'director': 'Anthony Vallone',
#    'director_likes': 2.0,
#    'actor_1': 'Richard Jewell',
#    'actor_1_likes': 45.0,
#    'actor_2': 'John Considine',
#    'actor_2_likes': 44.0,
#    'actor_3': 'Sara Stepnicka',
#    'actor_3_likes': 2.0}}}

# %%
# Record in both datasets
coll.find_one({'imdb_id': 'tt0114709'})
# Out:
# {'_id': ObjectId('5ecd7a289bbb609a3d75614f'),
#  'imdb_id': 'tt0114709',
#  'title': 'Toy Story',
#  'genres': 'Adventure, Animation, Comedy, Family, Fantasy',
#  'budget': '30000000',
#  'revenue': 373554033.0,
#  'popularity': '21.946943',
#  'vote_average': 7.7,
#  'vote_count': 5415.0,
#  'rating': 'G',
#  'imdb_score': 8.3,
#  'facebook': {'movie_likes': 0,
#   'cast': {'director': 'John Lasseter',
#    'director_likes': 487.0,
#    'actor_1': 'Tom Hanks',
#    'actor_1_likes': 15000.0,
#    'actor_2': 'John Ratzenberger',
#    'actor_2_likes': 1000.0,
#    'actor_3': 'Jim Varney',
#    'actor_3_likes': 802.0}}}

# %%
# Record with some NaNs
coll.find_one({'imdb_id': 'tt2035599'})
# Out:
# {'_id': ObjectId('5ecd7a299bbb609a3d75b0d7'),
#  'imdb_id': 'tt2035599',
#  'title': 'Pink Ribbons, Inc.',
#  'genres': 'Documentary',
#  'budget': '900000',
#  'revenue': 25000.0,
#  'popularity': '0.489328',
#  'vote_average': 6.8,
#  'vote_count': 6.0,
#  'rating': 'Not Rated',
#  'imdb_score': 7.4,
#  'facebook': {'movie_likes': 5000,
#   'cast': {'director': 'Léa Pool',
#    'director_likes': 4.0,
#    'actor_1': nan,
#    'actor_1_likes': nan,
#    'actor_2': nan,
#    'actor_2_likes': nan,
#    'actor_3': nan,
#    'actor_3_likes': nan}}}
